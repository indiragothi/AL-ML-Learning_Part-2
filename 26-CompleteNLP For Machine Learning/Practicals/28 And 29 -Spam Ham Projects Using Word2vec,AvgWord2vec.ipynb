# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\indira gothi\downloads\ai-ml-learning\venv\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\indira gothi\downloads\ai-ml-learning\venv\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\indira gothi\downloads\ai-ml-learning\venv\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\indira gothi\downloads\ai-ml-learning\venv\lib\site-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\indira gothi\downloads\ai-ml-learning\venv\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
#        -5.46875000e-02,  1.53198242e-02, -1.62109375e-01,  1.58203125e-01,
#        -2.59765625e-01,  2.01416016e-02, -1.63085938e-01,  1.35803223e-03,
#        -1.44531250e-01, -5.68847656e-02,  4.29687500e-02, -2.46582031e-02,
#         1.85546875e-01,  4.47265625e-01,  9.58251953e-03,  1.31835938e-01,
#         9.86328125e-02, -1.85546875e-01, -1.00097656e-01, -1.33789062e-01,
#        -1.25000000e-01,  2.83203125e-01,  1.23046875e-01,  5.32226562e-02,
#        -1.77734375e-01,  8.59375000e-02, -2.18505859e-02,  2.05078125e-02,
#        -1.39648438e-01,  2.51464844e-02,  1.38671875e-01, -1.05468750e-01,
#         1.38671875e-01,  8.88671875e-02, -7.51953125e-02, -2.13623047e-02,
#         1.72851562e-01,  4.63867188e-02, -2.65625000e-01,  8.91113281e-03,
#         1.49414062e-01,  3.78417969e-02,  2.38281250e-01, -1.24511719e-01,
#        -2.17773438e-01, -1.81640625e-01,  2.97851562e-02,  5.71289062e-02,
#        -2.89306641e-02,  1.24511719e-02,  9.66796875e-02, -2.31445312e-01,
#         5.81054688e-02,  6.68945312e-02,  7.08007812e-02, -3.08593750e-01,
#        -2.14843750e-01,  1.45507812e-01, -4.27734375e-01, -9.39941406e-03,
#         1.54296875e-01, -7.66601562e-02,  2.89062500e-01,  2.77343750e-01,
#        -4.86373901e-04, -1.36718750e-01,  3.24218750e-01, -2.46093750e-01,
#        -3.03649902e-03, -2.11914062e-01,  1.25000000e-01,  2.69531250e-01,
#         2.04101562e-01,  8.25195312e-02, -2.01171875e-01, -1.60156250e-01,
#        -3.78417969e-02, -1.20117188e-01,  1.15234375e-01, -4.10156250e-02,
#        -3.95507812e-02, -8.98437500e-02,  6.34765625e-03,  2.03125000e-01,
#         1.86523438e-01,  2.73437500e-01,  6.29882812e-02,  1.41601562e-01,
#        -9.81445312e-02,  1.38671875e-01,  1.82617188e-01,  1.73828125e-01,
#         1.73828125e-01, -2.37304688e-01,  1.78710938e-01,  6.34765625e-02,
#         2.36328125e-01, -2.08984375e-01,  8.74023438e-02, -1.66015625e-01,
#        -7.91015625e-02,  2.43164062e-01, -8.88671875e-02,  1.26953125e-01,
#        -2.16796875e-01, -1.73828125e-01, -3.59375000e-01, -8.25195312e-02,
#        -6.49414062e-02,  5.07812500e-02,  1.35742188e-01, -7.47070312e-02,
#        -1.64062500e-01,  1.15356445e-02,  4.45312500e-01, -2.15820312e-01,
#        -1.11328125e-01, -1.92382812e-01,  1.70898438e-01, -1.25000000e-01,
#         2.65502930e-03,  1.92382812e-01, -1.74804688e-01,  1.39648438e-01,
#         2.92968750e-01,  1.13281250e-01,  5.95703125e-02, -6.39648438e-02,
#         9.96093750e-02, -2.72216797e-02,  1.96533203e-02,  4.27246094e-02,
#        -2.46093750e-01,  6.39648438e-02, -2.25585938e-01, -1.68945312e-01,
#         2.89916992e-03,  8.20312500e-02,  3.41796875e-01,  4.32128906e-02,
#         1.32812500e-01,  1.42578125e-01,  7.61718750e-02,  5.98144531e-02,
#        -1.19140625e-01,  2.74658203e-03, -6.29882812e-02, -2.72216797e-02,
#        -4.82177734e-03, -8.20312500e-02, -2.49023438e-02, -4.00390625e-01,
#        -1.06933594e-01,  4.24804688e-02,  7.76367188e-02, -1.16699219e-01,
#         7.37304688e-02, -9.22851562e-02,  1.07910156e-01,  1.58203125e-01,
#         4.24804688e-02,  1.26953125e-01,  3.61328125e-02,  2.67578125e-01,
#        -1.01074219e-01, -3.02734375e-01, -5.76171875e-02,  5.05371094e-02,
#         5.26428223e-04, -2.07031250e-01, -1.38671875e-01, -8.97216797e-03,
#        -2.78320312e-02, -1.41601562e-01,  2.07031250e-01, -1.58203125e-01,
#         1.27929688e-01,  1.49414062e-01, -2.24609375e-02, -8.44726562e-02,
#         1.22558594e-01,  2.15820312e-01, -2.13867188e-01, -3.12500000e-01,
#        -3.73046875e-01,  4.08935547e-03,  1.07421875e-01,  1.06933594e-01,
#         7.32421875e-02,  8.97216797e-03, -3.88183594e-02, -1.29882812e-01,
#         1.49414062e-01, -2.14843750e-01, -1.83868408e-03,  9.91210938e-02,
#         1.57226562e-01, -1.14257812e-01, -2.05078125e-01,  9.91210938e-02,
#         3.69140625e-01, -1.97265625e-01,  3.54003906e-02,  1.09375000e-01,
#         1.31835938e-01,  1.66992188e-01,  2.35351562e-01,  1.04980469e-01,
#        -4.96093750e-01, -1.64062500e-01, -1.56250000e-01, -5.22460938e-02,
#         1.03027344e-01,  2.43164062e-01, -1.88476562e-01,  5.07812500e-02,
#        -9.37500000e-02, -6.68945312e-02,  2.27050781e-02,  7.61718750e-02,
#         2.89062500e-01,  3.10546875e-01, -5.37109375e-02,  2.28515625e-01,
#         2.51464844e-02,  6.78710938e-02, -1.21093750e-01, -2.15820312e-01,
#        -2.73437500e-01, -3.07617188e-02, -3.37890625e-01,  1.53320312e-01,
#         2.33398438e-01, -2.08007812e-01,  3.73046875e-01,  8.20312500e-02,
#         2.51953125e-01, -7.61718750e-02, -4.66308594e-02, -2.23388672e-02,
#         2.99072266e-02, -5.93261719e-02, -4.66918945e-03, -2.44140625e-01,
#        -2.09960938e-01, -2.87109375e-01, -4.54101562e-02, -1.77734375e-01,
#        -2.79296875e-01, -8.59375000e-02,  9.13085938e-02,  2.51953125e-01],
#       dtype=float32)

# %%
import pandas as pd
messages=pd.read_csv('SpamClassifier-master/smsspamcollection/SMSSpamCollection',
                    sep='\t',names=["label","message"])

# %%
messages.shape
# Out:
# (5572, 2)

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\indira
# [nltk_data]     gothi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
    review = review.lower()
    review = review.split()
    
    review = [lemmatizer.lemmatize(word) for word in review]
    review = ' '.join(review)
    corpus.append(review)

# %%
[[i,j,k] for i,j,k in zip(list(map(len,corpus)),corpus, messages['message']) if i<1]
# Out:
# [[0, '', '645'], [0, '', ':) '], [0, '', ':-) :-)']]

# %%
corpus
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#  'ok lar joking wif u oni',
#  'free entry in a wkly comp to win fa cup final tkts st may text fa to to receive entry question std txt rate t c s apply over s',
#  'u dun say so early hor u c already then say',
#  'nah i don t think he go to usf he life around here though',
#  'freemsg hey there darling it s been week s now and no word back i d like some fun you up for it still tb ok xxx std chgs to send to rcv',
#  'even my brother is not like to speak with me they treat me like aid patent',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'winner a a valued network customer you have been selected to receivea prize reward to claim call claim code kl valid hour only',
#  'had your mobile month or more u r entitled to update to the latest colour mobile with camera for free call the mobile update co free on',
#  'i m gonna be home soon and i don t want to talk about this stuff anymore tonight k i ve cried enough today',
#  'six chance to win cash from to pound txt csh and send to cost p day day tsandcs apply reply hl info',
#  'urgent you have won a week free membership in our prize jackpot txt the word claim to no t c www dbuk net lccltd pobox ldnw a rw',
#  'i ve been searching for the right word to thank you for this breather i promise i wont take your help for granted and will fulfil my promise you have been wonderful and a blessing at all time',
#  'i have a date on sunday with will',
#  'xxxmobilemovieclub to use your credit click the wap link in the next txt message or click here http wap xxxmobilemovieclub com n qjkgighjjgcbl',
#  'oh k i m watching here',
#  'eh u remember how spell his name yes i did he v naughty make until i v wet',
#  'fine if that s the way u feel that s the way it gota b',
#  'england v macedonia dont miss the goal team news txt ur national team to eg england to try wale scotland txt poboxox w wq',
#  'is that seriously how you spell his name',
#  'i m going to try for month ha ha only joking',
#  'so pay first lar then when is da stock comin',
#  'aft i finish my lunch then i go str down lor ard smth lor u finish ur lunch already',
#  'ffffffffff alright no way i can meet up with you sooner',
#  'just forced myself to eat a slice i m really not hungry tho this suck mark is getting worried he know i m sick when i turn down pizza lol',
#  'lol your always so convincing',
#  'did you catch the bus are you frying an egg did you make a tea are you eating your mom s left over dinner do you feel my love',
#  'i m back amp we re packing the car now i ll let you know if there s room',
#  'ahhh work i vaguely remember that what doe it feel like lol',
#  'wait that s still not all that clear were you not sure about me being sarcastic or that that s why x doesn t want to live with u',
#  'yeah he got in at and wa v apologetic n had fallen out and she wa actin like spoilt child and he got caught up in that till but we won t go there not doing too badly cheer you',
#  'k tell me anything about you',
#  'for fear of fainting with the of all that housework you just did quick have a cuppa',
#  'thanks for your subscription to ringtone uk your mobile will be charged month please confirm by replying yes or no if you reply no you will not be charged',
#  'yup ok i go home look at the timing then i msg again xuhui going to learn on nd may too but her lesson is at am',
#  'oops i ll let you know when my roommate s done',
#  'i see the letter b on my car',
#  'anything lor u decide',
#  'hello how s you and how did saturday go i wa just texting to see if you d decided to do anything tomo not that i m trying to invite myself or anything',
#  'pls go ahead with watt i just wanted to be sure do have a great weekend abiola',
#  'did i forget to tell you i want you i need you i crave you but most of all i love you my sweet arabian steed mmmmmm yummy',
#  'rodger burn msg we tried to call you re your reply to our sm for a free nokia mobile free camcorder please call now for delivery tomorrow',
#  'who are you seeing',
#  'great i hope you like your man well endowed i am lt gt inch',
#  'no call message missed call',
#  'didn t you get hep b immunisation in nigeria',
#  'fair enough anything going on',
#  'yeah hopefully if tyler can t do it i could maybe ask around a bit',
#  'u don t know how stubborn i am i didn t even want to go to the hospital i kept telling mark i m not a weak sucker hospital are for weak sucker',
#  'what you thinked about me first time you saw me in class',
#  'a gram usually run like lt gt a half eighth is smarter though and get you almost a whole second gram for lt gt',
#  'k fyi x ha a ride early tomorrow morning but he s crashing at our place tonight',
#  'wow i never realized that you were so embarassed by your accomodations i thought you liked it since i wa doing the best i could and you always seemed so happy about the cave i m sorry i didn t and don t have more to give i m sorry i offered i m sorry your room wa so embarassing',
#  'sm ac sptv the new jersey devil and the detroit red wing play ice hockey correct or incorrect end reply end sptv',
#  'do you know what mallika sherawat did yesterday find out now lt url gt',
#  'congrats year special cinema pas for is yours call now c suprman v matrix starwars etc all free bx ip we pm dont miss out',
#  'sorry i ll call later in meeting',
#  'tell where you reached',
#  'yes gauti and sehwag out of odi series',
#  'your gonna have to pick up a burger for yourself on your way home i can t even move pain is killing me',
#  'ha ha ha good joke girl are situation seeker',
#  'it a part of checking iq',
#  'sorry my roommate took forever it ok if i come by now',
#  'ok lar i double check wif da hair dresser already he said wun cut v short he said will cut until i look nice',
#  'a a valued customer i am pleased to advise you that following recent review of your mob no you are awarded with a bonus prize call',
#  'today is song dedicated day which song will u dedicate for me send this to all ur valuable frnds but first rply me',
#  'urgent ur awarded a complimentary trip to eurodisinc trav aco entry or to claim txt dis to morefrmmob shracomorsglsuplt l aj',
#  'did you hear about the new divorce barbie it come with all of ken s stuff',
#  'i plane to give on this month end',
#  'wah lucky man then can save money hee',
#  'finished class where are you',
#  'hi babe im at home now wanna do something xx',
#  'k k where are you how did you performed',
#  'u can call me now',
#  'i am waiting machan call me once you free',
#  'thats cool i am a gentleman and will treat you with dignity and respect',
#  'i like you people very much but am very shy pa',
#  'doe not operate after lt gt or what',
#  'it not the same here still looking for a job how much do ta s earn there',
#  'sorry i ll call later',
#  'k did you call me just now ah',
#  'ok i am on the way to home hi hi',
#  'you will be in the place of that man',
#  'yup next stop',
#  'i call you later don t have network if urgnt sm me',
#  'for real when u getting on yo i only need more ticket and one more jacket and i m done i already used all my multis',
#  'yes i started to send request to make it but pain came back so i m back in bed double coin at the factory too i gotta cash in all my nitros',
#  'i m really not up to it still tonight babe',
#  'ela kano il download come wen ur free',
#  'yeah do don t stand to close tho you ll catch something',
#  'sorry to be a pain is it ok if we meet another night i spent late afternoon in casualty and that mean i haven t done any of y stuff moro and that includes all my time sheet and that sorry',
#  'smile in pleasure smile in pain smile when trouble pours like rain smile when sum hurt u smile becoz someone still love to see u smiling',
#  'please call our customer service representative on between am pm a you have won a guaranteed cash or prize',
#  'havent planning to buy later i check already lido only got show in e afternoon u finish work already',
#  'your free ringtone is waiting to be collected simply text the password mix to to verify get usher and britney fml po box mk h ppw',
#  'watching telugu movie wat abt u',
#  'i see when we finish we have load of loan to pay',
#  'hi wk been ok on hols now yes on for a bit of a run forgot that i have hairdresser appointment at four so need to get home n shower beforehand doe that cause prob for u',
#  'i see a cup of coffee animation',
#  'please don t text me anymore i have nothing else to say',
#  'okay name ur price a long a it legal wen can i pick them up y u ave x am xx',
#  'i m still looking for a car to buy and have not gone the driving test yet',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'wow you re right i didn t mean to do that i guess once i gave up on boston men and changed my search location to nyc something changed cuz on my signin page it still say boston',
#  'umma my life and vava umma love you lot dear',
#  'thanks a lot for your wish on my birthday thanks you for making my birthday truly memorable',
#  'aight i ll hit you up when i get some cash',
#  'how would my ip address test that considering my computer isn t a minecraft server',
#  'i know grumpy old people my mom wa like you better not be lying then again i am always the one to play joke',
#  'dont worry i guess he s busy',
#  'what is the plural of the noun research',
#  'going for dinner msg you after',
#  'i m ok wif it co i like try new thing but i scared u dun like mah co u said not too loud',
#  'gent we are trying to contact you last weekend draw show that you won a prize guaranteed call claim code k valid hr only ppm',
#  'wa ur openin sentence very formal anyway i m fine too juz tt i m eatin too much n puttin on weight haha so anythin special happened',
#  'a i entered my cabin my pa said happy b day bos i felt special she askd me lunch after lunch she invited me to her apartment we went there',
#  'you are a winner u have been specially selected receive or a holiday flight inc speak to a live operator claim p min',
#  'goodo yes we must speak friday egg potato ratio for tortilla needed',
#  'hmm my uncle just informed me that he s paying the school directly so pls buy food',
#  'private your account statement for show unredeemed bonus point to claim call identifier code expires',
#  'urgent your mobile no wa awarded bonus caller prize on this is our final try to contact u call from landline box wr c ppm',
#  'here is my new address apple pair all that malarky',
#  'today voda number ending are selected to receive a award if you have a match please call quoting claim code standard rate app',
#  'i am going to sao mu today will be done only at',
#  'predict wat time ll finish buying',
#  'good stuff will do',
#  'just so that you know yetunde hasn t sent money yet i just sent her a text not to bother sending so it over you dont have to involve yourself in anything i shouldn t have imposed anything on you in the first place so for that i apologise',
#  'are you there in room',
#  'hey girl how r u hope u r well me an del r bak again long time no c give me a call sum time from lucyxx',
#  'k k how much doe it cost',
#  'i m home',
#  'dear will call tmorrow pls accomodate',
#  'first answer my question',
#  'sunshine quiz wkly q win a top sony dvd player if u know which country the algarve is in txt ansr to sp tyrone',
#  'want get laid tonight want real dogging location sent direct ur mob join the uk s largest dogging network bt txting gravel to nt ec a p msg p',
#  'i only haf msn it s yijue hotmail com',
#  'he is there you call and meet him',
#  'no no i will check all room befor activity',
#  'you ll not rcv any more msg from the chat svc for free hardcore service text go to if u get nothing u must age verify with yr network try again',
#  'got c i lazy to type i forgot in lect i saw a pouch but like not v nice',
#  'k text me when you re on the way',
#  'sir waiting for your mail',
#  'a swt thought nver get tired of doing little thing lovable person coz somtimes those little thing occupy d biggest part in their heart gud ni',
#  'i know you are can you pls open the back',
#  'yes see ya not on the dot',
#  'whats the staff name who is taking class for u',
#  'freemsg why haven t you replied to my text i m randy sexy female and live local luv to hear from u netcollex ltd p per msg reply stop to end',
#  'ummma will call after check in our life will begin from qatar so pls pray very hard',
#  'k i deleted my contact that why',
#  'sindu got job in birla soft',
#  'the wine is flowing and i m i have nevering',
#  'yup i thk cine is better co no need go down plaza mah',
#  'ok ur typical reply',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'you are everywhere dirt on the floor the window even on my shirt and sometimes when i open my mouth you are all that come flowing out i dream of my world without you then half my chore are out too a time of joy for me lot of tv show i ll see but i guess like all thing you just must exist like rain hail and mist and when my time here is done you and i become one',
#  'aaooooright are you at work',
#  'i m leaving my house now',
#  'hello my love what are you doing did you get to that interview today are you you happy are you being a good boy do you think of me are you missing me',
#  'customer service annoncement you have a new year delivery waiting for you please call now to arrange delivery',
#  'you are a winner u have been specially selected receive cash or a holiday flight inc speak to a live operator claim',
#  'keep yourself safe for me because i need you and i miss you already and i envy everyone that see s you in real life',
#  'new car and house for my parent i have only new job in hand',
#  'i m so in love with you i m excited each day i spend with you you make me so happy',
#  'pls stop bootydelious f is inviting you to be her friend reply yes or no see her www sm ac u bootydelious stop send stop frnd to',
#  'bangbabes ur order is on the way u should receive a service msg download ur content if u do not goto wap bangb tv on ur mobile internet service menu',
#  'i place all ur point on e culture module already',
#  'urgent we are trying to contact you last weekend draw show that you have won a prize guaranteed call claim code s valid hr only',
#  'hi frnd which is best way to avoid missunderstding wit our beloved one s',
#  'great escape i fancy the bridge but need her lager see you tomo',
#  'yes it completely in out of form clark also utter waste',
#  'sir i need axis bank account no and bank address',
#  'hmmm thk sure got time to hop ard ya can go free abt muz call u to discus liao',
#  'what time you coming down later',
#  'bloody hell cant believe you forgot my surname mr ill give u a clue it spanish and begin with m',
#  'well i m gonna finish my bath now have a good fine night',
#  'let me know when you ve got the money so carlos can make the call',
#  'u still going to the mall',
#  'turn out my friend are staying for the whole show and won t be back til lt gt so feel free to go ahead and smoke that lt gt worth',
#  'text her if she doesnt reply let me know so i can have her log in',
#  'hi you just spoke to maneesha v we d like to know if you were satisfied with the experience reply toll free with yes or no',
#  'you lifted my hope with the offer of money i am in need especially when the end of the month approach and it hurt my studying anyways have a gr weekend',
#  'lol no u can trust me',
#  'ok i am a gentleman and will treat you with dignity and respect',
#  'he will you guy close',
#  'going on nothing great bye',
#  'hello handsome are you finding that job not being lazy working towards getting back that net for mummy where s my boytoy now doe he miss me',
#  'haha awesome be there in a minute',
#  'please call our customer service representative on freephone between am pm a you have won a guaranteed cash or prize',
#  'have you got xmas radio time if not i will get it now',
#  'i jus reached home i go bathe first but my si using net tell u when she finish k',
#  'are you unique enough find out from th august www areyouunique co uk',
#  'i m sorry i ve joined the league of people that dont keep in touch you mean a great deal to me you have been a friend at all time even at great personal cost do have a great week',
#  'hi finally i completed the course',
#  'it will stop on itself i however suggest she stay with someone that will be able to give or for every stool',
#  'how are you doing hope you ve settled in for the new school year just wishin you a gr day',
#  'gud mrng dear hav a nice day',
#  'did u got that person story',
#  'is your hamster dead hey so tmr i meet you at pm orchard mrt',
#  'hi it kate how is your evening i hope i can see you tomorrow for a bit but i have to bloody babyjontet txt back if u can xxx',
#  'found it enc lt gt where you at',
#  'i sent you lt gt buck',
#  'hello darlin ive finished college now so txt me when u finish if u can love kate xxx',
#  'your account ha been refilled successfully by inr lt decimal gt your keralacircle prepaid account balance is r lt decimal gt your transaction id is kr lt gt',
#  'goodmorning sleeping ga',
#  'u call me alter at ok',
#  'say until like dat i dun buy ericsson oso cannot oredi lar',
#  'a i entered my cabin my pa said happy b day bos i felt special she askd me lunch after lunch she invited me to her apartment we went there',
#  'aight yo dat straight dogg',
#  'you please give u connection today itself before lt decimal gt or refund the bill',
#  'both i shoot big load so get ready',
#  'what s up bruv hope you had a great break do have a rewarding semester',
#  'home so we can always chat',
#  'k k good study well',
#  'yup how noe leh',
#  'sound great are you home now',
#  'finally the match heading towards draw a your prediction',
#  'tired i haven t slept well the past few night',
#  'easy ah sen got selected mean it good',
#  'i have to take exam with march',
#  'yeah you should i think you can use your gt atm now to register not sure but if there s anyway i can help let me know but when you do be sure you are ready',
#  'ok no prob take ur time',
#  'there is o called ubandu which will run without installing in hard disk you can use that o to copy the important file in system and give it to repair shop',
#  'sorry i ll call later',
#  'u say leh of course nothing happen lar not say v romantic jus a bit only lor i thk e nite scenery not so nice leh',
#  'new mobile from must go txt nokia to no collect yours today from only www tc biz optout gbp mtmsg',
#  'would really appreciate if you call me just need someone to talk to',
#  'will u meet ur dream partner soon is ur career off a flyng start find out free txt horo followed by ur star sign e g horo aries',
#  'hey company elama po mudyadhu',
#  'life is more strict than teacher bcoz teacher teach lesson amp then conduct exam but life first conduct exam amp then teach lesson happy morning',
#  'dear good morning now only i am up',
#  'get down in gandhipuram and walk to cross cut road right side lt gt street road and turn at first right',
#  'dear we are going to our rubber place',
#  'sorry battery died yeah i m here',
#  'yes here tv is always available in work place',
#  'text meet someone sexy today u can find a date or even flirt it up to u join just p reply with name age eg sam msg recd thirtyeight penny',
#  'i have printed it oh so lt gt come upstairs',
#  'or ill be a little closer like at the bus stop on the same street',
#  'where are you when wil you reach here',
#  'new theory argument win d situation but loses the person so dont argue with ur friend just kick them amp say i m always correct',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on',
#  'tomarrow final hearing on my laptop case so i cant',
#  'pleassssssseeeeee tel me v avent done sportsx',
#  'okay no no just shining on that wa meant to be signing but that sound better',
#  'although i told u dat i m into baig face watch now but i really like e watch u gave co it s fr u thanx everything dat u ve done today i m touched',
#  'u don t remember that old commercial',
#  'too late i said i have the website i didn t i have or dont have the slipper',
#  'i asked you to call him now ok',
#  'kallis wont bat in nd inning',
#  'it didnt work again oh ok goodnight then i ll fix and have it ready by the time you wake up you are very dearly missed have a good night sleep',
#  'congratulation ur awarded of cd voucher or gift guaranteed free entry wkly draw txt music to tncs www ldew com win ppmx age',
#  'ranjith cal drpd deeraj and deepak min hold',
#  'wen ur lovable bcums angry wid u dnt take it seriously coz being angry is d most childish n true way of showing deep affection care n luv kettoda manda have nice day da',
#  'what you doing how are you',
#  'ups which is day also and the shipping company that take wks the other way is usps which take a week but when it get to lag you may have to bribe nipost to get your stuff',
#  'i m back lemme know when you re ready',
#  'don t necessarily expect it to be done before you get back though because i m just now headin out',
#  'mmm so yummy babe nice jolt to the suzy',
#  'where are you lover i need you',
#  'we tried to contact you re your reply to our offer of a video handset anytime network min unlimited text camcorder reply or call now',
#  'i m parked next to a mini when are you coming in today do you think',
#  'yup',
#  'anyway i m going shopping on my own now co my si not done yet dun disturb u liao',
#  'my no in luton ring me if ur around h',
#  'hey i am really horny want to chat or see me naked text hot to text charged at pm to unsubscribe text stop',
#  'why you dint come with u',
#  'same wana plan a trip sometme then',
#  'not sure yet still trying to get a hold of him',
#  'ur ringtone service ha changed free credit go to club mobile com to choose content now stop txt club stop to p wk club po box mk wt',
#  'the evo i just had to download flash jealous',
#  'ringtone club get the uk single chart on your mobile each week and choose any top quality ringtone this message is free of charge',
#  'come to mu we re sorting out our narcotic situation',
#  'night ha ended for another day morning ha come in a special way may you smile like the sunny ray and leaf your worry at the blue blue bay',
#  'hmv bonus special pound of genuine hmv voucher to be won just answer easy question play now send hmv to more info www percent real com',
#  'usf i guess might a well take car',
#  'no objection my bf not coming',
#  'thanx',
#  'tell rob to mack his gf in the theater',
#  'awesome i ll see you in a bit',
#  'just sent it so what type of food do you like',
#  'all done all handed in celebration in full swing yet',
#  'you got called a tool',
#  'wen u miss someone the person is definitely special for u but if the person is so special why to miss them just keep in touch gdeve',
#  'ok i asked for money how far',
#  'okie',
#  'yeah i think my usual guy s still passed out from last night if you get ahold of anybody let me know and i ll throw down',
#  'k i might come by tonight then if my class let out early',
#  'ok',
#  'hi baby im cruisin with my girl friend what r u up give me a call in and hour at home if thats alright or fone me on this fone now love jenny xxx',
#  'my life mean a lot to me not because i love my life but because i love the people in my life the world call them friend i call them my world ge',
#  'dear shall mail tonite busy in the street shall update you tonite thing are looking ok varunnathu edukkukayee raksha ollu but a good one in real sense',
#  'hey you told your name to gautham ah',
#  'haf u found him i feel so stupid da v cam wa working',
#  'oops got that bit',
#  'are you this much buzy',
#  'i accidentally deleted the message resend please',
#  't mobile customer you may now claim your free camera phone upgrade a pay go sim card for your loyalty call on offer end thfeb t c s apply',
#  'unless it s a situation where you go gurl would be more appropriate',
#  'hurt me tease me make me cry but in the end of my life when i die plz keep one rose on my grave and say stupid i miss u have a nice day bslvyl',
#  'i cant pick the phone right now pls send a message',
#  'need a coffee run tomo can t believe it s that time of week already',
#  'awesome i remember the last time we got somebody high for the first time with diesel v',
#  'shit that is really shocking and scary cant imagine for a second def up for night out do u think there is somewhere i could crash for night save on taxi',
#  'oh and by the way you do have more food in your fridge want to go out for a meal tonight',
#  'he is a womdarfull actor',
#  'sm ac blind date u rodds is m from aberdeen united kingdom check him out http img sm ac w icmb cktz r no blind date send hide',
#  'yup from what i remb i think should be can book',
#  'jos ask if u wana meet up',
#  'lol yes our friendship is hanging on a thread cause u won t buy stuff',
#  'themob check out our newest selection of content game tone gossip babe and sport keep your mobile fit and funky text wap to',
#  'where are the garage key they aren t on the bookshelf',
#  'today is accept day u accept me a brother sister lover dear best clos lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd no rply mean enemy',
#  'think ur smart win this week in our weekly quiz text play to now t c winnersclub po box m uz gbp week',
#  'he say he ll give me a call when his friend s got the money but that he s definitely buying before the end of the week',
#  'hi the way i wa with u day is the normal way this is the real me ur unique i hope i know u the rest of mylife hope u find wot wa lost',
#  'you made my day do have a great day too',
#  'k k advance happy pongal',
#  'hmmm guess we can go kb n power yoga haha dunno we can tahan power yoga anot thk got lo oso forgot liao',
#  'not really dude have no friend i m afraid',
#  'december only had your mobile mths you are entitled to update to the latest colour camera mobile for free call the mobile update co free on',
#  'coffee cake i guess',
#  'merry christmas to you too babe i love ya kiss',
#  'hey why dont we just go watch x men and have lunch haha',
#  'cud u tell ppl im gona b a bit l co bus hav gon past co they were full im still waitin pete x',
#  'that would be great we ll be at the guild could meet on bristol road or somewhere will get in touch over weekend our plan take flight have a good week',
#  'no problem how are you doing',
#  'no call message missed call',
#  'hi da how is the today class',
#  'i d say that s a good sign but well you know my track record at reading woman',
#  'cool text me when you re parked',
#  'i m reading the text i just sent you it meant to be a joke so read it in that light',
#  'k k apo k good movie',
#  'maybe i could get book out tomo then return it immediately or something',
#  'call germany for only penny per minute call from a fixed line via access number no prepayment direct access',
#  'any chance you might have had with me evaporated a soon a you violated my privacy by stealing my phone number from your employer s paperwork not cool at all please do not contact me again or i will report you to your supervisor',
#  'valentine day special win over in our quiz and take your partner on the trip of a lifetime send go to now p msg rcvd custcare',
#  'ta daaaaa i am home babe are you still up',
#  'cool so how come you havent been wined and dined before',
#  'just sleeping and surfing',
#  'sorry i ll call later',
#  'u calling me right call my hand phone',
#  'ok that s great thanx a lot',
#  'i take it the post ha come then you must have s of text now happy reading my one from wiv hello caroline at the end is my favourite bless him',
#  'where u been hiding stranger',
#  'am not interested to do like that',
#  'my sister cleared two round in birla soft yesterday',
#  'gudnite tc practice going on',
#  'dis is yijue i jus saw ur mail in case huiming havent sent u my num dis is my num',
#  'one small prestige problem now',
#  'fancy a shag i do interested sextextuk com txt xxuk suzy to txts cost per msg tncs on website x',
#  'just checking in on you really do miss seeing jeremiah do have a great month',
#  'nah can t help you there i ve never had an iphone',
#  'if you re not in my car in an hour and a half i m going apeshit',
#  'today is sorry day if ever i wa angry with you if ever i misbehaved or hurt you plz plz just slap urself bcoz it ur fault i m basically good',
#  'yo you guy ever figure out how much we need for alcohol jay and i are trying to figure out how much we can safely spend on weed',
#  'lt gt ish minute wa minute ago wtf',
#  'thank you for calling forgot to say happy onam to you sirji i am fine here and remembered you when i met an insurance person meet you in qatar insha allah rakhesh ex tata aig who joined tissco tayseer',
#  'congratulation ur awarded of cd voucher or gift guaranteed free entry wkly draw txt music to tncs www ldew com win ppmx age',
#  'ur cash balance is currently pound to maximize ur cash in now send cash to only p msg cc hg suite land row w j hl',
#  'i m an actor when i work i work in the evening and sleep late since i m unemployed at the moment i always sleep late when you re unemployed every day is saturday',
#  'hello just got here st andrew boy it a long way it cold i will keep you posted',
#  'ha ha cool cool chikku chikku db',
#  'oh ok no prob',
#  'check audrey s status right now',
#  'busy here trying to finish for new year i am looking forward to finally meeting you',
#  'good afternoon sunshine how dawn that day are we refreshed and happy to be alive do we breathe in the air and smile i think of you my love a always',
#  'well i know z will take care of me so no worry',
#  'update now xmas offer latest motorola sonyericsson nokia free bluetooth double min txt on orange call mobileupd on or call optout f q',
#  'here is your discount code rp to stop further message reply stop www regalportfolio co uk customer service',
#  'wat uniform in where get',
#  'cool text me when you re ready',
#  'hello my boytoy geeee i miss you already and i just woke up i wish you were here in bed with me cuddling me i love you',
#  'i will spoil you in bed a well',
#  'i m going for bath will msg you next lt gt min',
#  'i cant keep talking to people if am not sure i can pay them if they agree to price so pls tell me what you want to really buy and how much you are willing to pay',
#  'thanks for your ringtone order reference t you will be charged gbp per week you can unsubscribe at anytime by calling customer service on',
#  'can you say what happen',
#  'you could have seen me i did t recognise you face',
#  'well there s not a lot of thing happening in lindsay on new year sigh some bar in ptbo and the blue heron ha something going',
#  'keep my payasam there if rinu brings',
#  'i taught that ranjith sir called me so only i sm like that becaus he verifying about project prabu told today so only pa dont mistake me',
#  'i guess that s why you re worried you must know that there s a way the body repair itself and i m quite sure you shouldn t worry we ll take it slow first the test they will guide when your ovulation is then just relax nothing you ve said is a reason to worry but i ll keep on followin you up',
#  'yeah sure give me a couple minute to track down my wallet',
#  'hey leave it not a big deal take care',
#  'hey i will be late ah meet you at',
#  'double min and txts month free bluetooth on orange available on sony nokia motorola phone call mobileupd on or call optout n dx',
#  'it took mr owl lick',
#  'customer place i will call you',
#  'mm that time you dont like fun',
#  'mths half price orange line rental latest camera phone free had your phone mths call mobilesdirect free on to update now or stoptxt',
#  'yup having my lunch buffet now u eat already',
#  'huh so late fr dinner',
#  'hey so this sat are we going for the intro pilate only or the kickboxing too',
#  'morning only i can ok',
#  'yes i think so i am in office but my lap is in room i think thats on for the last few day i didnt shut that down',
#  'pick you up bout ish what time are and that going',
#  'from here after the performance award is calculated every two month not for current one month period',
#  'wa actually sleeping and still might when u call back so a text is gr you rock si will send u a text wen i wake',
#  'you are always putting your business out there you put picture of your as on facebook you are one of the most open people i ve ever met why would i think a picture of your room would hurt you make you feel violated',
#  'good evening sir al salam wahleykkum sharing a happy news by the grace of god i got an offer from tayseer tissco and i joined hope you are fine inshah allah meet you sometime rakhesh visitor from india',
#  'hmmm k but i want to change the field quickly da i wanna get system administrator or network administrator',
#  'free ringtone text first to for a poly or text get to for a true tone help after st free tone are x pw to e nd txt stop',
#  'dear how is chechi did you talk to her',
#  'the hair cream ha not been shipped',
#  'none of that s happening til you get here though',
#  'yep the great loxahatchee xmas tree burning of lt gt start in an hour',
#  'haha get used to driving to usf man i know a lot of stoner',
#  'all wa well until slightly disastrous class this pm with my fav darling hope day off ok coffee wld be good a can t stay late tomorrow same time place a always',
#  'hello good week fancy a drink or something later',
#  'headin towards busetop',
#  'message some text missing sender name missing number missing sent date missing missing u a lot thats y everything is missing sent via fullonsms com',
#  'come by our room at some point so we can iron out the plan for this weekend',
#  'co i want it to be your thing',
#  'okies i ll go yan jiu too we can skip ard oso go cine den go mrt one blah blah blah',
#  'bring home some wendy d',
#  'dating service cal l box sk ch',
#  'whatsup there dont u want to sleep',
#  'alright i have a new goal now',
#  'free entry into our weekly competition just text the word win to now t c www txttowin co uk',
#  'alright i ll head out in a few minute text me where to meet you',
#  'send a logo ur lover name joined by a heart txt love name name mobno eg love adam eve to yahoo pobox w wq txtno no ad p',
#  'yes from last week itself i m taking live call',
#  'someone ha contacted our dating service and entered your phone because they fancy you to find out who it is call from a landline pobox n tf p',
#  'siva is in hostel aha',
#  'urgent your mobile number ha been awarded with a prize guaranteed call from land line claim valid hr only',
#  'send this to ur friend and receive something about ur voice how is my speaking expression childish naughty sentiment rowdy ful of attitude romantic shy attractive funny lt gt irritating lt gt lovable reply me',
#  'ok she ll be ok i guess',
#  'aathi where are you dear',
#  'any pain on urination any thing else',
#  'at esplanade do mind giving me a lift co i got no car today',
#  'i wnt to buy a bmw car urgently it vry urgent but hv a shortage of lt gt lac there is no source to arng dis amt lt gt lac thats my prob',
#  'at home watching tv lor',
#  'doe she usually take fifteen fucking minute to respond to a yes or no question',
#  'congrats nokia video camera phone is your call call cost ppm ave call min vary from mobile close post bcm ldn wc n xx',
#  'booked ticket for pongal',
#  'you available now i m like right around hillsborough amp lt gt th',
#  'the message sent is askin for lt gt dollar shoul i pay lt gt or lt gt',
#  'ask g or iouri i ve told the story like ten time already',
#  'how long doe applebees fucking take',
#  'hi hope u get this txt journey hasnt been gd now about min late i think',
#  'but i have to i like to have love and arrange',
#  'yes he is really great bhaji told kallis best cricketer after sachin in world very tough to get out',
#  'you were supposed to wake me up gt',
#  'oic i saw him too but i tot he din c me i found a group liao',
#  'sorry i ll call later',
#  'hey hey werethe monkeespeople say we monkeyaround howdy gorgeous howu doin foundurself a jobyet sausage love jen xxx',
#  'sorry my battery died i can come by but i m only getting a gram for now where s your place',
#  'well done blimey exercise yeah i kinda remember wot that is hmm',
#  'i wont get concentration dear you know you are my mind and everything',
#  'lol have you made plan for new year',
#  'min later k',
#  'hank lotsly',
#  'thanks for this hope you had a good day today',
#  'k k what are detail you want to transfer acc no enough',
#  'ok i will tell her to stay out yeah it been tough but we are optimistic thing will improve this month',
#  'loan for any purpose homeowner tenant welcome have you been previously refused we can still help call free or text back help',
#  'si si i think ill go make those oreo truffle',
#  'look at amy ure a beautiful intelligent woman and i like u a lot i know u don t like me like that so don t worry',
#  'i hope you that s the result of being consistently intelligent and kind start asking him about practicum link and keep your ear open and all the best ttyl',
#  'that call cost which i guess isnt bad miss ya need ya want ya love ya',
#  'going thru a very different feeling wavering decision and coping up with the same is the same individual time will heal everything i believe',
#  'where did u go my phone is gonna die you have to stay in here',
#  'great never been better each day give even more reason to thank god',
#  'upgrdcentre orange customer you may now claim your free camera phone upgrade for your loyalty call now on offer end th july t c s apply opt out available',
#  'sorry i ll call later ok bye',
#  'ok i am on the way to railway',
#  'great princess i love giving and receiving oral doggy style is my fave position how about you i enjoy making love lt gt time per night',
#  'they don t put that stuff on the road to keep it from getting slippery over there',
#  'when are you going to ride your bike',
#  'yup no need i ll jus wait e rain stop',
#  'there are many company tell me the language',
#  'okmail dear dave this is your final notice to collect your tenerife holiday or cash award call from landline tc sae box cw wx ppm',
#  'how long ha it been since you screamed princess',
#  'nothing i meant that once the money enters your account here the bank will remove it flat rate someone transfered lt gt to my account and lt gt dollar got removed so the bank differ and charge also differ be sure you trust the ja person you are sending account detail to co',
#  'want get laid tonight want real dogging location sent direct ur mob join the uk s largest dogging network by txting moan to nyt ec a p msg p',
#  'nice line said by a broken heart plz don t cum more time infront of me other wise once again i ll trust u good t',
#  'ok i m gonna head up to usf in like fifteen minute',
#  'love you aathi love u lot',
#  'tension ah what machi any problem',
#  'k can i pick up another th when you re done',
#  'when re you guy getting back g said you were thinking about not staying for mcr',
#  'almost there see u in a sec',
#  'yo carlos a few friend are already asking me about you you working at all this weekend',
#  'watching tv lor',
#  'thank you baby i cant wait to taste the real thing',
#  'you should change your fb to jaykwon thuglyfe falconerf',
#  'if we win it really no side for long time',
#  'free message activate your free text message by replying to this message with the word free for term condition visit www com',
#  'dear reached railway what happen to you',
#  'depends on quality if you want the type i sent boye faded glory then about if you want ralphs maybe',
#  'i think i ve fixed it can you send a test message',
#  'sorry man my account s dry or i would if you want we could trade back half or i could buy some shit with my credit card',
#  'congrats year special cinema pas for is yours call now c suprman v matrix starwars etc all free bx ip we pm dont miss out',
#  'sorry in meeting i ll call later',
#  'what class of lt gt reunion',
#  'are you free now can i call now',
#  'got meh when',
#  'nope think i will go for it on monday sorry i replied so late',
#  'some of them told accenture is not confirm is it true',
#  'kate jackson rec center before ish right',
#  'dear i have reache room',
#  'fighting with the world is easy u either win or lose bt fightng with some who is close to u is dificult if u lose u lose if u win u still lose',
#  'when can come out',
#  'check with nuerologist',
#  'lolnice i went from a fish to water',
#  'congratulation in this week s competition draw u have won the prize to claim just call b t c stop sm over only ppm',
#  'no it s waiting in e car dat s bored wat co wait outside got nothing do at home can do my stuff or watch tv wat',
#  'maybe westshore or hyde park village the place near my house',
#  'you should know now so how s anthony are you bringing money i ve school fee to pay and rent and stuff like that thats why i need your help a friend in need',
#  'what s the significance',
#  'your opinion about me over jada kusruthi lovable silent spl character not matured stylish simple pls reply',
#  'at the latest g s still there if you can scrounge up some ammo and want to give the new ak a try',
#  'prabha i m soryda realy frm heart i m sory',
#  'lol ok your forgiven',
#  'no jst change tat only',
#  'you are guaranteed the latest nokia phone a gb ipod mp player or a prize txt word collect to no ibhltd ldnw h p mtmsgrcvd',
#  's no competition for him',
#  'boltblue tone for p reply poly or mono eg poly cha cha slide yeah slow jamz toxic come with me or stop more tone txt more',
#  'your credit have been topped up for http www bubbletext com your renewal pin is tgxxrz',
#  'that way transport is less problematic than on sat night by the way if u want to ask n to join my bday feel free but need to know definite no a booking on fri',
#  'usually the person is unconscious that s in child but in adult they may just behave abnormally i ll call you now',
#  'but that s on ebay it might be less elsewhere',
#  'shall i come to get pickle',
#  'were gonna go get some taco',
#  'that s very rude you on campus',
#  'urgent your mobile no wa awarded a bonus caller prize on this is our nd attempt to contact you call box qu',
#  'hi i won t b ard christmas but do enjoy n merry x ma',
#  'today s offer claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub unsub reply x',
#  'yes how is a pretty lady like you single',
#  'you will recieve your tone within the next hr for term and condition please see channel u teletext pg',
#  'jay say that you re a double faggot',
#  'private your account statement for show un redeemed s i m point call identifier code expires',
#  'what today sunday sunday is holiday so no work',
#  'gudnite tc practice going on',
#  'i ll be late',
#  'i ve not called you in a while this is hoping it wa l r malaria and that you know that we miss you guy i miss ban big so pls give her my love especially have a great day',
#  'good afternoon my love how go that day i hope maybe you got some lead on a job i think of you boytoy and send you a passionate kiss from across the sea',
#  'probably gonna be here for a while see you later tonight lt',
#  'or maybe my fat finger just press all these button and it doesn t know what to do',
#  'ummmmmaah many many happy return of d day my dear sweet heart happy birthday dear',
#  'i am in tirupur da once you started from office call me',
#  'from www applausestore com monthlysubscription p msg max month t csc web age stop txt stop',
#  'a famous quote when you develop the ability to listen to anything unconditionally without losing your temper or self confidence it mean you are married',
#  'but am going to college pa what to do are else ill come there it self pa',
#  'oclock at mine just to bash out a flat plan',
#  'this girl doe not stay in bed this girl doesn t need recovery time id rather pas out while having fun then be cooped up in bed',
#  'then any special there',
#  'i know but you need to get hotel now i just got my invitation but i had to apologise cali is to sweet for me to come to some english bloke s weddin',
#  'sorry that took so long omw now',
#  'wait lt gt min',
#  'ok give me minute i think i see her btw you re my alibi you were cutting my hair the whole time',
#  'imagine you finally get to sink into that bath after i have put you through your pace maybe even having you eat me for a while before i left but also imagine the feel of that cage on your cock surrounded by the bath water reminding you always who owns you enjoy my cuck',
#  'hurry up i ve been weed deficient for like three day',
#  'sure if i get an acknowledgement from you that it s astoundingly tactless and generally faggy to demand a blood oath fo',
#  'ok every night take a warm bath drink a cup of milk and you ll see a work of magic you still need to loose weight just so that you know',
#  'i ll have a look at the frying pan in case it s cheap or a book perhaps no that s silly a frying pan isn t likely to be a book',
#  'o well uv cause mutation sunscreen is like essential thesedays',
#  'having lunch you are not in online why',
#  'i know that my friend already told that',
#  'hi princess thank you for the pic you are very pretty how are you',
#  'aiyo u always c our ex one i dunno abt mei she haven reply first time u reply so fast y so lucky not workin huh got bao by ur sugardad ah gee',
#  'hi msg me i m in office',
#  'thanx e brownie it s v nice',
#  'geeeee i love you so much i can barely stand it',
#  'gent we are trying to contact you last weekend draw show that you won a prize guaranteed call claim code k valid hr only ppm',
#  'fuck babe i miss you already you know can t you let me send you some money towards your net i need you i want you i crave you',
#  'ill call u mrw at ninish with my address that icky american freek wont stop callin me bad jen k eh',
#  'oooh bed ridden ey what are you thinking of',
#  'so anyways you can just go to your gym or whatever my love smile i hope your ok and having a good day babe i miss you so much already',
#  'love it daddy will make you scream with pleasure i am going to slap your as with my dick',
#  'wot u wanna do then missy',
#  'yar lor wait my mum finish sch then have lunch lor i whole morning stay at home clean my room now my room quite clean hee',
#  'do you know where my lab goggles went',
#  'can you open the door',
#  'waiting for your call',
#  'nope i waiting in sch daddy',
#  'you have won cash or a prize to claim call',
#  'i m tired of arguing with you about this week after week do what you want and from now on i ll do the same',
#  'wait me in sch i finish ard',
#  'our mobile number ha won to claim call u back or ring the claim hot line on',
#  'arngd marriage is while u r walkin unfortuntly a snake bite u bt love marriage is dancing in frnt of d snake amp sayin bite me bite me',
#  'huh so early then having dinner outside izzit',
#  'ok anyway no need to change with what you said',
#  'we tried to contact you re your reply to our offer of min textand a new video phone call now or reply for free delivery tomorrow',
#  'my ex wife wa not able to have kid do you want kid one day',
#  'so how s scotland hope you are not over showing your jjc tendency take care live the dream',
#  'tell them u have a headache and just want to use hour of sick time',
#  'i dun thk i ll quit yet hmmm can go jazz yogasana oso can we can go meet em after our lesson den',
#  'pete can you please ring meive hardly gotany credit',
#  'ya srsly better than yi tho',
#  'i m in a meeting call me later at',
#  'for ur chance to win a wkly shopping spree txt shop to t s c s www txt shop com custcare x p wk',
#  'you have been specially selected to receive a pound award call before the line close cost ppm t c apply ag promo',
#  'private your account statement for show un redeemed s i m point call identifier code expires',
#  'you still at grand prix',
#  'i met you a a stranger and choose you a my friend a long a the world stand our friendship never end let be friend forever gud nitz',
#  'i am great how are you',
#  'gud mrng dear have a nice day',
#  'you have an important customer service announcement call freephone now',
# ...
#  'i borrow ur bag ok',
#  'u were outbid by simonwatson on the shinco dvd plyr bid again visit sm ac smsrewards end bid notification reply end out',
#  'where s my boytoy i miss you what happened',
#  'he ha lot of used one babe but the model doesn t help youi have to bring it over and he ll match it up',
#  'also are you bringing galileo or dobby',
#  'then why you not responding',
#  'boo babe u enjoyin yourjob u seemed b gettin on well hunny hope ure ok take care i llspeak u soonlots of loveme xxxx',
#  'good afternoon starshine how s my boytoy doe he crave me yet ache to fuck me sip cappuccino i miss you babe teasing kiss',
#  'on the road so cant txt',
#  'smsservices for yourinclusive text credit pls goto www comuk net login qxj unsubscribe with stop no extra charge help comuk cm ae',
#  'p alfie moon s child in need song on ur mob tell ur m s txt tone charity to for nokias or poly charity for polys zed profit charity',
#  'have a good evening ttyl',
#  'hmm bit and piece lol sigh',
#  'hahaha use your brain dear',
#  'hey you got any mail',
#  'sorry light turned green i meant another friend wanted lt gt worth but he may not be around',
#  'thanks for yesterday sir you have been wonderful hope you enjoyed the burial mojibiola',
#  'u have a secret admirer reveal who think u r so special call to opt out reply reveal stop per msg recd cust care',
#  'hi mate it rv did u hav a nice hol just a message say hello coz haven t sent u in age started driving so stay off road rvx',
#  'dear voucher holder to claim this week offer at you pc please go to http www e tlp co uk expressoffer t c apply to stop text txt stop to',
#  'thank you so much when we skyped wit kz and sura we didnt get the pleasure of your company hope you are good we ve given you ultimatum oh we are countin down to aburo enjoy this is the message i sent day ago',
#  'surely result will offer',
#  'good morning my dear have a great amp successful day',
#  'do you want anytime any network min text and a new video phone for only five pound per week call or reply for delivery tomorrow',
#  'sir i have been late in paying rent for the past few month and had to pay a lt gt charge i felt it would be inconsiderate of me to nag about something you give at great cost to yourself and that s why i didnt speak up i however am in a recession and wont be able to pay the charge this month hence my askin well ahead of month s end can you please help thanks',
#  'we tried to contact you re our offer of new video phone anytime any network min half price rental camcorder call or reply for delivery wed',
#  'last chance claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub remove txt x or stop',
#  'i luv u soo much u don t understand how special u r me ring u morrow luv u xxx',
#  'pls send me a comprehensive mail about who i m paying when and how much',
#  'our prashanthettan s mother passed away last night pray for her and family',
#  'urgent call from your landline your complimentary ibiza holiday or cash await collection sae t c po box sk wp ppm',
#  'k k when are you going',
#  'meanwhile in the shit suite xavier decided to give u lt gt second of warning that samantha wa coming over and is playing jay s guitar to impress her or some shit also i don t think doug realizes i don t live here anymore',
#  'my stomach ha been thru so much trauma i swear i just can t eat i better lose weight',
#  'i am in office whats the matter msg me now i will call you at break',
#  'yeah there s barely enough room for the two of u x ha too many fucking shoe sorry man see you later',
#  'today s offer claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub unsub reply x',
#  'u reach orchard already u wan go buy ticket first',
#  'i am real baby i want to bring out your inner tigress',
#  'no da if you run that it activate the full version da',
#  'ah poor baby hope urfeeling bettersn luv probthat overdose of work hey go careful spk u sn lot of lovejen xxx',
#  'stop the story i ve told him i ve returned it and he s saying i should not re order it',
#  'talk sexy make new friend or fall in love in the world most discreet text dating service just text vip to and see who you could meet',
#  'going to take your babe out',
#  'hai ana tomarrow am coming on morning lt decimal gt ill be there in sathy then we ll go to rto office reply me after came to home',
#  'spoon it is then okay',
#  'did he just say somebody is named tampa',
#  'in work now going have in few min',
#  'your brother is a genius',
#  'sorry i guess whenever i can get a hold of my connection maybe an hour or two i ll text you',
#  'did u find out what time the bus is at coz i need to sort some stuff out',
#  'dude ive been seeing a lotta corvette lately',
#  'congratulation ur awarded either a yr supply of cd from virgin record or a mystery gift guaranteed call t c www smsco net pm approx min',
#  'same here but i consider wall and bunker and shit important just because i never play on peaceful but i guess your place is high enough that it don t matter',
#  'private your account statement for xxxxxx show un redeemed s i m point call identifier code expires',
#  'hello we need some posh bird and chap to user trial prod for champneys can i put you down i need your address and dob asap ta r',
#  'what do u want for xmas how about free text message a new video phone with half price line rental call free now on to find out more',
#  'well am officially in a philosophical hole so if u wanna call am at home ready to be saved',
#  'it going good no problem but still need little experience to understand american customer voice',
#  'i ll text you when i drop x off',
#  'ugh it been a long day i m exhausted just want to cuddle up and take a nap',
#  'talk with yourself atleast once in a day otherwise you will miss your best friend in this world shakespeare shesil lt gt',
#  'shop till u drop is it you either k k cash or travel voucher call now ntt po box cr bt fixedline cost ppm mobile vary',
#  'are you in castor you need to see something',
#  'sunshine quiz wkly q win a top sony dvd player if u know which country liverpool played in mid week txt ansr to sp tyrone',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on stopsms',
#  'reminder you have not downloaded the content you have already paid for goto http doit mymoby tv to collect your content',
#  'see i knew giving you a break a few time woul lead to you always wanting to miss curfew i wa gonna gibe you til one but a midnight movie is not gonna get out til after you need to come home you need to getsleep and if anything you need to b studdying ear training',
#  'i love to give massage i use lot of baby oil what is your fave position',
#  'dude we should go sup again',
#  'yoyyooo u know how to change permission for a drive in mac my usb flash drive',
#  'gibbs unsold mike hussey',
#  'i like to talk pa but am not able to i dont know y',
#  'y dun cut too short leh u dun like ah she failed she s quite sad',
#  'you unbelievable faglord',
#  'wife how she knew the time of murder exactly',
#  'why do you ask princess',
#  'i am great princess what are you thinking about me',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie you',
#  'it s ok i noe u re busy but i m really too bored so i msg u i oso dunno wat colour she choose me one',
#  'doesn t g have class early tomorrow and thus shouldn t be trying to smoke at lt gt',
#  'superb thought be grateful that u dont have everything u want that mean u still have an opportunity to be happier tomorrow than u are today',
#  'hope you are having a good week just checking in',
#  'i m used to it i just hope my agent don t drop me since i ve only booked a few thing this year this whole me in boston them in nyc wa an experiment',
#  'thursday night yeah sure thing we ll work it out then',
#  'your free ringtone is waiting to be collected simply text the password mix to to verify get usher and britney fml po box mk h ppw',
#  'probably money worry thing are coming due and i have several outstanding invoice for work i did two and three month ago',
#  'how is it possible to teach you and where',
#  'i wonder if your phone battery went dead i had to tell you i love you babe',
#  'lovely smell on this bus and it ain t tobacco',
#  'we re all getting worried over here derek and taylor have already assumed the worst',
#  'hey what s up charles sorry about the late reply',
#  'all the lastest from stereophonics marley dizzee racal libertine and the stroke win nookii game with flirt click themob wap bookmark or text wap to',
#  'i ll give her once i have it plus she said grinule greet you whenever we speak',
#  'white fudge oreo are in store',
#  'january male sale hot gay chat now cheaper call national rate from p min cheap to p min peak to stop text call p min',
#  'my love how come it took you so long to leave for zaher s i got your word on ym and wa happy to see them but wa sad you had left i miss you',
#  'i am sorry it hurt you',
#  'can t i feel nauseous i m so pissed i didn t eat any sweet all week cause today i wa planning to pig out i wa dieting all week and now i m not hungry',
#  'ok lor but not too early me still having project meeting now',
#  'call me da i am waiting for your call',
#  'i could ask carlos if we could get more if anybody else can chip in',
#  'wa actually about to send you a reminder today have a wonderful weekend',
#  'when people see my msg they think iam addicted to msging they are wrong bcoz they don t know that iam addicted to my sweet friend bslvyl',
#  'hey you gave them your photo when you registered for driving ah tmr wanna meet at yck',
#  'dont talk to him ever ok it my word',
#  'when u wana see it then',
#  'on ma way to school can you pls send me ashley s number',
#  'it shall be fine i have avalarr now will hollalater',
#  'she went to attend another two round today but still did t reach home',
#  'actually i deleted my old website now i m blogging at magicalsongs blogspot com',
#  'k wait chikku il send aftr lt gt min',
#  'but i m on a diet and i ate too many slice of pizza yesterday ugh i m always on a diet',
#  'k i will give my kvb acc detail',
#  'oh all have to come ah',
#  'money you r a lucky winner claim your prize text money over million to give away ppt x normal text rate box w t jy',
#  'i m really sorry i won t b able do this friday hope u can find an alternative hope yr term s going ok',
#  'congratulation ore mo owo re wa enjoy it and i wish you many happy moment to and fro wherever you go',
#  'so do you have samus shoulder yet',
#  'what time you think you ll have it need to know when i should be near campus',
#  'dear matthew please call from a landline your complimentary lux tenerife holiday or cash await collection ppm sae t c box sk xh',
#  'then dun wear jean lor',
#  'since when which side any fever any vomitin',
#  'k k are you in college',
#  'urgent call from landline your complimentary tenerife holiday or cash await collection sae t c box hp yf ppm',
#  'better made up for friday and stuffed myself like a pig yesterday now i feel bleh but at least it not writhing pain kind of bleh',
#  'no we sell it all so we ll have ton if coin then sell our coin to someone thru paypal voila money back in life pocket',
#  'theyre doing it to lot of place only hospital and medical place are safe',
#  'how about getting in touch with folk waiting for company just txt back your name and age to opt in enjoy the community p sm',
#  'and also i ve sorta blown him off a couple time recently so id rather not text him out of the blue looking for weed',
#  'i sent my score to sophas and i had to do secondary application for a few school i think if you are thinking of applying do a research on cost also contact joke ogunrinde her school is one me the less expensive one',
#  'i cant wait to see you how were the photo were useful',
#  'ur cash balance is currently pound to maximize ur cash in now send go to only p msg cc po box tcr w',
#  'hey i booked the kb on sat already what other lesson are we going for ah keep your sat night free we need to meet and confirm our lodging',
#  'chk in ur belovd m dict',
#  'is that what time you want me to come',
#  'awesome lemme know whenever you re around',
#  'shb b ok lor thanx',
#  'beautiful truth against gravity read carefully our heart feel light when someone is in it but it feel very heavy when someone leaf it good night',
#  'also remember to get dobby s bowl from your car',
#  'filthy story and girl waiting for your',
#  'sorry i now then c ur msg yar lor so poor thing but only one night tmr u ll have a brand new room sleep in',
#  'love isn t a decision it s a feeling if we could decide who to love then life would be much simpler but then less magical',
#  'welp apparently he retired',
#  'my sort code is and acc no is the bank is natwest can you reply to confirm i ve sent this to the right person',
#  'where',
#  'u sure u can t take any sick time',
#  'urgent we are trying to contact u today draw show that you have won a prize guaranteed call from land line claim m valid hr only',
#  'watching cartoon listening music amp at eve had to go temple amp church what about u',
#  'yo chad which gymnastics class do you wanna take the site say christian class is full',
#  'are you this much buzy',
#  'or better still can you catch her and let ask her if she can sell lt gt for me',
#  'i am not sure about night menu i know only about noon menu',
#  'what do u want when i come back a beautiful necklace a a token of my heart for you thats what i will give but only to my wife of my liking be that and see no one can give you that dont call me i will wait till i come',
#  'are you willing to go for aptitude class',
#  'it wont b until a trying sort house out is that ok',
#  'yar lor he wan go c horse racing today mah so eat earlier lor i ate chicken rice u',
#  'haha awesome omw back now then',
#  'yup i thk so until e shop close lor',
#  'what is your account number',
#  'eh u send wrongly lar',
#  'hey no i ad a crap nite wa borin without ya boggy with me u boring biatch thanx but u wait til nxt time il ave ya',
#  'ok i shall talk to him',
#  'dont hesitate you know this is the second time she ha had weakness like that so keep i notebook of what she eat and did the day before or if anything changed the day before so that we can be sure it nothing',
#  'hey you can pay with salary de only lt gt',
#  'another month i need chocolate weed and alcohol',
#  'if he started searching he will get job in few day he have great potential and talent',
#  'reckon need to be in town by eightish to walk from carpark',
#  'congrats mobile g videophones r yours call now videochat wid your mate play java game dload polyph music noline rentl',
#  'look at the fuckin time what the fuck you think is up',
#  'yo guess what i just dropped',
#  'carlos say he ll be at mu in lt gt minute',
#  'i m in office now i will call you lt gt min',
#  'geeee i miss you already you know your all i can think about fuck i can t wait till next year when we will be together loving kiss',
#  'yun ah the ubi one say if wan call by tomorrow call look for irene ere only got bus ubi cres ubi tech park ph for st wkg day n',
#  'ugh gotta drive back to sd from la my butt is sore',
#  'th of july',
#  'hi im having the most relaxing time ever we have to get up at am every day wa the party good the other night i get home tomorrow at ish',
#  'up to wan come then come lor but i din c any stripe skirt',
#  'the xmas story is peace the xmas msg is love the xmas miracle is jesus hav a blessed month ahead amp wish u merry xmas',
#  'i can t i don t have her number',
#  'change again it s e one next to escalator',
#  'yetunde i m in class can you not run water on it to make it ok pls now',
#  'not a lot ha happened here feel very quiet beth is at her aunt and charlie is working lot just me and helen in at the mo how have you been',
#  'then wait me at bus stop aft ur lect lar if i dun c then i go get my car then come back n pick',
#  ...]

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
words=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'don',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'to',
#   'send',
#   'to',
#   'rcv'],
#  ['even',
#   'my',
#   'brother',
#   'is',
#   'not',
#   'like',
#   'to',
#   'speak',
#   'with',
#   'me',
#   'they',
#   'treat',
#   'me',
#   'like',
#   'aid',
#   'patent'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'you',
#   'have',
#   'been',
#   'selected',
#   'to',
#   'receivea',
#   'prize',
#   'reward',
#   'to',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour',
#   'only'],
#  ['had',
#   'your',
#   'mobile',
#   'month',
#   'or',
#   'more',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'mobile',
#   'with',
#   'camera',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['gonna',
#   'be',
#   'home',
#   'soon',
#   'and',
#   'don',
#   'want',
#   'to',
#   'talk',
#   'about',
#   'this',
#   'stuff',
#   'anymore',
#   'tonight',
#   've',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'to',
#   'win',
#   'cash',
#   'from',
#   'to',
#   'pound',
#   'txt',
#   'csh',
#   'and',
#   'send',
#   'to',
#   'cost',
#   'day',
#   'day',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'you',
#   'have',
#   'won',
#   'week',
#   'free',
#   'membership',
#   'in',
#   'our',
#   'prize',
#   'jackpot',
#   'txt',
#   'the',
#   'word',
#   'claim',
#   'to',
#   'no',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['ve',
#   'been',
#   'searching',
#   'for',
#   'the',
#   'right',
#   'word',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'your',
#   'help',
#   'for',
#   'granted',
#   'and',
#   'will',
#   'fulfil',
#   'my',
#   'promise',
#   'you',
#   'have',
#   'been',
#   'wonderful',
#   'and',
#   'blessing',
#   'at',
#   'all',
#   'time'],
#  ['have', 'date', 'on', 'sunday', 'with', 'will'],
#  ['to',
#   'use',
#   'your',
#   'credit',
#   'click',
#   'the',
#   'wap',
#   'link',
#   'in',
#   'the',
#   'next',
#   'txt',
#   'message',
#   'or',
#   'click',
#   'here',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching', 'here'],
#  ['eh',
#   'remember',
#   'how',
#   'spell',
#   'his',
#   'name',
#   'yes',
#   'did',
#   'he',
#   'naughty',
#   'make',
#   'until',
#   'wet'],
#  ['fine',
#   'if',
#   'that',
#   'the',
#   'way',
#   'feel',
#   'that',
#   'the',
#   'way',
#   'it',
#   'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'the',
#   'goal',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'to',
#   'eg',
#   'england',
#   'to',
#   'try',
#   'wale',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name'],
#  ['going', 'to', 'try', 'for', 'month', 'ha', 'ha', 'only', 'joking'],
#  ['so', 'pay', 'first', 'lar', 'then', 'when', 'is', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'my',
#   'lunch',
#   'then',
#   'go',
#   'str',
#   'down',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff',
#   'alright',
#   'no',
#   'way',
#   'can',
#   'meet',
#   'up',
#   'with',
#   'you',
#   'sooner'],
#  ['just',
#   'forced',
#   'myself',
#   'to',
#   'eat',
#   'slice',
#   'really',
#   'not',
#   'hungry',
#   'tho',
#   'this',
#   'suck',
#   'mark',
#   'is',
#   'getting',
#   'worried',
#   'he',
#   'know',
#   'sick',
#   'when',
#   'turn',
#   'down',
#   'pizza',
#   'lol'],
#  ['lol', 'your', 'always', 'so', 'convincing'],
#  ['did',
#   'you',
#   'catch',
#   'the',
#   'bus',
#   'are',
#   'you',
#   'frying',
#   'an',
#   'egg',
#   'did',
#   'you',
#   'make',
#   'tea',
#   'are',
#   'you',
#   'eating',
#   'your',
#   'mom',
#   'left',
#   'over',
#   'dinner',
#   'do',
#   'you',
#   'feel',
#   'my',
#   'love'],
#  ['back',
#   'amp',
#   'we',
#   're',
#   'packing',
#   'the',
#   'car',
#   'now',
#   'll',
#   'let',
#   'you',
#   'know',
#   'if',
#   'there',
#   'room'],
#  ['ahhh',
#   'work',
#   'vaguely',
#   'remember',
#   'that',
#   'what',
#   'doe',
#   'it',
#   'feel',
#   'like',
#   'lol'],
#  ['wait',
#   'that',
#   'still',
#   'not',
#   'all',
#   'that',
#   'clear',
#   'were',
#   'you',
#   'not',
#   'sure',
#   'about',
#   'me',
#   'being',
#   'sarcastic',
#   'or',
#   'that',
#   'that',
#   'why',
#   'doesn',
#   'want',
#   'to',
#   'live',
#   'with'],
#  ['yeah',
#   'he',
#   'got',
#   'in',
#   'at',
#   'and',
#   'wa',
#   'apologetic',
#   'had',
#   'fallen',
#   'out',
#   'and',
#   'she',
#   'wa',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'and',
#   'he',
#   'got',
#   'caught',
#   'up',
#   'in',
#   'that',
#   'till',
#   'but',
#   'we',
#   'won',
#   'go',
#   'there',
#   'not',
#   'doing',
#   'too',
#   'badly',
#   'cheer',
#   'you'],
#  ['tell', 'me', 'anything', 'about', 'you'],
#  ['for',
#   'fear',
#   'of',
#   'fainting',
#   'with',
#   'the',
#   'of',
#   'all',
#   'that',
#   'housework',
#   'you',
#   'just',
#   'did',
#   'quick',
#   'have',
#   'cuppa'],
#  ['thanks',
#   'for',
#   'your',
#   'subscription',
#   'to',
#   'ringtone',
#   'uk',
#   'your',
#   'mobile',
#   'will',
#   'be',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'by',
#   'replying',
#   'yes',
#   'or',
#   'no',
#   'if',
#   'you',
#   'reply',
#   'no',
#   'you',
#   'will',
#   'not',
#   'be',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'at',
#   'the',
#   'timing',
#   'then',
#   'msg',
#   'again',
#   'xuhui',
#   'going',
#   'to',
#   'learn',
#   'on',
#   'nd',
#   'may',
#   'too',
#   'but',
#   'her',
#   'lesson',
#   'is',
#   'at',
#   'am'],
#  ['oops', 'll', 'let', 'you', 'know', 'when', 'my', 'roommate', 'done'],
#  ['see', 'the', 'letter', 'on', 'my', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello',
#   'how',
#   'you',
#   'and',
#   'how',
#   'did',
#   'saturday',
#   'go',
#   'wa',
#   'just',
#   'texting',
#   'to',
#   'see',
#   'if',
#   'you',
#   'decided',
#   'to',
#   'do',
#   'anything',
#   'tomo',
#   'not',
#   'that',
#   'trying',
#   'to',
#   'invite',
#   'myself',
#   'or',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'with',
#   'watt',
#   'just',
#   'wanted',
#   'to',
#   'be',
#   'sure',
#   'do',
#   'have',
#   'great',
#   'weekend',
#   'abiola'],
#  ['did',
#   'forget',
#   'to',
#   'tell',
#   'you',
#   'want',
#   'you',
#   'need',
#   'you',
#   'crave',
#   'you',
#   'but',
#   'most',
#   'of',
#   'all',
#   'love',
#   'you',
#   'my',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'we',
#   'tried',
#   'to',
#   'call',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'sm',
#   'for',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'now',
#   'for',
#   'delivery',
#   'tomorrow'],
#  ['who', 'are', 'you', 'seeing'],
#  ['great',
#   'hope',
#   'you',
#   'like',
#   'your',
#   'man',
#   'well',
#   'endowed',
#   'am',
#   'lt',
#   'gt',
#   'inch'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['didn', 'you', 'get', 'hep', 'immunisation', 'in', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going', 'on'],
#  ['yeah',
#   'hopefully',
#   'if',
#   'tyler',
#   'can',
#   'do',
#   'it',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['don',
#   'know',
#   'how',
#   'stubborn',
#   'am',
#   'didn',
#   'even',
#   'want',
#   'to',
#   'go',
#   'to',
#   'the',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'not',
#   'weak',
#   'sucker',
#   'hospital',
#   'are',
#   'for',
#   'weak',
#   'sucker'],
#  ['what',
#   'you',
#   'thinked',
#   'about',
#   'me',
#   'first',
#   'time',
#   'you',
#   'saw',
#   'me',
#   'in',
#   'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'is',
#   'smarter',
#   'though',
#   'and',
#   'get',
#   'you',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'for',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ha',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'but',
#   'he',
#   'crashing',
#   'at',
#   'our',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'that',
#   'you',
#   'were',
#   'so',
#   'embarassed',
#   'by',
#   'your',
#   'accomodations',
#   'thought',
#   'you',
#   'liked',
#   'it',
#   'since',
#   'wa',
#   'doing',
#   'the',
#   'best',
#   'could',
#   'and',
#   'you',
#   'always',
#   'seemed',
#   'so',
#   'happy',
#   'about',
#   'the',
#   'cave',
#   'sorry',
#   'didn',
#   'and',
#   'don',
#   'have',
#   'more',
#   'to',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'your',
#   'room',
#   'wa',
#   'so',
#   'embarassing'],
#  ['sm',
#   'ac',
#   'sptv',
#   'the',
#   'new',
#   'jersey',
#   'devil',
#   'and',
#   'the',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'or',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['do',
#   'you',
#   'know',
#   'what',
#   'mallika',
#   'sherawat',
#   'did',
#   'yesterday',
#   'find',
#   'out',
#   'now',
#   'lt',
#   'url',
#   'gt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'for',
#   'is',
#   'yours',
#   'call',
#   'now',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'all',
#   'free',
#   'bx',
#   'ip',
#   'we',
#   'pm',
#   'dont',
#   'miss',
#   'out'],
#  ['sorry', 'll', 'call', 'later', 'in', 'meeting'],
#  ['tell', 'where', 'you', 'reached'],
#  ['yes', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series'],
#  ['your',
#   'gonna',
#   'have',
#   'to',
#   'pick',
#   'up',
#   'burger',
#   'for',
#   'yourself',
#   'on',
#   'your',
#   'way',
#   'home',
#   'can',
#   'even',
#   'move',
#   'pain',
#   'is',
#   'killing',
#   'me'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'are', 'situation', 'seeker'],
#  ['it', 'part', 'of', 'checking', 'iq'],
#  ['sorry',
#   'my',
#   'roommate',
#   'took',
#   'forever',
#   'it',
#   'ok',
#   'if',
#   'come',
#   'by',
#   'now'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'he',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'he',
#   'said',
#   'will',
#   'cut',
#   'until',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'am',
#   'pleased',
#   'to',
#   'advise',
#   'you',
#   'that',
#   'following',
#   'recent',
#   'review',
#   'of',
#   'your',
#   'mob',
#   'no',
#   'you',
#   'are',
#   'awarded',
#   'with',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'is',
#   'song',
#   'dedicated',
#   'day',
#   'which',
#   'song',
#   'will',
#   'dedicate',
#   'for',
#   'me',
#   'send',
#   'this',
#   'to',
#   'all',
#   'ur',
#   'valuable',
#   'frnds',
#   'but',
#   'first',
#   'rply',
#   'me'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'to',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'or',
#   'to',
#   'claim',
#   'txt',
#   'dis',
#   'to',
#   'morefrmmob',
#   'aj'],
#  ['did',
#   'you',
#   'hear',
#   'about',
#   'the',
#   'new',
#   'divorce',
#   'barbie',
#   'it',
#   'come',
#   'with',
#   'all',
#   'of',
#   'ken',
#   'stuff'],
#  ['plane', 'to', 'give', 'on', 'this', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'then', 'can', 'save', 'money', 'hee'],
#  ['finished', 'class', 'where', 'are', 'you'],
#  ['hi', 'babe', 'im', 'at', 'home', 'now', 'wanna', 'do', 'something', 'xx'],
#  ['where', 'are', 'you', 'how', 'did', 'you', 'performed'],
#  ['can', 'call', 'me', 'now'],
#  ['am', 'waiting', 'machan', 'call', 'me', 'once', 'you', 'free'],
#  ['thats',
#   'cool',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['like', 'you', 'people', 'very', 'much', 'but', 'am', 'very', 'shy', 'pa'],
#  ['doe', 'not', 'operate', 'after', 'lt', 'gt', 'or', 'what'],
#  ['it',
#   'not',
#   'the',
#   'same',
#   'here',
#   'still',
#   'looking',
#   'for',
#   'job',
#   'how',
#   'much',
#   'do',
#   'ta',
#   'earn',
#   'there'],
#  ['sorry', 'll', 'call', 'later'],
#  ['did', 'you', 'call', 'me', 'just', 'now', 'ah'],
#  ['ok', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi'],
#  ['you', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'you', 'later', 'don', 'have', 'network', 'if', 'urgnt', 'sm', 'me'],
#  ['for',
#   'real',
#   'when',
#   'getting',
#   'on',
#   'yo',
#   'only',
#   'need',
#   'more',
#   'ticket',
#   'and',
#   'one',
#   'more',
#   'jacket',
#   'and',
#   'done',
#   'already',
#   'used',
#   'all',
#   'my',
#   'multis'],
#  ['yes',
#   'started',
#   'to',
#   'send',
#   'request',
#   'to',
#   'make',
#   'it',
#   'but',
#   'pain',
#   'came',
#   'back',
#   'so',
#   'back',
#   'in',
#   'bed',
#   'double',
#   'coin',
#   'at',
#   'the',
#   'factory',
#   'too',
#   'gotta',
#   'cash',
#   'in',
#   'all',
#   'my',
#   'nitros'],
#  ['really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah',
#   'do',
#   'don',
#   'stand',
#   'to',
#   'close',
#   'tho',
#   'you',
#   'll',
#   'catch',
#   'something'],
#  ['sorry',
#   'to',
#   'be',
#   'pain',
#   'is',
#   'it',
#   'ok',
#   'if',
#   'we',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'in',
#   'casualty',
#   'and',
#   'that',
#   'mean',
#   'haven',
#   'done',
#   'any',
#   'of',
#   'stuff',
#   'moro',
#   'and',
#   'that',
#   'includes',
#   'all',
#   'my',
#   'time',
#   'sheet',
#   'and',
#   'that',
#   'sorry'],
#  ['smile',
#   'in',
#   'pleasure',
#   'smile',
#   'in',
#   'pain',
#   'smile',
#   'when',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'when',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'to',
#   'see',
#   'smiling'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['havent',
#   'planning',
#   'to',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'only',
#   'got',
#   'show',
#   'in',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see',
#   'when',
#   'we',
#   'finish',
#   'we',
#   'have',
#   'load',
#   'of',
#   'loan',
#   'to',
#   'pay'],
#  ['hi',
#   'wk',
#   'been',
#   'ok',
#   'on',
#   'hols',
#   'now',
#   'yes',
#   'on',
#   'for',
#   'bit',
#   'of',
#   'run',
#   'forgot',
#   'that',
#   'have',
#   'hairdresser',
#   'appointment',
#   'at',
#   'four',
#   'so',
#   'need',
#   'to',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'doe',
#   'that',
#   'cause',
#   'prob',
#   'for'],
#  ['see', 'cup', 'of', 'coffee', 'animation'],
#  ['please',
#   'don',
#   'text',
#   'me',
#   'anymore',
#   'have',
#   'nothing',
#   'else',
#   'to',
#   'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'it',
#   'legal',
#   'wen',
#   'can',
#   'pick',
#   'them',
#   'up',
#   'ave',
#   'am',
#   'xx'],
#  ['still',
#   'looking',
#   'for',
#   'car',
#   'to',
#   'buy',
#   'and',
#   'have',
#   'not',
#   'gone',
#   'the',
#   'driving',
#   'test',
#   'yet'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['wow',
#   'you',
#   're',
#   'right',
#   'didn',
#   'mean',
#   'to',
#   'do',
#   'that',
#   'guess',
#   'once',
#   'gave',
#   'up',
#   'on',
#   'boston',
#   'men',
#   'and',
#   'changed',
#   'my',
#   'search',
#   'location',
#   'to',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'on',
#   'my',
#   'signin',
#   'page',
#   'it',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'for',
#   'your',
#   'wish',
#   'on',
#   'my',
#   'birthday',
#   'thanks',
#   'you',
#   'for',
#   'making',
#   'my',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'll', 'hit', 'you', 'up', 'when', 'get', 'some', 'cash'],
#  ['how',
#   'would',
#   'my',
#   'ip',
#   'address',
#   'test',
#   'that',
#   'considering',
#   'my',
#   'computer',
#   'isn',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'my',
#   'mom',
#   'wa',
#   'like',
#   'you',
#   'better',
#   'not',
#   'be',
#   'lying',
#   'then',
#   'again',
#   'am',
#   'always',
#   'the',
#   'one',
#   'to',
#   'play',
#   'joke'],
#  ['dont', 'worry', 'guess', 'he', 'busy'],
#  ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research'],
#  ['going', 'for', 'dinner', 'msg', 'you', 'after'],
#  ['ok',
#   'wif',
#   'it',
#   'co',
#   'like',
#   'try',
#   'new',
#   'thing',
#   'but',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'not',
#   'too',
#   'loud'],
#  ['gent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'very',
#   'formal',
#   'anyway',
#   'fine',
#   'too',
#   'juz',
#   'tt',
#   'eatin',
#   'too',
#   'much',
#   'puttin',
#   'on',
#   'weight',
#   'haha',
#   'so',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo',
#   'yes',
#   'we',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'for',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'my',
#   'uncle',
#   'just',
#   'informed',
#   'me',
#   'that',
#   'he',
#   'paying',
#   'the',
#   'school',
#   'directly',
#   'so',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'show',
#   'unredeemed',
#   'bonus',
#   'point',
#   'to',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'your',
#   'mobile',
#   'no',
#   'wa',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'on',
#   'this',
#   'is',
#   'our',
#   'final',
#   'try',
#   'to',
#   'contact',
#   'call',
#   'from',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['here',
#   'is',
#   'my',
#   'new',
#   'address',
#   'apple',
#   'pair',
#   'all',
#   'that',
#   'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'award',
#   'if',
#   'you',
#   'have',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['am',
#   'going',
#   'to',
#   'sao',
#   'mu',
#   'today',
#   'will',
#   'be',
#   'done',
#   'only',
#   'at'],
#  ['predict', 'wat', 'time', 'll', 'finish', 'buying'],
#  ['good', 'stuff', 'will', 'do'],
#  ['just',
#   'so',
#   'that',
#   'you',
#   'know',
#   'yetunde',
#   'hasn',
#   'sent',
#   'money',
#   'yet',
#   'just',
#   'sent',
#   'her',
#   'text',
#   'not',
#   'to',
#   'bother',
#   'sending',
#   'so',
#   'it',
#   'over',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'involve',
#   'yourself',
#   'in',
#   'anything',
#   'shouldn',
#   'have',
#   'imposed',
#   'anything',
#   'on',
#   'you',
#   'in',
#   'the',
#   'first',
#   'place',
#   'so',
#   'for',
#   'that',
#   'apologise'],
#  ['are', 'you', 'there', 'in', 'room'],
#  ['hey',
#   'girl',
#   'how',
#   'hope',
#   'well',
#   'me',
#   'an',
#   'del',
#   'bak',
#   'again',
#   'long',
#   'time',
#   'no',
#   'give',
#   'me',
#   'call',
#   'sum',
#   'time',
#   'from',
#   'lucyxx'],
#  ['how', 'much', 'doe', 'it', 'cost'],
#  ['home'],
#  ['dear', 'will', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'my', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'if',
#   'know',
#   'which',
#   'country',
#   'the',
#   'algarve',
#   'is',
#   'in',
#   'txt',
#   'ansr',
#   'to',
#   'sp',
#   'tyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'the',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'to',
#   'nt',
#   'ec',
#   'msg'],
#  ['only', 'haf', 'msn', 'it', 'yijue', 'hotmail', 'com'],
#  ['he', 'is', 'there', 'you', 'call', 'and', 'meet', 'him'],
#  ['no', 'no', 'will', 'check', 'all', 'room', 'befor', 'activity'],
#  ['you',
#   'll',
#   'not',
#   'rcv',
#   'any',
#   'more',
#   'msg',
#   'from',
#   'the',
#   'chat',
#   'svc',
#   'for',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'to',
#   'if',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'with',
#   'yr',
#   'network',
#   'try',
#   'again'],
#  ['got',
#   'lazy',
#   'to',
#   'type',
#   'forgot',
#   'in',
#   'lect',
#   'saw',
#   'pouch',
#   'but',
#   'like',
#   'not',
#   'nice'],
#  ['text', 'me', 'when', 'you', 're', 'on', 'the', 'way'],
#  ['sir', 'waiting', 'for', 'your', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'of',
#   'doing',
#   'little',
#   'thing',
#   'lovable',
#   'person',
#   'coz',
#   'somtimes',
#   'those',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'in',
#   'their',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'you', 'are', 'can', 'you', 'pls', 'open', 'the', 'back'],
#  ['yes', 'see', 'ya', 'not', 'on', 'the', 'dot'],
#  ['whats', 'the', 'staff', 'name', 'who', 'is', 'taking', 'class', 'for'],
#  ['freemsg',
#   'why',
#   'haven',
#   'you',
#   'replied',
#   'to',
#   'my',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'and',
#   'live',
#   'local',
#   'luv',
#   'to',
#   'hear',
#   'from',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'to',
#   'end'],
#  ['ummma',
#   'will',
#   'call',
#   'after',
#   'check',
#   'in',
#   'our',
#   'life',
#   'will',
#   'begin',
#   'from',
#   'qatar',
#   'so',
#   'pls',
#   'pray',
#   'very',
#   'hard'],
#  ['deleted', 'my', 'contact', 'that', 'why'],
#  ['sindu', 'got', 'job', 'in', 'birla', 'soft'],
#  ['the', 'wine', 'is', 'flowing', 'and', 'have', 'nevering'],
#  ['yup',
#   'thk',
#   'cine',
#   'is',
#   'better',
#   'co',
#   'no',
#   'need',
#   'go',
#   'down',
#   'plaza',
#   'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['you',
#   'are',
#   'everywhere',
#   'dirt',
#   'on',
#   'the',
#   'floor',
#   'the',
#   'window',
#   'even',
#   'on',
#   'my',
#   'shirt',
#   'and',
#   'sometimes',
#   'when',
#   'open',
#   'my',
#   'mouth',
#   'you',
#   'are',
#   'all',
#   'that',
#   'come',
#   'flowing',
#   'out',
#   'dream',
#   'of',
#   'my',
#   'world',
#   'without',
#   'you',
#   'then',
#   'half',
#   'my',
#   'chore',
#   'are',
#   'out',
#   'too',
#   'time',
#   'of',
#   'joy',
#   'for',
#   'me',
#   'lot',
#   'of',
#   'tv',
#   'show',
#   'll',
#   'see',
#   'but',
#   'guess',
#   'like',
#   'all',
#   'thing',
#   'you',
#   'just',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'and',
#   'mist',
#   'and',
#   'when',
#   'my',
#   'time',
#   'here',
#   'is',
#   'done',
#   'you',
#   'and',
#   'become',
#   'one'],
#  ['aaooooright', 'are', 'you', 'at', 'work'],
#  ['leaving', 'my', 'house', 'now'],
#  ['hello',
#   'my',
#   'love',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'did',
#   'you',
#   'get',
#   'to',
#   'that',
#   'interview',
#   'today',
#   'are',
#   'you',
#   'you',
#   'happy',
#   'are',
#   'you',
#   'being',
#   'good',
#   'boy',
#   'do',
#   'you',
#   'think',
#   'of',
#   'me',
#   'are',
#   'you',
#   'missing',
#   'me'],
#  ['customer',
#   'service',
#   'annoncement',
#   'you',
#   'have',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'for',
#   'you',
#   'please',
#   'call',
#   'now',
#   'to',
#   'arrange',
#   'delivery'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'yourself',
#   'safe',
#   'for',
#   'me',
#   'because',
#   'need',
#   'you',
#   'and',
#   'miss',
#   'you',
#   'already',
#   'and',
#   'envy',
#   'everyone',
#   'that',
#   'see',
#   'you',
#   'in',
#   'real',
#   'life'],
#  ['new',
#   'car',
#   'and',
#   'house',
#   'for',
#   'my',
#   'parent',
#   'have',
#   'only',
#   'new',
#   'job',
#   'in',
#   'hand'],
#  ['so',
#   'in',
#   'love',
#   'with',
#   'you',
#   'excited',
#   'each',
#   'day',
#   'spend',
#   'with',
#   'you',
#   'you',
#   'make',
#   'me',
#   'so',
#   'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'is',
#   'inviting',
#   'you',
#   'to',
#   'be',
#   'her',
#   'friend',
#   'reply',
#   'yes',
#   'or',
#   'no',
#   'see',
#   'her',
#   'www',
#   'sm',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd',
#   'to'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'is',
#   'on',
#   'the',
#   'way',
#   'should',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'if',
#   'do',
#   'not',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'on',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'all', 'ur', 'point', 'on', 'culture', 'module', 'already'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only'],
#  ['hi',
#   'frnd',
#   'which',
#   'is',
#   'best',
#   'way',
#   'to',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'our',
#   'beloved',
#   'one'],
#  ['great',
#   'escape',
#   'fancy',
#   'the',
#   'bridge',
#   'but',
#   'need',
#   'her',
#   'lager',
#   'see',
#   'you',
#   'tomo'],
#  ['yes',
#   'it',
#   'completely',
#   'in',
#   'out',
#   'of',
#   'form',
#   'clark',
#   'also',
#   'utter',
#   'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'no', 'and', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'to',
#   'hop',
#   'ard',
#   'ya',
#   'can',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'to',
#   'discus',
#   'liao'],
#  ['what', 'time', 'you', 'coming', 'down', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'you',
#   'forgot',
#   'my',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'it',
#   'spanish',
#   'and',
#   'begin',
#   'with'],
#  ['well',
#   'gonna',
#   'finish',
#   'my',
#   'bath',
#   'now',
#   'have',
#   'good',
#   'fine',
#   'night'],
#  ['let',
#   'me',
#   'know',
#   'when',
#   'you',
#   've',
#   'got',
#   'the',
#   'money',
#   'so',
#   'carlos',
#   'can',
#   'make',
#   'the',
#   'call'],
#  ['still', 'going', 'to', 'the', 'mall'],
#  ['turn',
#   'out',
#   'my',
#   'friend',
#   'are',
#   'staying',
#   'for',
#   'the',
#   'whole',
#   'show',
#   'and',
#   'won',
#   'be',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'so',
#   'feel',
#   'free',
#   'to',
#   'go',
#   'ahead',
#   'and',
#   'smoke',
#   'that',
#   'lt',
#   'gt',
#   'worth'],
#  ['text',
#   'her',
#   'if',
#   'she',
#   'doesnt',
#   'reply',
#   'let',
#   'me',
#   'know',
#   'so',
#   'can',
#   'have',
#   'her',
#   'log',
#   'in'],
#  ['hi',
#   'you',
#   'just',
#   'spoke',
#   'to',
#   'maneesha',
#   'we',
#   'like',
#   'to',
#   'know',
#   'if',
#   'you',
#   'were',
#   'satisfied',
#   'with',
#   'the',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'with',
#   'yes',
#   'or',
#   'no'],
#  ['you',
#   'lifted',
#   'my',
#   'hope',
#   'with',
#   'the',
#   'offer',
#   'of',
#   'money',
#   'am',
#   'in',
#   'need',
#   'especially',
#   'when',
#   'the',
#   'end',
#   'of',
#   'the',
#   'month',
#   'approach',
#   'and',
#   'it',
#   'hurt',
#   'my',
#   'studying',
#   'anyways',
#   'have',
#   'gr',
#   'weekend'],
#  ['lol', 'no', 'can', 'trust', 'me'],
#  ['ok',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['he', 'will', 'you', 'guy', 'close'],
#  ['going', 'on', 'nothing', 'great', 'bye'],
#  ['hello',
#   'handsome',
#   'are',
#   'you',
#   'finding',
#   'that',
#   'job',
#   'not',
#   'being',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'that',
#   'net',
#   'for',
#   'mummy',
#   'where',
#   'my',
#   'boytoy',
#   'now',
#   'doe',
#   'he',
#   'miss',
#   'me'],
#  ['haha', 'awesome', 'be', 'there', 'in', 'minute'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'freephone',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['have',
#   'you',
#   'got',
#   'xmas',
#   'radio',
#   'time',
#   'if',
#   'not',
#   'will',
#   'get',
#   'it',
#   'now'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'but',
#   'my',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'when',
#   'she',
#   'finish'],
#  ['are',
#   'you',
#   'unique',
#   'enough',
#   'find',
#   'out',
#   'from',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   've',
#   'joined',
#   'the',
#   'league',
#   'of',
#   'people',
#   'that',
#   'dont',
#   'keep',
#   'in',
#   'touch',
#   'you',
#   'mean',
#   'great',
#   'deal',
#   'to',
#   'me',
#   'you',
#   'have',
#   'been',
#   'friend',
#   'at',
#   'all',
#   'time',
#   'even',
#   'at',
#   'great',
#   'personal',
#   'cost',
#   'do',
#   'have',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'the', 'course'],
#  ['it',
#   'will',
#   'stop',
#   'on',
#   'itself',
#   'however',
#   'suggest',
#   'she',
#   'stay',
#   'with',
#   'someone',
#   'that',
#   'will',
#   'be',
#   'able',
#   'to',
#   'give',
#   'or',
#   'for',
#   'every',
#   'stool'],
#  ['how',
#   'are',
#   'you',
#   'doing',
#   'hope',
#   'you',
#   've',
#   'settled',
#   'in',
#   'for',
#   'the',
#   'new',
#   'school',
#   'year',
#   'just',
#   'wishin',
#   'you',
#   'gr',
#   'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['did', 'got', 'that', 'person', 'story'],
#  ['is',
#   'your',
#   'hamster',
#   'dead',
#   'hey',
#   'so',
#   'tmr',
#   'meet',
#   'you',
#   'at',
#   'pm',
#   'orchard',
#   'mrt'],
#  ['hi',
#   'it',
#   'kate',
#   'how',
#   'is',
#   'your',
#   'evening',
#   'hope',
#   'can',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'bit',
#   'but',
#   'have',
#   'to',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'if',
#   'can',
#   'xxx'],
#  ['found', 'it', 'enc', 'lt', 'gt', 'where', 'you', 'at'],
#  ['sent', 'you', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'now',
#   'so',
#   'txt',
#   'me',
#   'when',
#   'finish',
#   'if',
#   'can',
#   'love',
#   'kate',
#   'xxx'],
#  ['your',
#   'account',
#   'ha',
#   'been',
#   'refilled',
#   'successfully',
#   'by',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'is',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'transaction',
#   'id',
#   'is',
#   'kr',
#   'lt',
#   'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'me', 'alter', 'at', 'ok'],
#  ['say',
#   'until',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['you',
#   'please',
#   'give',
#   'connection',
#   'today',
#   'itself',
#   'before',
#   'lt',
#   'decimal',
#   'gt',
#   'or',
#   'refund',
#   'the',
#   'bill'],
#  ['both', 'shoot', 'big', 'load', 'so', 'get', 'ready'],
#  ['what',
#   'up',
#   'bruv',
#   'hope',
#   'you',
#   'had',
#   'great',
#   'break',
#   'do',
#   'have',
#   'rewarding',
#   'semester'],
#  ['home', 'so', 'we', 'can', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'how', 'noe', 'leh'],
#  ['sound', 'great', 'are', 'you', 'home', 'now'],
#  ['finally',
#   'the',
#   'match',
#   'heading',
#   'towards',
#   'draw',
#   'your',
#   'prediction'],
#  ['tired', 'haven', 'slept', 'well', 'the', 'past', 'few', 'night'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'it', 'good'],
#  ['have', 'to', 'take', 'exam', 'with', 'march'],
#  ['yeah',
#   'you',
#   'should',
#   'think',
#   'you',
#   'can',
#   'use',
#   'your',
#   'gt',
#   'atm',
#   'now',
#   'to',
#   'register',
#   'not',
#   'sure',
#   'but',
#   'if',
#   'there',
#   'anyway',
#   'can',
#   'help',
#   'let',
#   'me',
#   'know',
#   'but',
#   'when',
#   'you',
#   'do',
#   'be',
#   'sure',
#   'you',
#   'are',
#   'ready'],
#  ['ok', 'no', 'prob', 'take', 'ur', 'time'],
#  ['there',
#   'is',
#   'called',
#   'ubandu',
#   'which',
#   'will',
#   'run',
#   'without',
#   'installing',
#   'in',
#   'hard',
#   'disk',
#   'you',
#   'can',
#   'use',
#   'that',
#   'to',
#   'copy',
#   'the',
#   'important',
#   'file',
#   'in',
#   'system',
#   'and',
#   'give',
#   'it',
#   'to',
#   'repair',
#   'shop'],
#  ['sorry', 'll', 'call', 'later'],
#  ['say',
#   'leh',
#   'of',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'not',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'only',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'not',
#   'so',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'from',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'to',
#   'no',
#   'collect',
#   'yours',
#   'today',
#   'from',
#   'only',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would',
#   'really',
#   'appreciate',
#   'if',
#   'you',
#   'call',
#   'me',
#   'just',
#   'need',
#   'someone',
#   'to',
#   'talk',
#   'to'],
#  ['will',
#   'meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'is',
#   'ur',
#   'career',
#   'off',
#   'flyng',
#   'start',
#   'find',
#   'out',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'by',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'is',
#   'more',
#   'strict',
#   'than',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'then',
#   'conduct',
#   'exam',
#   'but',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'then',
#   'teach',
#   'lesson',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning', 'now', 'only', 'am', 'up'],
#  ['get',
#   'down',
#   'in',
#   'gandhipuram',
#   'and',
#   'walk',
#   'to',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'and',
#   'turn',
#   'at',
#   'first',
#   'right'],
#  ['dear', 'we', 'are', 'going', 'to', 'our', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah', 'here'],
#  ['yes', 'here', 'tv', 'is', 'always', 'available', 'in', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'can',
#   'find',
#   'date',
#   'or',
#   'even',
#   'flirt',
#   'it',
#   'up',
#   'to',
#   'join',
#   'just',
#   'reply',
#   'with',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['have', 'printed', 'it', 'oh', 'so', 'lt', 'gt', 'come', 'upstairs'],
#  ['or',
#   'ill',
#   'be',
#   'little',
#   'closer',
#   'like',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'on',
#   'the',
#   'same',
#   'street'],
#  ['where', 'are', 'you', 'when', 'wil', 'you', 'reach', 'here'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'but',
#   'loses',
#   'the',
#   'person',
#   'so',
#   'dont',
#   'argue',
#   'with',
#   'ur',
#   'friend',
#   'just',
#   'kick',
#   'them',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'think',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on'],
#  ['tomarrow', 'final', 'hearing', 'on', 'my', 'laptop', 'case', 'so', 'cant'],
#  ['tel', 'me', 'avent', 'done', 'sportsx'],
#  ['okay',
#   'no',
#   'no',
#   'just',
#   'shining',
#   'on',
#   'that',
#   'wa',
#   'meant',
#   'to',
#   'be',
#   'signing',
#   'but',
#   'that',
#   'sound',
#   'better'],
#  ['although',
#   'told',
#   'dat',
#   'into',
#   'baig',
#   'face',
#   'watch',
#   'now',
#   'but',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'it',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   've',
#   'done',
#   'today',
#   'touched'],
#  ['don', 'remember', 'that', 'old', 'commercial'],
#  ['too',
#   'late',
#   'said',
#   'have',
#   'the',
#   'website',
#   'didn',
#   'have',
#   'or',
#   'dont',
#   'have',
#   'the',
#   'slipper'],
#  ['asked', 'you', 'to', 'call', 'him', 'now', 'ok'],
#  ['kallis', 'wont', 'bat', 'in', 'nd', 'inning'],
#  ['it',
#   'didnt',
#   'work',
#   'again',
#   'oh',
#   'ok',
#   'goodnight',
#   'then',
#   'll',
#   'fix',
#   'and',
#   'have',
#   'it',
#   'ready',
#   'by',
#   'the',
#   'time',
#   'you',
#   'wake',
#   'up',
#   'you',
#   'are',
#   'very',
#   'dearly',
#   'missed',
#   'have',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'of',
#   'cd',
#   'voucher',
#   'or',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'to',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'and', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'it',
#   'seriously',
#   'coz',
#   'being',
#   'angry',
#   'is',
#   'most',
#   'childish',
#   'true',
#   'way',
#   'of',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'have',
#   'nice',
#   'day',
#   'da'],
#  ['what', 'you', 'doing', 'how', 'are', 'you'],
#  ['ups',
#   'which',
#   'is',
#   'day',
#   'also',
#   'and',
#   'the',
#   'shipping',
#   'company',
#   'that',
#   'take',
#   'wks',
#   'the',
#   'other',
#   'way',
#   'is',
#   'usps',
#   'which',
#   'take',
#   'week',
#   'but',
#   'when',
#   'it',
#   'get',
#   'to',
#   'lag',
#   'you',
#   'may',
#   'have',
#   'to',
#   'bribe',
#   'nipost',
#   'to',
#   'get',
#   'your',
#   'stuff'],
#  ['back', 'lemme', 'know', 'when', 'you', 're', 'ready'],
#  ['don',
#   'necessarily',
#   'expect',
#   'it',
#   'to',
#   'be',
#   'done',
#   'before',
#   'you',
#   'get',
#   'back',
#   'though',
#   'because',
#   'just',
#   'now',
#   'headin',
#   'out'],
#  ['mmm', 'so', 'yummy', 'babe', 'nice', 'jolt', 'to', 'the', 'suzy'],
#  ['where', 'are', 'you', 'lover', 'need', 'you'],
#  ['we',
#   'tried',
#   'to',
#   'contact',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'offer',
#   'of',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'min',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'or',
#   'call',
#   'now'],
#  ['parked',
#   'next',
#   'to',
#   'mini',
#   'when',
#   'are',
#   'you',
#   'coming',
#   'in',
#   'today',
#   'do',
#   'you',
#   'think'],
#  ['yup'],
#  ['anyway',
#   'going',
#   'shopping',
#   'on',
#   'my',
#   'own',
#   'now',
#   'co',
#   'my',
#   'si',
#   'not',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['my', 'no', 'in', 'luton', 'ring', 'me', 'if', 'ur', 'around'],
#  ['hey',
#   'am',
#   'really',
#   'horny',
#   'want',
#   'to',
#   'chat',
#   'or',
#   'see',
#   'me',
#   'naked',
#   'text',
#   'hot',
#   'to',
#   'text',
#   'charged',
#   'at',
#   'pm',
#   'to',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['why', 'you', 'dint', 'come', 'with'],
#  ['same', 'wana', 'plan', 'trip', 'sometme', 'then'],
#  ['not', 'sure', 'yet', 'still', 'trying', 'to', 'get', 'hold', 'of', 'him'],
#  ['ur',
#   'ringtone',
#   'service',
#   'ha',
#   'changed',
#   'free',
#   'credit',
#   'go',
#   'to',
#   'club',
#   'mobile',
#   'com',
#   'to',
#   'choose',
#   'content',
#   'now',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'to',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['the', 'evo', 'just', 'had', 'to', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'the',
#   'uk',
#   'single',
#   'chart',
#   'on',
#   'your',
#   'mobile',
#   'each',
#   'week',
#   'and',
#   'choose',
#   'any',
#   'top',
#   'quality',
#   'ringtone',
#   'this',
#   'message',
#   'is',
#   'free',
#   'of',
#   'charge'],
#  ['come',
#   'to',
#   'mu',
#   'we',
#   're',
#   'sorting',
#   'out',
#   'our',
#   'narcotic',
#   'situation'],
#  ['night',
#   'ha',
#   'ended',
#   'for',
#   'another',
#   'day',
#   'morning',
#   'ha',
#   'come',
#   'in',
#   'special',
#   'way',
#   'may',
#   'you',
#   'smile',
#   'like',
#   'the',
#   'sunny',
#   'ray',
#   'and',
#   'leaf',
#   'your',
#   'worry',
#   'at',
#   'the',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'of',
#   'genuine',
#   'hmv',
#   'voucher',
#   'to',
#   'be',
#   'won',
#   'just',
#   'answer',
#   'easy',
#   'question',
#   'play',
#   'now',
#   'send',
#   'hmv',
#   'to',
#   'more',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['no', 'objection', 'my', 'bf', 'not', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'to', 'mack', 'his', 'gf', 'in', 'the', 'theater'],
#  ['awesome', 'll', 'see', 'you', 'in', 'bit'],
#  ['just',
#   'sent',
#   'it',
#   'so',
#   'what',
#   'type',
#   'of',
#   'food',
#   'do',
#   'you',
#   'like'],
#  ['all',
#   'done',
#   'all',
#   'handed',
#   'in',
#   'celebration',
#   'in',
#   'full',
#   'swing',
#   'yet'],
#  ['you', 'got', 'called', 'tool'],
#  ['wen',
#   'miss',
#   'someone',
#   'the',
#   'person',
#   'is',
#   'definitely',
#   'special',
#   'for',
#   'but',
#   'if',
#   'the',
#   'person',
#   'is',
#   'so',
#   'special',
#   'why',
#   'to',
#   'miss',
#   'them',
#   'just',
#   'keep',
#   'in',
#   'touch',
#   'gdeve'],
#  ['ok', 'asked', 'for', 'money', 'how', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'my',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'out',
#   'from',
#   'last',
#   'night',
#   'if',
#   'you',
#   'get',
#   'ahold',
#   'of',
#   'anybody',
#   'let',
#   'me',
#   'know',
#   'and',
#   'll',
#   'throw',
#   'down'],
#  ['might',
#   'come',
#   'by',
#   'tonight',
#   'then',
#   'if',
#   'my',
#   'class',
#   'let',
#   'out',
#   'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'with',
#   'my',
#   'girl',
#   'friend',
#   'what',
#   'up',
#   'give',
#   'me',
#   'call',
#   'in',
#   'and',
#   'hour',
#   'at',
#   'home',
#   'if',
#   'thats',
#   'alright',
#   'or',
#   'fone',
#   'me',
#   'on',
#   'this',
#   'fone',
#   'now',
#   'love',
#   'jenny',
#   'xxx'],
#  ['my',
#   'life',
#   'mean',
#   'lot',
#   'to',
#   'me',
#   'not',
#   'because',
#   'love',
#   'my',
#   'life',
#   'but',
#   'because',
#   'love',
#   'the',
#   'people',
#   'in',
#   'my',
#   'life',
#   'the',
#   'world',
#   'call',
#   'them',
#   'friend',
#   'call',
#   'them',
#   'my',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'in',
#   'the',
#   'street',
#   'shall',
#   'update',
#   'you',
#   'tonite',
#   'thing',
#   'are',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'but',
#   'good',
#   'one',
#   'in',
#   'real',
#   'sense'],
#  ['hey', 'you', 'told', 'your', 'name', 'to', 'gautham', 'ah'],
#  ['haf', 'found', 'him', 'feel', 'so', 'stupid', 'da', 'cam', 'wa', 'working'],
#  ['oops', 'got', 'that', 'bit'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['accidentally', 'deleted', 'the', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'for',
#   'your',
#   'loyalty',
#   'call',
#   'on',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['unless',
#   'it',
#   'situation',
#   'where',
#   'you',
#   'go',
#   'gurl',
#   'would',
#   'be',
#   'more',
#   'appropriate'],
#  ['hurt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'me',
#   'cry',
#   'but',
#   'in',
#   'the',
#   'end',
#   'of',
#   'my',
#   'life',
#   'when',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'on',
#   'my',
#   'grave',
#   'and',
#   'say',
#   'stupid',
#   'miss',
#   'have',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'the', 'phone', 'right', 'now', 'pls', 'send', 'message'],
#  ['need',
#   'coffee',
#   'run',
#   'tomo',
#   'can',
#   'believe',
#   'it',
#   'that',
#   'time',
#   'of',
#   'week',
#   'already'],
#  ['awesome',
#   'remember',
#   'the',
#   'last',
#   'time',
#   'we',
#   'got',
#   'somebody',
#   'high',
#   'for',
#   'the',
#   'first',
#   'time',
#   'with',
#   'diesel'],
#  ['shit',
#   'that',
#   'is',
#   'really',
#   'shocking',
#   'and',
#   'scary',
#   'cant',
#   'imagine',
#   'for',
#   'second',
#   'def',
#   'up',
#   'for',
#   'night',
#   'out',
#   'do',
#   'think',
#   'there',
#   'is',
#   'somewhere',
#   'could',
#   'crash',
#   'for',
#   'night',
#   'save',
#   'on',
#   'taxi'],
#  ['oh',
#   'and',
#   'by',
#   'the',
#   'way',
#   'you',
#   'do',
#   'have',
#   'more',
#   'food',
#   'in',
#   'your',
#   'fridge',
#   'want',
#   'to',
#   'go',
#   'out',
#   'for',
#   'meal',
#   'tonight'],
#  ['he', 'is', 'womdarfull', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'is',
#   'from',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'him',
#   'out',
#   'http',
#   'img',
#   'sm',
#   'ac',
#   'icmb',
#   'cktz',
#   'no',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'from', 'what', 'remb', 'think', 'should', 'be', 'can', 'book'],
#  ['jos', 'ask', 'if', 'wana', 'meet', 'up'],
#  ['lol',
#   'yes',
#   'our',
#   'friendship',
#   'is',
#   'hanging',
#   'on',
#   'thread',
#   'cause',
#   'won',
#   'buy',
#   'stuff'],
#  ['themob',
#   'check',
#   'out',
#   'our',
#   'newest',
#   'selection',
#   'of',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'and',
#   'sport',
#   'keep',
#   'your',
#   'mobile',
#   'fit',
#   'and',
#   'funky',
#   'text',
#   'wap',
#   'to'],
#  ['where',
#   'are',
#   'the',
#   'garage',
#   'key',
#   'they',
#   'aren',
#   'on',
#   'the',
#   'bookshelf'],
#  ['today',
#   'is',
#   'accept',
#   'day',
#   'accept',
#   'me',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'this',
#   'week',
#   'in',
#   'our',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'to',
#   'now',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['he',
#   'say',
#   'he',
#   'll',
#   'give',
#   'me',
#   'call',
#   'when',
#   'his',
#   'friend',
#   'got',
#   'the',
#   'money',
#   'but',
#   'that',
#   'he',
#   'definitely',
#   'buying',
#   'before',
#   'the',
#   'end',
#   'of',
#   'the',
#   'week'],
#  ['hi',
#   'the',
#   'way',
#   'wa',
#   'with',
#   'day',
#   'is',
#   'the',
#   'normal',
#   'way',
#   'this',
#   'is',
#   'the',
#   'real',
#   'me',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'the',
#   'rest',
#   'of',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'wa',
#   'lost'],
#  ['you', 'made', 'my', 'day', 'do', 'have', 'great', 'day', 'too'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'we',
#   'can',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'we',
#   'can',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['not', 'really', 'dude', 'have', 'no', 'friend', 'afraid'],
#  ['december',
#   'only',
#   'had',
#   'your',
#   'mobile',
#   'mths',
#   'you',
#   'are',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'to', 'you', 'too', 'babe', 'love', 'ya', 'kiss'],
#  ['hey',
#   'why',
#   'dont',
#   'we',
#   'just',
#   'go',
#   'watch',
#   'men',
#   'and',
#   'have',
#   'lunch',
#   'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'they',
#   'were',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['that',
#   'would',
#   'be',
#   'great',
#   'we',
#   'll',
#   'be',
#   'at',
#   'the',
#   'guild',
#   'could',
#   'meet',
#   'on',
#   'bristol',
#   'road',
#   'or',
#   'somewhere',
#   'will',
#   'get',
#   'in',
#   'touch',
#   'over',
#   'weekend',
#   'our',
#   'plan',
#   'take',
#   'flight',
#   'have',
#   'good',
#   'week'],
#  ['no', 'problem', 'how', 'are', 'you', 'doing'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['hi', 'da', 'how', 'is', 'the', 'today', 'class'],
#  ['say',
#   'that',
#   'good',
#   'sign',
#   'but',
#   'well',
#   'you',
#   'know',
#   'my',
#   'track',
#   'record',
#   'at',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'me', 'when', 'you', 're', 'parked'],
#  ['reading',
#   'the',
#   'text',
#   'just',
#   'sent',
#   'you',
#   'it',
#   'meant',
#   'to',
#   'be',
#   'joke',
#   'so',
#   'read',
#   'it',
#   'in',
#   'that',
#   'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'out',
#   'tomo',
#   'then',
#   'return',
#   'it',
#   'immediately',
#   'or',
#   'something'],
#  ['call',
#   'germany',
#   'for',
#   'only',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'from',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'no',
#   'prepayment',
#   'direct',
#   'access'],
#  ['any',
#   'chance',
#   'you',
#   'might',
#   'have',
#   'had',
#   'with',
#   'me',
#   'evaporated',
#   'soon',
#   'you',
#   'violated',
#   'my',
#   'privacy',
#   'by',
#   'stealing',
#   'my',
#   'phone',
#   'number',
#   'from',
#   'your',
#   'employer',
#   'paperwork',
#   'not',
#   'cool',
#   'at',
#   'all',
#   'please',
#   'do',
#   'not',
#   'contact',
#   'me',
#   'again',
#   'or',
#   'will',
#   'report',
#   'you',
#   'to',
#   'your',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime',
#   'send',
#   'go',
#   'to',
#   'now',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['ta', 'daaaaa', 'am', 'home', 'babe', 'are', 'you', 'still', 'up'],
#  ['cool',
#   'so',
#   'how',
#   'come',
#   'you',
#   'havent',
#   'been',
#   'wined',
#   'and',
# ...
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsold', 'mike', 'hussey'],
#  ['like',
#   'to',
#   'talk',
#   'pa',
#   'but',
#   'am',
#   'not',
#   'able',
#   'to',
#   'dont',
#   'know'],
#  ['dun',
#   'cut',
#   'too',
#   'short',
#   'leh',
#   'dun',
#   'like',
#   'ah',
#   'she',
#   'failed',
#   'she',
#   'quite',
#   'sad'],
#  ['you', 'unbelievable', 'faglord'],
#  ['wife', 'how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly'],
#  ['why', 'do', 'you', 'ask', 'princess'],
#  ['am', 'great', 'princess', 'what', 'are', 'you', 'thinking', 'about', 'me'],
#  ['nutter',
#   'cutter',
#   'ctter',
#   'cttergg',
#   'cttargg',
#   'ctargg',
#   'ctagg',
#   'ie',
#   'you'],
#  ['it',
#   'ok',
#   'noe',
#   're',
#   'busy',
#   'but',
#   'really',
#   'too',
#   'bored',
#   'so',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'she',
#   'choose',
#   'me',
#   'one'],
#  ['doesn',
#   'have',
#   'class',
#   'early',
#   'tomorrow',
#   'and',
#   'thus',
#   'shouldn',
#   'be',
#   'trying',
#   'to',
#   'smoke',
#   'at',
#   'lt',
#   'gt'],
#  ['superb',
#   'thought',
#   'be',
#   'grateful',
#   'that',
#   'dont',
#   'have',
#   'everything',
#   'want',
#   'that',
#   'mean',
#   'still',
#   'have',
#   'an',
#   'opportunity',
#   'to',
#   'be',
#   'happier',
#   'tomorrow',
#   'than',
#   'are',
#   'today'],
#  ['hope', 'you', 'are', 'having', 'good', 'week', 'just', 'checking', 'in'],
#  ['used',
#   'to',
#   'it',
#   'just',
#   'hope',
#   'my',
#   'agent',
#   'don',
#   'drop',
#   'me',
#   'since',
#   've',
#   'only',
#   'booked',
#   'few',
#   'thing',
#   'this',
#   'year',
#   'this',
#   'whole',
#   'me',
#   'in',
#   'boston',
#   'them',
#   'in',
#   'nyc',
#   'wa',
#   'an',
#   'experiment'],
#  ['thursday',
#   'night',
#   'yeah',
#   'sure',
#   'thing',
#   'we',
#   'll',
#   'work',
#   'it',
#   'out',
#   'then'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['probably',
#   'money',
#   'worry',
#   'thing',
#   'are',
#   'coming',
#   'due',
#   'and',
#   'have',
#   'several',
#   'outstanding',
#   'invoice',
#   'for',
#   'work',
#   'did',
#   'two',
#   'and',
#   'three',
#   'month',
#   'ago'],
#  ['how', 'is', 'it', 'possible', 'to', 'teach', 'you', 'and', 'where'],
#  ['wonder',
#   'if',
#   'your',
#   'phone',
#   'battery',
#   'went',
#   'dead',
#   'had',
#   'to',
#   'tell',
#   'you',
#   'love',
#   'you',
#   'babe'],
#  ['lovely', 'smell', 'on', 'this', 'bus', 'and', 'it', 'ain', 'tobacco'],
#  ['we',
#   're',
#   'all',
#   'getting',
#   'worried',
#   'over',
#   'here',
#   'derek',
#   'and',
#   'taylor',
#   'have',
#   'already',
#   'assumed',
#   'the',
#   'worst'],
#  ['hey', 'what', 'up', 'charles', 'sorry', 'about', 'the', 'late', 'reply'],
#  ['all',
#   'the',
#   'lastest',
#   'from',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'and',
#   'the',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'with',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'or',
#   'text',
#   'wap',
#   'to'],
#  ['ll',
#   'give',
#   'her',
#   'once',
#   'have',
#   'it',
#   'plus',
#   'she',
#   'said',
#   'grinule',
#   'greet',
#   'you',
#   'whenever',
#   'we',
#   'speak'],
#  ['white', 'fudge', 'oreo', 'are', 'in', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'now',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'from',
#   'min',
#   'cheap',
#   'to',
#   'min',
#   'peak',
#   'to',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['my',
#   'love',
#   'how',
#   'come',
#   'it',
#   'took',
#   'you',
#   'so',
#   'long',
#   'to',
#   'leave',
#   'for',
#   'zaher',
#   'got',
#   'your',
#   'word',
#   'on',
#   'ym',
#   'and',
#   'wa',
#   'happy',
#   'to',
#   'see',
#   'them',
#   'but',
#   'wa',
#   'sad',
#   'you',
#   'had',
#   'left',
#   'miss',
#   'you'],
#  ['am', 'sorry', 'it', 'hurt', 'you'],
#  ['can',
#   'feel',
#   'nauseous',
#   'so',
#   'pissed',
#   'didn',
#   'eat',
#   'any',
#   'sweet',
#   'all',
#   'week',
#   'cause',
#   'today',
#   'wa',
#   'planning',
#   'to',
#   'pig',
#   'out',
#   'wa',
#   'dieting',
#   'all',
#   'week',
#   'and',
#   'now',
#   'not',
#   'hungry'],
#  ['ok',
#   'lor',
#   'but',
#   'not',
#   'too',
#   'early',
#   'me',
#   'still',
#   'having',
#   'project',
#   'meeting',
#   'now'],
#  ['call', 'me', 'da', 'am', 'waiting', 'for', 'your', 'call'],
#  ['could',
#   'ask',
#   'carlos',
#   'if',
#   'we',
#   'could',
#   'get',
#   'more',
#   'if',
#   'anybody',
#   'else',
#   'can',
#   'chip',
#   'in'],
#  ['wa',
#   'actually',
#   'about',
#   'to',
#   'send',
#   'you',
#   'reminder',
#   'today',
#   'have',
#   'wonderful',
#   'weekend'],
#  ['when',
#   'people',
#   'see',
#   'my',
#   'msg',
#   'they',
#   'think',
#   'iam',
#   'addicted',
#   'to',
#   'msging',
#   'they',
#   'are',
#   'wrong',
#   'bcoz',
#   'they',
#   'don',
#   'know',
#   'that',
#   'iam',
#   'addicted',
#   'to',
#   'my',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'you',
#   'gave',
#   'them',
#   'your',
#   'photo',
#   'when',
#   'you',
#   'registered',
#   'for',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'at',
#   'yck'],
#  ['dont', 'talk', 'to', 'him', 'ever', 'ok', 'it', 'my', 'word'],
#  ['when', 'wana', 'see', 'it', 'then'],
#  ['on',
#   'ma',
#   'way',
#   'to',
#   'school',
#   'can',
#   'you',
#   'pls',
#   'send',
#   'me',
#   'ashley',
#   'number'],
#  ['it', 'shall', 'be', 'fine', 'have', 'avalarr', 'now', 'will', 'hollalater'],
#  ['she',
#   'went',
#   'to',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'but',
#   'still',
#   'did',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'my',
#   'old',
#   'website',
#   'now',
#   'blogging',
#   'at',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['but',
#   'on',
#   'diet',
#   'and',
#   'ate',
#   'too',
#   'many',
#   'slice',
#   'of',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'on',
#   'diet'],
#  ['will', 'give', 'my', 'kvb', 'acc', 'detail'],
#  ['oh', 'all', 'have', 'to', 'come', 'ah'],
#  ['money',
#   'you',
#   'lucky',
#   'winner',
#   'claim',
#   'your',
#   'prize',
#   'text',
#   'money',
#   'over',
#   'million',
#   'to',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'won',
#   'able',
#   'do',
#   'this',
#   'friday',
#   'hope',
#   'can',
#   'find',
#   'an',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   're',
#   'wa',
#   'enjoy',
#   'it',
#   'and',
#   'wish',
#   'you',
#   'many',
#   'happy',
#   'moment',
#   'to',
#   'and',
#   'fro',
#   'wherever',
#   'you',
#   'go'],
#  ['so', 'do', 'you', 'have', 'samus', 'shoulder', 'yet'],
#  ['what',
#   'time',
#   'you',
#   'think',
#   'you',
#   'll',
#   'have',
#   'it',
#   'need',
#   'to',
#   'know',
#   'when',
#   'should',
#   'be',
#   'near',
#   'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'box',
#   'sk',
#   'xh'],
#  ['then', 'dun', 'wear', 'jean', 'lor'],
#  ['since', 'when', 'which', 'side', 'any', 'fever', 'any', 'vomitin'],
#  ['are', 'you', 'in', 'college'],
#  ['urgent',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'up',
#   'for',
#   'friday',
#   'and',
#   'stuffed',
#   'myself',
#   'like',
#   'pig',
#   'yesterday',
#   'now',
#   'feel',
#   'bleh',
#   'but',
#   'at',
#   'least',
#   'it',
#   'not',
#   'writhing',
#   'pain',
#   'kind',
#   'of',
#   'bleh'],
#  ['no',
#   'we',
#   'sell',
#   'it',
#   'all',
#   'so',
#   'we',
#   'll',
#   'have',
#   'ton',
#   'if',
#   'coin',
#   'then',
#   'sell',
#   'our',
#   'coin',
#   'to',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'in',
#   'life',
#   'pocket'],
#  ['theyre',
#   'doing',
#   'it',
#   'to',
#   'lot',
#   'of',
#   'place',
#   'only',
#   'hospital',
#   'and',
#   'medical',
#   'place',
#   'are',
#   'safe'],
#  ['how',
#   'about',
#   'getting',
#   'in',
#   'touch',
#   'with',
#   'folk',
#   'waiting',
#   'for',
#   'company',
#   'just',
#   'txt',
#   'back',
#   'your',
#   'name',
#   'and',
#   'age',
#   'to',
#   'opt',
#   'in',
#   'enjoy',
#   'the',
#   'community',
#   'sm'],
#  ['and',
#   'also',
#   've',
#   'sorta',
#   'blown',
#   'him',
#   'off',
#   'couple',
#   'time',
#   'recently',
#   'so',
#   'id',
#   'rather',
#   'not',
#   'text',
#   'him',
#   'out',
#   'of',
#   'the',
#   'blue',
#   'looking',
#   'for',
#   'weed'],
#  ['sent',
#   'my',
#   'score',
#   'to',
#   'sophas',
#   'and',
#   'had',
#   'to',
#   'do',
#   'secondary',
#   'application',
#   'for',
#   'few',
#   'school',
#   'think',
#   'if',
#   'you',
#   'are',
#   'thinking',
#   'of',
#   'applying',
#   'do',
#   'research',
#   'on',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'her',
#   'school',
#   'is',
#   'one',
#   'me',
#   'the',
#   'less',
#   'expensive',
#   'one'],
#  ['cant',
#   'wait',
#   'to',
#   'see',
#   'you',
#   'how',
#   'were',
#   'the',
#   'photo',
#   'were',
#   'useful'],
#  ['ur',
#   'cash',
#   'balance',
#   'is',
#   'currently',
#   'pound',
#   'to',
#   'maximize',
#   'ur',
#   'cash',
#   'in',
#   'now',
#   'send',
#   'go',
#   'to',
#   'only',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['hey',
#   'booked',
#   'the',
#   'kb',
#   'on',
#   'sat',
#   'already',
#   'what',
#   'other',
#   'lesson',
#   'are',
#   'we',
#   'going',
#   'for',
#   'ah',
#   'keep',
#   'your',
#   'sat',
#   'night',
#   'free',
#   'we',
#   'need',
#   'to',
#   'meet',
#   'and',
#   'confirm',
#   'our',
#   'lodging'],
#  ['chk', 'in', 'ur', 'belovd', 'dict'],
#  ['is', 'that', 'what', 'time', 'you', 'want', 'me', 'to', 'come'],
#  ['awesome', 'lemme', 'know', 'whenever', 'you', 're', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'against',
#   'gravity',
#   'read',
#   'carefully',
#   'our',
#   'heart',
#   'feel',
#   'light',
#   'when',
#   'someone',
#   'is',
#   'in',
#   'it',
#   'but',
#   'it',
#   'feel',
#   'very',
#   'heavy',
#   'when',
#   'someone',
#   'leaf',
#   'it',
#   'good',
#   'night'],
#  ['also', 'remember', 'to', 'get', 'dobby', 'bowl', 'from', 'your', 'car'],
#  ['filthy', 'story', 'and', 'girl', 'waiting', 'for', 'your'],
#  ['sorry',
#   'now',
#   'then',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'so',
#   'poor',
#   'thing',
#   'but',
#   'only',
#   'one',
#   'night',
#   'tmr',
#   'll',
#   'have',
#   'brand',
#   'new',
#   'room',
#   'sleep',
#   'in'],
#  ['love',
#   'isn',
#   'decision',
#   'it',
#   'feeling',
#   'if',
#   'we',
#   'could',
#   'decide',
#   'who',
#   'to',
#   'love',
#   'then',
#   'life',
#   'would',
#   'be',
#   'much',
#   'simpler',
#   'but',
#   'then',
#   'less',
#   'magical'],
#  ['welp', 'apparently', 'he', 'retired'],
#  ['my',
#   'sort',
#   'code',
#   'is',
#   'and',
#   'acc',
#   'no',
#   'is',
#   'the',
#   'bank',
#   'is',
#   'natwest',
#   'can',
#   'you',
#   'reply',
#   'to',
#   'confirm',
#   've',
#   'sent',
#   'this',
#   'to',
#   'the',
#   'right',
#   'person'],
#  ['where'],
#  ['sure', 'can', 'take', 'any', 'sick', 'time'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr',
#   'only'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'at',
#   'eve',
#   'had',
#   'to',
#   'go',
#   'temple',
#   'amp',
#   'church',
#   'what',
#   'about'],
#  ['yo',
#   'chad',
#   'which',
#   'gymnastics',
#   'class',
#   'do',
#   'you',
#   'wanna',
#   'take',
#   'the',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'is',
#   'full'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['or',
#   'better',
#   'still',
#   'can',
#   'you',
#   'catch',
#   'her',
#   'and',
#   'let',
#   'ask',
#   'her',
#   'if',
#   'she',
#   'can',
#   'sell',
#   'lt',
#   'gt',
#   'for',
#   'me'],
#  ['am',
#   'not',
#   'sure',
#   'about',
#   'night',
#   'menu',
#   'know',
#   'only',
#   'about',
#   'noon',
#   'menu'],
#  ['what',
#   'do',
#   'want',
#   'when',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'of',
#   'my',
#   'heart',
#   'for',
#   'you',
#   'thats',
#   'what',
#   'will',
#   'give',
#   'but',
#   'only',
#   'to',
#   'my',
#   'wife',
#   'of',
#   'my',
#   'liking',
#   'be',
#   'that',
#   'and',
#   'see',
#   'no',
#   'one',
#   'can',
#   'give',
#   'you',
#   'that',
#   'dont',
#   'call',
#   'me',
#   'will',
#   'wait',
#   'till',
#   'come'],
#  ['are', 'you', 'willing', 'to', 'go', 'for', 'aptitude', 'class'],
#  ['it', 'wont', 'until', 'trying', 'sort', 'house', 'out', 'is', 'that', 'ok'],
#  ['yar',
#   'lor',
#   'he',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'so',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesome', 'omw', 'back', 'now', 'then'],
#  ['yup', 'thk', 'so', 'until', 'shop', 'close', 'lor'],
#  ['what', 'is', 'your', 'account', 'number'],
#  ['eh', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'no',
#   'ad',
#   'crap',
#   'nite',
#   'wa',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'with',
#   'me',
#   'boring',
#   'biatch',
#   'thanx',
#   'but',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk', 'to', 'him'],
#  ['dont',
#   'hesitate',
#   'you',
#   'know',
#   'this',
#   'is',
#   'the',
#   'second',
#   'time',
#   'she',
#   'ha',
#   'had',
#   'weakness',
#   'like',
#   'that',
#   'so',
#   'keep',
#   'notebook',
#   'of',
#   'what',
#   'she',
#   'eat',
#   'and',
#   'did',
#   'the',
#   'day',
#   'before',
#   'or',
#   'if',
#   'anything',
#   'changed',
#   'the',
#   'day',
#   'before',
#   'so',
#   'that',
#   'we',
#   'can',
#   'be',
#   'sure',
#   'it',
#   'nothing'],
#  ['hey', 'you', 'can', 'pay', 'with', 'salary', 'de', 'only', 'lt', 'gt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'and', 'alcohol'],
#  ['if',
#   'he',
#   'started',
#   'searching',
#   'he',
#   'will',
#   'get',
#   'job',
#   'in',
#   'few',
#   'day',
#   'he',
#   'have',
#   'great',
#   'potential',
#   'and',
#   'talent'],
#  ['reckon',
#   'need',
#   'to',
#   'be',
#   'in',
#   'town',
#   'by',
#   'eightish',
#   'to',
#   'walk',
#   'from',
#   'carpark'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'yours',
#   'call',
#   'now',
#   'videochat',
#   'wid',
#   'your',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look',
#   'at',
#   'the',
#   'fuckin',
#   'time',
#   'what',
#   'the',
#   'fuck',
#   'you',
#   'think',
#   'is',
#   'up'],
#  ['yo', 'guess', 'what', 'just', 'dropped'],
#  ['carlos', 'say', 'he', 'll', 'be', 'at', 'mu', 'in', 'lt', 'gt', 'minute'],
#  ['in', 'office', 'now', 'will', 'call', 'you', 'lt', 'gt', 'min'],
#  ['geeee',
#   'miss',
#   'you',
#   'already',
#   'you',
#   'know',
#   'your',
#   'all',
#   'can',
#   'think',
#   'about',
#   'fuck',
#   'can',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'when',
#   'we',
#   'will',
#   'be',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ah',
#   'the',
#   'ubi',
#   'one',
#   'say',
#   'if',
#   'wan',
#   'call',
#   'by',
#   'tomorrow',
#   'call',
#   'look',
#   'for',
#   'irene',
#   'ere',
#   'only',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'for',
#   'st',
#   'wkg',
#   'day'],
#  ['ugh',
#   'gotta',
#   'drive',
#   'back',
#   'to',
#   'sd',
#   'from',
#   'la',
#   'my',
#   'butt',
#   'is',
#   'sore'],
#  ['th', 'of', 'july'],
#  ['hi',
#   'im',
#   'having',
#   'the',
#   'most',
#   'relaxing',
#   'time',
#   'ever',
#   'we',
#   'have',
#   'to',
#   'get',
#   'up',
#   'at',
#   'am',
#   'every',
#   'day',
#   'wa',
#   'the',
#   'party',
#   'good',
#   'the',
#   'other',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'at',
#   'ish'],
#  ['up',
#   'to',
#   'wan',
#   'come',
#   'then',
#   'come',
#   'lor',
#   'but',
#   'din',
#   'any',
#   'stripe',
#   'skirt'],
#  ['the',
#   'xmas',
#   'story',
#   'is',
#   'peace',
#   'the',
#   'xmas',
#   'msg',
#   'is',
#   'love',
#   'the',
#   'xmas',
#   'miracle',
#   'is',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['can', 'don', 'have', 'her', 'number'],
#  ['change', 'again', 'it', 'one', 'next', 'to', 'escalator'],
#  ['yetunde',
#   'in',
#   'class',
#   'can',
#   'you',
#   'not',
#   'run',
#   'water',
#   'on',
#   'it',
#   'to',
#   'make',
#   'it',
#   'ok',
#   'pls',
#   'now'],
#  ['not',
#   'lot',
#   'ha',
#   'happened',
#   'here',
#   'feel',
#   'very',
#   'quiet',
#   'beth',
#   'is',
#   'at',
#   'her',
#   'aunt',
#   'and',
#   'charlie',
#   'is',
#   'working',
#   'lot',
#   'just',
#   'me',
#   'and',
#   'helen',
#   'in',
#   'at',
#   'the',
#   'mo',
#   'how',
#   'have',
#   'you',
#   'been'],
#  ['then',
#   'wait',
#   'me',
#   'at',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'if',
#   'dun',
#   'then',
#   'go',
#   'get',
#   'my',
#   'car',
#   'then',
#   'come',
#   'back',
#   'pick'],
#  ...]

# %%
import gensim

# %%
## Lets train Word2vec from scratch
model=gensim.models.Word2Vec(words)

# %%
## To Get All the Vocabulary
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'it',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'will',
#  'if',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'go',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'll',
#  'come',
#  'like',
#  'good',
#  'time',
#  'am',
#  'then',
#  'got',
#  'wa',
#  'there',
#  'he',
#  'love',
#  'text',
#  'only',
#  'want',
#  'send',
#  'one',
#  'need',
#  'txt',
#  'today',
#  'by',
#  'going',
#  'don',
#  'stop',
#  'home',
#  'she',
#  'about',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'our',
#  'think',
#  'tell',
#  'week',
#  'hi',
#  'phone',
#  'they',
#  'new',
#  'please',
#  'later',
#  'pls',
#  'any',
#  'her',
#  'ha',
#  'co',
#  'did',
#  'been',
#  'msg',
#  'min',
#  'some',
#  'an',
#  'night',
#  'make',
#  'dear',
#  'who',
#  'here',
#  'message',
#  'say',
#  'well',
#  'where',
#  're',
#  'thing',
#  'much',
#  'oh',
#  'great',
#  'claim',
#  'hope',
#  'hey',
#  'him',
#  'number',
#  'give',
#  'more',
#  'too',
#  'happy',
#  'work',
#  'wat',
#  'friend',
#  'had',
#  'yes',
#  'way',
#  'www',
#  've',
#  'let',
#  'should',
#  'prize',
#  'won',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'after',
#  'ask',
#  'win',
#  'said',
#  'life',
#  'amp',
#  'cash',
#  'doing',
#  'im',
#  'yeah',
#  'really',
#  'meet',
#  'babe',
#  'why',
#  'find',
#  'them',
#  'miss',
#  'morning',
#  'very',
#  'last',
#  'year',
#  'service',
#  'thanks',
#  'uk',
#  'care',
#  'com',
#  'would',
#  'anything',
#  'lol',
#  'nokia',
#  'also',
#  'every',
#  'feel',
#  'keep',
#  'sure',
#  'pick',
#  'urgent',
#  'over',
#  'sent',
#  'contact',
#  'something',
#  'buy',
#  'gud',
#  'again',
#  'cant',
#  'wait',
#  'before',
#  'place',
#  'box',
#  'first',
#  'his',
#  'even',
#  'someone',
#  'guy',
#  'help',
#  'went',
#  'wish',
#  'next',
#  'tonight',
#  'were',
#  'nice',
#  'soon',
#  'show',
#  'which',
#  'off',
#  'around',
#  'word',
#  'could',
#  'customer',
#  'money',
#  'sleep',
#  'chat',
#  'per',
#  'many',
#  'late',
#  'always',
#  'ya',
#  'gonna',
#  'sm',
#  'down',
#  'leave',
#  'wan',
#  'name',
#  'lot',
#  'end',
#  'other',
#  'dun',
#  'pm',
#  'told',
#  'st',
#  'person',
#  'waiting',
#  'hello',
#  'special',
#  'try',
#  'month',
#  'girl',
#  'hour',
#  'may',
#  'fine',
#  'best',
#  'haha',
#  'minute',
#  'heart',
#  'people',
#  'coming',
#  'done',
#  'guaranteed',
#  'yet',
#  'thk',
#  'same',
#  'th',
#  'getting',
#  'smile',
#  'ppm',
#  'use',
#  'thought',
#  'god',
#  'didn',
#  'offer',
#  'stuff',
#  'holiday',
#  'talk',
#  'start',
#  'class',
#  'man',
#  'cost',
#  'live',
#  'mean',
#  'bit',
#  'line',
#  'car',
#  'lunch',
#  'few',
#  'draw',
#  'finish',
#  'job',
#  'being',
#  'problem',
#  'never',
#  'yup',
#  'ill',
#  'better',
#  'plan',
#  'trying',
#  'house',
#  'thats',
#  'cool',
#  'hr',
#  'meeting',
#  'account',
#  'rate',
#  'mind',
#  'pobox',
#  'ready',
#  'having',
#  'dat',
#  'long',
#  'weekend',
#  'game',
#  'chance',
#  'world',
#  'real',
#  'half',
#  'enjoy',
#  'latest',
#  'wk',
#  'po',
#  'room',
#  'yo',
#  'sir',
#  'check',
#  'because',
#  'than',
#  'bt',
#  'guess',
#  'play',
#  'awarded',
#  'wanna',
#  'nothing',
#  'lar',
#  'receive',
#  'boy',
#  'voucher',
#  'eat',
#  'sweet',
#  'luv',
#  'look',
#  'camera',
#  'pic',
#  'another',
#  'liao',
#  'big',
#  'shit',
#  'dinner',
#  'into',
#  'ah',
#  'landline',
#  'birthday',
#  'xxx',
#  'jus',
#  'might',
#  'ever',
#  'quite',
#  'video',
#  'kiss',
#  'age',
#  'watching',
#  'wont',
#  'question',
#  'land',
#  'watch',
#  'dream',
#  'orange',
#  'early',
#  'thanx',
#  'worry',
#  'baby',
#  'called',
#  'speak',
#  'two',
#  'tv',
#  'aight',
#  'once',
#  'hear',
#  'fun',
#  'probably',
#  'nd',
#  'point',
#  'bed',
#  'pa',
#  'pay',
#  'doe',
#  'actually',
#  'network',
#  'princess',
#  'nite',
#  'apply',
#  'maybe',
#  'shall',
#  'bus',
#  'part',
#  'sat',
#  'left',
#  'forgot',
#  'den',
#  'bad',
#  'ringtone',
#  'remember',
#  'office',
#  'hurt',
#  'easy',
#  'reach',
#  'code',
#  'shopping',
#  'between',
#  'dunno',
#  'made',
#  'xx',
#  'dis',
#  'little',
#  'evening',
#  'didnt',
#  'award',
#  'put',
#  'true',
#  'leh',
#  'fuck',
#  'everything',
#  'wife',
#  'anyway',
#  'face',
#  'dad',
#  'looking',
#  'town',
#  'thank',
#  'afternoon',
#  'gift',
#  'school',
#  'enough',
#  'sound',
#  'those',
#  'mail',
#  'working',
#  'mate',
#  'selected',
#  'yr',
#  'movie',
#  'most',
#  'collect',
#  'pound',
#  'detail',
#  'without',
#  'asked',
#  'entry',
#  'while',
#  'missing',
#  'tmr',
#  'hav',
#  'join',
#  'price',
#  'sexy',
#  'okay',
#  'though',
#  'pain',
#  'wif',
#  'important',
#  'must',
#  'xmas',
#  'wanted',
#  'until',
#  'since',
#  'valid',
#  'came',
#  'update',
#  'mob',
#  'answer',
#  'wot',
#  'lesson',
#  'missed',
#  'wake',
#  'book',
#  'abt',
#  'run',
#  'collection',
#  'bring',
#  'able',
#  'til',
#  'wen',
#  'haven',
#  'decimal',
#  'de',
#  'test',
#  'charge',
#  'juz',
#  'plus',
#  'change',
#  'stay',
#  'date',
#  'plz',
#  'colour',
#  'away',
#  'double',
#  'weekly',
#  'havent',
#  'yesterday',
#  'saw',
#  'else',
#  'music',
#  'till',
#  'shop',
#  'dude',
#  'bored',
#  'attempt',
#  'alright',
#  'hair',
#  'lei',
#  'food',
#  'optout',
#  'trip',
#  'credit',
#  'friendship',
#  'making',
#  'drink',
#  'net',
#  'these',
#  'online',
#  'id',
#  'haf',
#  'yours',
#  'top',
#  'oso',
#  'coz',
#  'goin',
#  'tried',
#  'gr',
#  'family',
#  'address',
#  'delivery',
#  'sch',
#  'hot',
#  'player',
#  'club',
#  'either',
#  'smoke',
#  'ard',
#  'driving',
#  'feeling',
#  'national',
#  'yourself',
#  'nt',
#  'sad',
#  'order',
#  'lose',
#  'together',
#  'calling',
#  'full',
#  'wid',
#  'second',
#  'story',
#  'mom',
#  'busy',
#  'ring',
#  'beautiful',
#  'head',
#  'bonus',
#  'walk',
#  'http',
#  'brother',
#  'tot',
#  'both',
#  'si',
#  'sae',
#  'post',
#  'believe',
#  'smiling',
#  'huh',
#  'close',
#  'poly',
#  'old',
#  'eve',
#  'row',
#  'chikku',
#  'happen',
#  'noe',
#  'drive',
#  'await',
#  'set',
#  'info',
#  'hand',
#  'saying',
#  'mum',
#  'sleeping',
#  'leaving',
#  'awesome',
#  'mths',
#  'took',
#  'congrats',
#  'pub',
#  'hl',
#  'email',
#  'drop',
#  'parent',
#  'wil',
#  'rite',
#  'tomo',
#  'match',
#  'thinking',
#  'suite',
#  'started',
#  'news',
#  'simple',
#  'aft',
#  'finished',
#  'private',
#  'cause',
#  'doesn',
#  'okie',
#  'tho',
#  'unsubscribe',
#  'auction',
#  'available',
#  'tc',
#  'forget',
#  'content',
#  'everyone',
#  'company',
#  'anyone',
#  'sister',
#  'touch',
#  'break',
#  'caller',
#  'valentine',
#  'reason',
#  'mine',
#  'final',
#  'card',
#  'angry',
#  'neva',
#  'taking',
#  'gd',
#  'statement',
#  'open',
#  'dating',
#  'loving',
#  'whats',
#  'alone',
#  'found',
#  'treat',
#  'whatever',
#  'lucky',
#  'fancy',
#  'carlos',
#  'gal',
#  'choose',
#  'worth',
#  'opt',
#  'each',
#  'ticket',
#  'search',
#  'sun',
#  'knw',
#  'type',
#  'bank',
#  'expires',
#  'wonderful',
#  'frnd',
#  'hows',
#  'mobileupd',
#  'hit',
#  'winner',
#  'hard',
#  'boytoy',
#  'gone',
#  'saturday',
#  'gbp',
#  'welcome',
#  'fast',
#  'happened',
#  'quiz',
#  'anytime',
#  'kind',
#  'congratulation',
#  'bout',
#  'secret',
#  'far',
#  'identifier',
#  'decided',
#  'sub',
#  'ni',
#  'exam',
#  'uncle',
#  'ltd',
#  'party',
#  'smth',
#  'friday',
#  'college',
#  'visit',
#  'nyt',
#  'prob',
#  'song',
#  'darlin',
#  'mu',
#  'hold',
#  'read',
#  'light',
#  'operator',
#  'oredi',
#  'goodmorning',
#  'finally',
#  'mrng',
#  'tel',
#  'sea',
#  'wit',
#  'project',
#  'pretty',
#  'outside',
#  'nope',
#  'term',
#  'used',
#  'drug',
#  'fucking',
#  'wonder',
#  'camcorder',
#  'lovely',
#  'wrong',
#  'least',
#  'chennai',
#  'fri',
#  'crazy',
#  'ten',
#  'log',
#  'cum',
#  'listen',
#  'frnds',
#  'freemsg',
#  'seeing',
#  'blue',
#  'telling',
#  'fone',
#  'case',
#  'meant',
#  'jay',
#  'whole',
#  'fr',
#  'unlimited',
#  'cd',
#  'their',
#  'wasn',
#  'isn',
#  'support',
#  'course',
#  'frm',
#  'sunday',
#  'hmm',
#  'wq',
#  'savamob',
#  'snow',
#  'hungry',
#  'earlier',
#  'wkly',
#  'stupid',
#  'die',
#  'happiness',
#  'un',
#  'dnt',
#  'move',
#  'etc',
#  'hee',
#  'within',
#  'single',
#  'yar',
#  'hmmm',
#  'cut',
#  'mr',
#  'eh',
#  'moment',
#  'march',
#  'enter',
#  'joy',
#  'luck',
#  'film',
#  'na',
#  'balance',
#  'gn',
#  'john',
#  'gas',
#  'child',
#  'knew',
#  'understand',
#  'pas',
#  'father',
#  'valued',
#  'store',
#  'tired',
#  'bslvyl',
#  'mayb',
#  'sell',
#  'almost',
#  'sex',
#  'paper',
#  'press',
#  'side',
#  'area',
#  'sk',
#  'currently',
#  'couple',
#  'txts',
#  'computer',
#  'rock',
#  'invited',
#  'felt',
#  'as',
#  'ago',
#  'download',
#  'india',
#  'lost',
#  'mah',
#  'christmas',
#  'talking',
#  'reading',
#  'load',
#  'motorola',
#  'park',
#  'shower',
#  'bill',
#  'hospital',
#  'askd',
#  'picking',
#  'charged',
#  'photo',
#  'direct',
#  'heard',
#  'return',
#  'rental',
#  'eye',
#  'via',
#  'darren',
#  'confirm',
#  'semester',
#  'correct',
#  'reveal',
#  'red',
#  'doin',
#  'ac',
#  'laptop',
#  'xy',
#  'supposed',
#  'wow',
#  'sort',
#  'ugh',
#  'extra',
#  'information',
#  'bcoz',
#  'kid',
#  'gym',
#  'swing',
#  'redeemed',
#  'surprise',
#  'seen',
#  'difficult',
#  'through',
#  'ge',
#  'promise',
#  'met',
#  'max',
#  'sending',
#  'lady',
#  'complimentary',
#  'comp',
#  'figure',
#  'ipod',
#  'gotta',
#  'grin',
#  'ish',
#  'abiola',
#  'slowly',
#  'ex',
#  'whenever',
#  'discount',
#  'lovable',
#  'yep',
#  'muz',
#  'request',
#  'std',
#  'bath',
#  'police',
#  'hg',
#  'crave',
#  'usf',
#  'safe',
#  'reward',
#  'nobody',
#  'eg',
#  'orchard',
#  'road',
#  'kate',
#  'wine',
#  'comin',
#  'slow',
#  'weed',
#  'link',
#  'asap',
#  'truth',
#  'wap',
#  'fantasy',
#  'study',
#  'fact',
#  'loved',
#  'loan',
#  'cheer',
#  'small',
#  'somebody',
#  'page',
#  'rest',
#  'laugh',
#  'rply',
#  'hmv',
#  'joke',
#  'leaf',
#  'entered',
#  'txting',
#  'blood',
#  'wana',
#  'idea',
#  'noon',
#  'clean',
#  'dogging',
#  'door',
#  'checking',
#  'asking',
#  'train',
#  'own',
#  'remove',
#  'lover',
#  'monday',
#  'save',
#  'rent',
#  'pete',
#  'member',
#  'energy',
#  'nah',
#  'deal',
#  'near',
#  'del',
#  'forever',
#  'mistake',
#  'cup',
#  'copy',
#  'normal',
#  'somewhere',
#  'men',
#  'england',
#  'la',
#  'opinion',
#  'situation',
#  'em',
#  'cheap',
#  'warm',
#  'hoping',
#  'empty',
#  'across',
#  'hw',
#  'woke',
#  'usual',
#  'rakhesh',
#  'callertune',
#  'spend',
#  'med',
#  'gave',
#  'cover',
#  'write',
#  'short',
#  'bb',
#  'tonite',
#  'ringtones',
#  'bathe',
#  'water',
#  'different',
#  'representative',
#  'sony',
#  'ho',
#  'ntt',
#  'voice',
#  'king',
#  'merry',
#  'gap',
#  'poor',
#  'fantastic',
#  'booked',
#  'oops',
#  'wc',
#  'gettin',
#  'bag',
#  'admirer',
#  'getzed',
#  'ldn',
#  'kick',
#  'less',
#  'immediately',
#  'glad',
#  'summer',
#  'wishing',
#  'street',
#  'teach',
#  'cr',
#  'otherwise',
#  'worried',
#  'doctor',
#  'sale',
#  'il',
#  'convey',
#  'custcare',
#  'indian',
#  ...]

# %%
model.corpus_count
# Out:
# 5569

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('my', 0.9988569617271423),
#  ('all', 0.998847484588623),
#  ('well', 0.9988037943840027),
#  ('morning', 0.9987487196922302),
#  ('night', 0.9987141489982605),
#  ('not', 0.9987050294876099),
#  ('day', 0.9986633062362671),
#  ('dear', 0.9986313581466675),
#  ('wa', 0.998615026473999),
#  ('oh', 0.9985678195953369)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
words[0]
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'great',
#  'world',
#  'la',
#  'buffet',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat']

# %%
def avg_word2vec(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)
    
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\indira gothi\downloads\ai-ml-learning\venv\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\indira gothi\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tqdm import tqdm

# %%
#apply for the entire sentences
import numpy as np
X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
#   0%|          | 0/5569 [00:00<?, ?it/s]c:\Users\indira gothi\Downloads\AI-ML-Learning\venv\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\indira gothi\Downloads\AI-ML-Learning\venv\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 5569/5569 [00:00<00:00, 6197.00it/s]

# %%
X
# Out:
# [array([-1.71343833e-01,  2.36079827e-01,  1.24769114e-01,  8.30340385e-02,
#          9.28719714e-02, -4.97339725e-01,  1.79416478e-01,  4.64051694e-01,
#         -2.69818693e-01, -1.32228106e-01, -1.55763462e-01, -3.60272825e-01,
#         -4.94791269e-02,  9.53688920e-02,  1.98053688e-01, -1.68316498e-01,
#          1.06815659e-01, -3.07823360e-01, -7.90153667e-02, -5.12440503e-01,
#          2.00984702e-01,  9.91651490e-02,  7.16567039e-02, -2.17182145e-01,
#         -4.32692207e-02, -2.81740259e-02, -2.00575620e-01, -1.93412021e-01,
#         -2.74952054e-01,  3.32614854e-02,  3.05104613e-01,  1.13960123e-02,
#          1.03895150e-01, -1.87506706e-01, -1.11927785e-01,  3.86822522e-01,
#          6.65969998e-02, -1.19801432e-01, -1.27736434e-01, -4.64834183e-01,
#          1.07727334e-01, -2.27704063e-01, -1.84430972e-01, -2.95696722e-04,
#          1.45751521e-01,  1.59008838e-02, -1.05464600e-01, -2.54447982e-02,
#          2.10545078e-01,  1.42166719e-01,  1.56812683e-01, -1.93317100e-01,
#         -4.67790589e-02,  6.18289188e-02, -4.43275832e-02,  6.64105117e-02,
#          1.46415442e-01,  7.21792085e-03, -3.53858352e-01,  1.77491933e-01,
#          7.06583261e-03,  1.55040577e-01,  6.31303433e-03, -1.08237758e-01,
#         -2.98830569e-01,  2.66570777e-01,  9.78779942e-02,  2.22566277e-01,
#         -3.43684226e-01,  3.93130630e-01, -2.56285548e-01,  1.69512495e-01,
#          3.89814198e-01, -1.21034704e-01,  3.66685033e-01,  7.41155222e-02,
#          1.06651507e-01, -9.78684202e-02, -1.85281649e-01,  7.87086189e-02,
#         -2.37298235e-01, -9.65823159e-02, -2.58712500e-01,  4.53909755e-01,
#         -1.60188973e-01, -4.21204418e-02,  3.00307218e-02,  2.15918049e-01,
#          3.84023368e-01,  6.47714064e-02,  3.60833585e-01,  1.46002218e-01,
#          3.99394482e-02,  5.02587967e-02,  4.26850587e-01,  1.90430984e-01,
#          1.35698959e-01, -2.08878860e-01,  1.59176752e-01, -2.30085198e-03],
#        dtype=float32),
#  array([-0.16142417,  0.20936535,  0.10910235,  0.07266189,  0.0876686 ,
#         -0.43355548,  0.14564502,  0.40953946, -0.23685072, -0.10779582,
#         -0.13970356, -0.3164426 , -0.03711207,  0.08915971,  0.17997432,
#         -0.1532048 ,  0.09352865, -0.2695069 , -0.07605857, -0.4550827 ,
#          0.18163157,  0.08425961,  0.05759562, -0.1843001 , -0.03999444,
#         -0.02240202, -0.17395385, -0.17829816, -0.23533663,  0.02417738,
#          0.26398167,  0.01061055,  0.08455356, -0.16477555, -0.10183021,
#          0.33685613,  0.05258676, -0.10586419, -0.1103888 , -0.41040137,
#          0.093048  , -0.19308022, -0.15455501, -0.00573082,  0.12135752,
#          0.0075133 , -0.09500825, -0.02593028,  0.18701957,  0.12834044,
#          0.13356651, -0.1622518 , -0.03839936,  0.05265147, -0.03040441,
#          0.06193931,  0.13073201,  0.00573115, -0.3083683 ,  0.16375574,
#          0.01017574,  0.13582912,  0.0046293 , -0.08452452, -0.26483676,
#          0.22964731,  0.08177902,  0.19434828, -0.29484665,  0.34805354,
#         -0.2201255 ,  0.13484697,  0.33452672, -0.10959353,  0.31326088,
#          0.06139991,  0.09139006, -0.08360712, -0.17083916,  0.06196534,
#         -0.19780277, -0.08237611, -0.23565793,  0.38779277, -0.14865535,
#         -0.03560683,  0.02377527,  0.1981885 ,  0.33331057,  0.05029596,
#          0.3229221 ,  0.12118066,  0.03123459,  0.0400969 ,  0.36674222,
#          0.16451465,  0.12284797, -0.18966769,  0.14319524, -0.0096972 ],
#        dtype=float32),
#  array([-0.18480422,  0.25104108,  0.13061796,  0.09451959,  0.07311136,
#         -0.54070336,  0.18155959,  0.45862943, -0.2786185 , -0.1591429 ,
#         -0.1509317 , -0.37812853, -0.05670565,  0.08425424,  0.18649091,
#         -0.18314734,  0.11949074, -0.33509   , -0.08707306, -0.51364   ,
#          0.1930421 ,  0.1306253 ,  0.0687146 , -0.23558287, -0.01970276,
#         -0.026819  , -0.208282  , -0.17422345, -0.29349077,  0.02154626,
#          0.31151214,  0.01731981,  0.10613644, -0.19138256, -0.10380945,
#          0.3992884 ,  0.11595762, -0.14190389, -0.14988588, -0.49850637,
#          0.10056606, -0.2659063 , -0.21782188, -0.01125663,  0.12386464,
#          0.02872877, -0.09789485, -0.00655708,  0.21011676,  0.13276762,
#          0.15407068, -0.22305536, -0.0487878 ,  0.08979214, -0.08570684,
#          0.06373661,  0.15337421, -0.01385488, -0.37782565,  0.20186566,
#          0.00095162,  0.14735045,  0.02809698, -0.12628567, -0.32306588,
#          0.29603451,  0.07833018,  0.24083328, -0.37571555,  0.42717358,
#         -0.27586567,  0.22237147,  0.41725966, -0.14012198,  0.3850498 ,
#          0.07121644,  0.08687938, -0.11804751, -0.18695499,  0.0609867 ,
#         -0.24900772, -0.10875271, -0.25973874,  0.4584831 , -0.13035075,
#         -0.030115  ,  0.00538986,  0.19257697,  0.3898846 ,  0.10876942,
#          0.35229596,  0.14563228,  0.03247124,  0.02887933,  0.44199368,
#          0.18236479,  0.09216135, -0.23896427,  0.18179807,  0.0195467 ],
#        dtype=float32),
#  array([-0.24290022,  0.3207303 ,  0.16619565,  0.11758592,  0.13114795,
#         -0.67033666,  0.23433815,  0.6337298 , -0.37249708, -0.17009567,
#         -0.21494795, -0.48002583, -0.05665701,  0.14139089,  0.28251788,
#         -0.23945482,  0.14865485, -0.41701016, -0.1145726 , -0.71062326,
#          0.28322056,  0.12642981,  0.08821989, -0.286264  , -0.06863789,
#         -0.02543981, -0.2750709 , -0.27134982, -0.35953966,  0.04653179,
#          0.4193385 ,  0.01595451,  0.13486354, -0.2449834 , -0.16281475,
#          0.52109915,  0.07820304, -0.15519433, -0.158673  , -0.6332366 ,
#          0.1523366 , -0.30327645, -0.23935774,  0.00776129,  0.19955148,
#          0.01221225, -0.14425151, -0.05023901,  0.28804204,  0.19236858,
#          0.19727217, -0.25302264, -0.0496919 ,  0.07644957, -0.04227858,
#          0.09626941,  0.19955552,  0.01753267, -0.4685947 ,  0.24789895,
#          0.0157696 ,  0.21373351,  0.0053264 , -0.13457467, -0.39871815,
#          0.3608561 ,  0.13631608,  0.3085883 , -0.45059276,  0.54118276,
#         -0.34239605,  0.20092191,  0.5198624 , -0.17465298,  0.48658457,
#          0.0997679 ,  0.14798866, -0.11792365, -0.2554099 ,  0.09572455,
#         -0.31274128, -0.12897418, -0.35334596,  0.6115109 , -0.22683299,
#         -0.05764923,  0.05596871,  0.30640116,  0.5237393 ,  0.0598979 ,
#          0.49491447,  0.19091538,  0.04869152,  0.07444708,  0.5679489 ,
#          0.2628754 ,  0.20012902, -0.28952366,  0.21542986, -0.01172628],
#        dtype=float32),
#  array([-0.20871155,  0.27049443,  0.14942086,  0.09819365,  0.11582502,
#         -0.5723373 ,  0.20161319,  0.5481246 , -0.31985858, -0.1553019 ,
#         -0.18357615, -0.42049265, -0.05298864,  0.1146396 ,  0.24429913,
#         -0.19607137,  0.1337404 , -0.3626612 , -0.09590451, -0.611126  ,
#          0.24424751,  0.10723162,  0.08106462, -0.24743788, -0.04744086,
#         -0.02407466, -0.23120423, -0.22588499, -0.31687224,  0.03947489,
#          0.3607259 ,  0.015142  ,  0.1258308 , -0.21834148, -0.13674507,
#          0.44977403,  0.07498571, -0.1354021 , -0.13740839, -0.53428984,
#          0.12926133, -0.26701614, -0.20928693,  0.00807701,  0.1739075 ,
#          0.0186336 , -0.12534009, -0.03515214,  0.24037369,  0.16907309,
#          0.17130888, -0.21620832, -0.04730999,  0.06968044, -0.03953737,
#          0.08039769,  0.16366735,  0.0189385 , -0.4023039 ,  0.21501492,
#          0.01026471,  0.18330635,  0.0029671 , -0.11352395, -0.34509632,
#          0.31368667,  0.12259271,  0.26670745, -0.38209584,  0.4633726 ,
#         -0.29259098,  0.18029451,  0.44823882, -0.1432443 ,  0.42109945,
#          0.07988906,  0.11786715, -0.11146396, -0.21153115,  0.08866469,
#         -0.26636195, -0.10670847, -0.30034807,  0.5332081 , -0.18701458,
#         -0.03854563,  0.05366241,  0.25074506,  0.4436022 ,  0.05506293,
#          0.42447472,  0.162854  ,  0.04761226,  0.06702417,  0.49032068,
#          0.22674173,  0.1656863 , -0.25398403,  0.17960261, -0.01264425],
#        dtype=float32),
#  array([-0.21952896,  0.2884272 ,  0.15266402,  0.10436658,  0.11330099,
#         -0.6123646 ,  0.21239388,  0.5661559 , -0.3340403 , -0.17364775,
#         -0.18759733, -0.44181404, -0.05767499,  0.11768202,  0.24488193,
#         -0.20804502,  0.13798058, -0.3802284 , -0.09996703, -0.6298993 ,
#          0.24955167,  0.12161431,  0.08854688, -0.2688699 , -0.03899137,
#         -0.02843357, -0.2439571 , -0.22605275, -0.33492577,  0.03590412,
#          0.37999558,  0.0156073 ,  0.13047618, -0.22710098, -0.13264802,
#          0.47407576,  0.09378651, -0.15166627, -0.15126665, -0.5691392 ,
#          0.13233808, -0.2930857 , -0.2306174 ,  0.00071325,  0.17064053,
#          0.02407148, -0.1288636 , -0.02785214,  0.24989347,  0.17152774,
#          0.18995762, -0.23320545, -0.05064779,  0.08202795, -0.05575895,
#          0.08275524,  0.17693417,  0.00920936, -0.42671713,  0.22667702,
#          0.01003622,  0.18541886,  0.01478399, -0.12434212, -0.36572698,
#          0.33593878,  0.11826423,  0.28084454, -0.41349232,  0.49122292,
#         -0.30968264,  0.21020205,  0.4759626 , -0.14798303,  0.44809982,
#          0.08434706,  0.12178019, -0.12225066, -0.21807155,  0.08829699,
#         -0.2871155 , -0.11402443, -0.31256393,  0.55109066, -0.18590018,
#         -0.04041348,  0.04614207,  0.25000063,  0.46582127,  0.0805029 ,
#          0.436402  ,  0.17367783,  0.04736273,  0.05952775,  0.5125611 ,
#          0.2354381 ,  0.15393457, -0.26402596,  0.19274577, -0.00306466],
#        dtype=float32),
#  array([-0.2309071 ,  0.30649853,  0.17130663,  0.11304644,  0.12617578,
#         -0.64745986,  0.22537494,  0.6104264 , -0.3601647 , -0.17830229,
#         -0.20131645, -0.46766886, -0.05091245,  0.13396327,  0.269396  ,
#         -0.22231284,  0.14734599, -0.39986446, -0.1063539 , -0.68596214,
#          0.27884454,  0.12122234,  0.09424125, -0.28682998, -0.05089452,
#         -0.0287867 , -0.26120532, -0.2502349 , -0.3569972 ,  0.04364421,
#          0.40977266,  0.02189239,  0.14667036, -0.2443576 , -0.14856808,
#          0.5072606 ,  0.08162134, -0.15826108, -0.16011092, -0.6086988 ,
#          0.1420266 , -0.30340794, -0.23673308,  0.00507143,  0.19823787,
#          0.01705847, -0.14283673, -0.03922359,  0.2739155 ,  0.18695593,
#          0.19958937, -0.23788552, -0.05589741,  0.07661103, -0.04396813,
#          0.08773814,  0.18390451,  0.01929712, -0.452115  ,  0.2326304 ,
#          0.00949811,  0.20778184,  0.00443882, -0.12831569, -0.38884613,
#          0.36036214,  0.13463394,  0.30169412, -0.43417534,  0.524851  ,
#         -0.33123156,  0.20314375,  0.5062715 , -0.15277395,  0.47682732,
#          0.09061091,  0.14004709, -0.12910828, -0.23471956,  0.10791765,
#         -0.30971736, -0.12567654, -0.33946487,  0.60018253, -0.21265526,
#         -0.05219108,  0.05618966,  0.2774741 ,  0.5022854 ,  0.07223952,
#          0.473211  ,  0.18778129,  0.05218848,  0.07344593,  0.5531347 ,
#          0.25651628,  0.18665612, -0.2754114 ,  0.19925007, -0.01349591],
#        dtype=float32),
#  array([-0.17151375,  0.24089248,  0.12882784,  0.08501212,  0.07332692,
#         -0.5017609 ,  0.17627129,  0.44964907, -0.26904833, -0.14739105,
#         -0.1434793 , -0.364     , -0.04828598,  0.090675  ,  0.19145614,
#         -0.16974755,  0.11000508, -0.31395236, -0.07462251, -0.49665004,
#          0.19263496,  0.11044798,  0.0681762 , -0.22307958, -0.03535474,
#         -0.02927958, -0.20000798, -0.17462796, -0.2756196 ,  0.02605373,
#          0.30947995,  0.01764842,  0.11372825, -0.17546612, -0.10303878,
#          0.3866823 ,  0.08740402, -0.12620802, -0.13738596, -0.46829867,
#          0.1005244 , -0.24293508, -0.19954596, -0.00236511,  0.1284163 ,
#          0.02490079, -0.09961969, -0.01318252,  0.21278213,  0.14110304,
#          0.15582043, -0.20049568, -0.04959347,  0.07173716, -0.05541415,
#          0.05858115,  0.13503335,  0.00150341, -0.35636312,  0.18461415,
#         -0.00584652,  0.14805618,  0.0185126 , -0.11713111, -0.30830643,
#          0.26964813,  0.08585685,  0.22267833, -0.35349926,  0.40587363,
#         -0.25720572,  0.195058  ,  0.39748576, -0.12725012,  0.37534237,
#          0.07739683,  0.10827451, -0.11631539, -0.17973717,  0.0703729 ,
#         -0.24713743, -0.10023318, -0.25459203,  0.45107475, -0.14758345,
#         -0.03777462,  0.01166237,  0.1922849 ,  0.38284254,  0.09194413,
#          0.34983906,  0.14949149,  0.0445648 ,  0.04315907,  0.41875172,
#          0.1821597 ,  0.11149876, -0.21458846,  0.1639948 ,  0.00631615],
#        dtype=float32),
#  array([-0.2025653 ,  0.27629316,  0.1600624 ,  0.11128422,  0.0850519 ,
#         -0.5788617 ,  0.20106375,  0.49416262, -0.3071833 , -0.17157204,
#         -0.16774566, -0.4226879 , -0.07029516,  0.09816107,  0.21159528,
#         -0.20351595,  0.12160549, -0.35960418, -0.09962637, -0.5569833 ,
#          0.21065737,  0.1354067 ,  0.07676439, -0.25737116, -0.03194651,
#         -0.04005294, -0.23393334, -0.18046091, -0.30338955,  0.03273938,
#          0.3462928 ,  0.00986104,  0.11588913, -0.19144876, -0.1095707 ,
#          0.4271783 ,  0.12622695, -0.14863926, -0.16627276, -0.53743255,
#          0.11359782, -0.2859314 , -0.2276564 , -0.00708163,  0.13117552,
#          0.03204121, -0.10773335, -0.0059714 ,  0.23109062,  0.14555018,
#          0.18010104, -0.25263122, -0.05654107,  0.10004169, -0.08707902,
#          0.07844274,  0.17071758, -0.00106052, -0.4150702 ,  0.22479951,
#         -0.00650217,  0.15328434,  0.03149683, -0.13080306, -0.34299466,
#          0.30402192,  0.10112695,  0.25893387, -0.40774292,  0.454802  ,
#         -0.29526305,  0.23561111,  0.4467135 , -0.14909671,  0.41977096,
#          0.07841315,  0.10093577, -0.13364248, -0.20382947,  0.05935681,
#         -0.27478147, -0.11242126, -0.28024748,  0.4930985 , -0.13826215,
#         -0.0249308 ,  0.00321608,  0.1981974 ,  0.421473  ,  0.10328142,
#          0.39183864,  0.15652478,  0.03329759,  0.02473047,  0.48293018,
#          0.18728927,  0.09584798, -0.2608405 ,  0.19332023,  0.02795558],
#        dtype=float32),
#  array([-2.2442955e-01,  3.1745842e-01,  1.6751471e-01,  1.1545594e-01,
#          8.9864329e-02, -6.7974627e-01,  2.2421563e-01,  5.7268178e-01,
#         -3.4843498e-01, -2.0293888e-01, -1.9133402e-01, -4.8042759e-01,
#         -7.5667821e-02,  1.0613117e-01,  2.3954943e-01, -2.2933462e-01,
#          1.4236963e-01, -4.1819519e-01, -1.0101249e-01, -6.3360578e-01,
#          2.3529086e-01,  1.6813038e-01,  8.6415350e-02, -3.0597979e-01,
#         -2.3347925e-02, -4.3044709e-02, -2.6297018e-01, -2.0806237e-01,
#         -3.7356246e-01,  2.5903590e-02,  3.9761710e-01,  1.7330494e-02,
#          1.3613676e-01, -2.2751060e-01, -1.3188443e-01,  5.0267190e-01,
#          1.4776228e-01, -1.8479851e-01, -1.9753629e-01, -6.2149322e-01,
#          1.2635683e-01, -3.3580580e-01, -2.8185052e-01, -1.8203830e-02,
#          1.5514323e-01,  3.9522499e-02, -1.1831859e-01, -3.5381711e-03,
#          2.7258277e-01,  1.6955002e-01,  2.0140089e-01, -2.9005706e-01,
#         -6.0483109e-02,  1.0790790e-01, -1.1276603e-01,  7.8181714e-02,
#          1.8006958e-01, -2.6013274e-02, -4.7285706e-01,  2.4725492e-01,
#          1.4195750e-05,  1.8515335e-01,  4.2491876e-02, -1.6252625e-01,
#         -4.2592672e-01,  3.6265293e-01,  9.2844754e-02,  3.0230781e-01,
#         -4.8609611e-01,  5.4885066e-01, -3.4417015e-01,  2.9115489e-01,
#          5.2783084e-01, -1.8095402e-01,  4.9903560e-01,  1.0161036e-01,
#          1.2351435e-01, -1.5474188e-01, -2.3492917e-01,  7.4227512e-02,
#         -3.2034957e-01, -1.4238903e-01, -3.3419049e-01,  5.8478636e-01,
#         -1.6434912e-01, -4.3459903e-02, -9.1464398e-03,  2.2663850e-01,
#          4.9279663e-01,  1.4697355e-01,  4.4216079e-01,  1.9166508e-01,
#          4.5146734e-02,  3.6727294e-02,  5.5878675e-01,  2.2483830e-01,
#          1.1246226e-01, -2.9033241e-01,  2.2538619e-01,  2.1491939e-02],
#        dtype=float32),
#  array([-0.21847004,  0.2823686 ,  0.14759564,  0.09849906,  0.11486341,
#         -0.59627104,  0.20730484,  0.5646697 , -0.32886225, -0.16418263,
#         -0.18792918, -0.43341026, -0.05228088,  0.11445321,  0.24589932,
#         -0.21019007,  0.13464929, -0.37269893, -0.09770995, -0.62791526,
#          0.25204152,  0.11240894,  0.08507058, -0.2626004 , -0.04605384,
#         -0.02914311, -0.23616286, -0.22721422, -0.32773083,  0.03921753,
#          0.37693527,  0.01479202,  0.13091815, -0.22140278, -0.13247785,
#          0.4617639 ,  0.08487848, -0.14561102, -0.1409568 , -0.5561354 ,
#          0.13445854, -0.28406718, -0.22061828,  0.00529596,  0.17266655,
#          0.02130394, -0.1260718 , -0.03282363,  0.24401353,  0.1693135 ,
#          0.18480282, -0.2238697 , -0.04802757,  0.07859606, -0.04496931,
#          0.08632531,  0.17133883,  0.01069018, -0.4113616 ,  0.22037469,
#          0.01389585,  0.18421488,  0.00945405, -0.1178498 , -0.35161865,
#          0.32938352,  0.12489428,  0.27563944, -0.40126115,  0.4767898 ,
#         -0.30487403,  0.19048859,  0.4642919 , -0.14172478,  0.43601847,
#          0.08797875,  0.12153681, -0.11247363, -0.21547346,  0.09197135,
#         -0.27873307, -0.11127216, -0.307904  ,  0.54553604, -0.18962716,
#         -0.04129323,  0.05264927,  0.24898358,  0.45664334,  0.0668745 ,
#          0.43620387,  0.17011303,  0.04538004,  0.06279986,  0.50428903,
#          0.23311354,  0.16011877, -0.25754842,  0.18341774, -0.00556645],
#        dtype=float32),
#  array([-0.22259767,  0.29422748,  0.15668976,  0.11210469,  0.09516281,
#         -0.64885676,  0.21678296,  0.5500217 , -0.33668092, -0.18445502,
#         -0.18343323, -0.45592356, -0.06898405,  0.10441986,  0.22716247,
#         -0.21883297,  0.15023875, -0.4011018 , -0.10627898, -0.61938804,
#          0.2357394 ,  0.15484735,  0.08467324, -0.2807589 , -0.02677902,
#         -0.03302276, -0.2524577 , -0.20857273, -0.3507147 ,  0.03106878,
#          0.37938017,  0.012985  ,  0.12989478, -0.22113758, -0.12547399,
#          0.47408903,  0.12922326, -0.17565124, -0.17590162, -0.5989287 ,
#          0.12529904, -0.3206772 , -0.25238717, -0.01153705,  0.14694744,
#          0.03402011, -0.12169965, -0.00705205,  0.25030068,  0.16140898,
#          0.18802722, -0.26665527, -0.05245394,  0.10551772, -0.09835512,
#          0.07941903,  0.18762091, -0.01147165, -0.4522434 ,  0.24582045,
#         -0.00104232,  0.17587267,  0.03018432, -0.1456213 , -0.38504887,
#          0.3549905 ,  0.0978322 ,  0.29229337, -0.4493396 ,  0.5143816 ,
#         -0.33219084,  0.25823814,  0.4977817 , -0.17367429,  0.46482626,
#          0.08204424,  0.10764226, -0.13934255, -0.22452351,  0.06710213,
#         -0.3017568 , -0.12536363, -0.30904883,  0.5521233 , -0.1576677 ,
#         -0.03277716,  0.01112983,  0.22744799,  0.465168  ,  0.11918633,
#          0.42312178,  0.1730004 ,  0.037018  ,  0.04196537,  0.52427423,
#          0.21880439,  0.11377329, -0.28614467,  0.21378618,  0.02033166],
#        dtype=float32),
#  array([-0.23445801,  0.313058  ,  0.17515671,  0.11826564,  0.09760416,
#         -0.6684444 ,  0.22764811,  0.56723243, -0.35006133, -0.19534059,
#         -0.19095781, -0.48108393, -0.07484406,  0.10346911,  0.24174948,
#         -0.2254032 ,  0.146661  , -0.42167497, -0.11012805, -0.64223146,
#          0.23760751,  0.16366288,  0.0877317 , -0.30062413, -0.03181825,
#         -0.03626436, -0.2676017 , -0.21191348, -0.35898   ,  0.03228796,
#          0.4006053 ,  0.00859061,  0.13269822, -0.22544964, -0.12846243,
#          0.49404943,  0.14237337, -0.17385286, -0.182071  , -0.62249076,
#          0.13715978, -0.33455455, -0.26533458, -0.00981328,  0.15407485,
#          0.03847498, -0.1210708 , -0.00692105,  0.2588748 ,  0.16144243,
#          0.20163558, -0.28773546, -0.06018283,  0.11261522, -0.1035588 ,
#          0.08825517,  0.19579782, -0.00748204, -0.47898895,  0.2534773 ,
#         -0.00616675,  0.17769921,  0.04098127, -0.149616  , -0.40463164,
#          0.3583598 ,  0.1043599 ,  0.30266756, -0.4672571 ,  0.52875084,
#         -0.34482834,  0.2758776 ,  0.52056324, -0.17501737,  0.48515394,
#          0.0903936 ,  0.11516962, -0.14948967, -0.23713672,  0.07236537,
#         -0.31546235, -0.12995327, -0.32150826,  0.57591826, -0.15870035,
#         -0.03320652,  0.00458163,  0.23447034,  0.4879832 ,  0.1267371 ,
#          0.44342628,  0.18325052,  0.04180047,  0.03385273,  0.5567625 ,
#          0.22393891,  0.11413475, -0.29617292,  0.22346145,  0.02623233],
#        dtype=float32),
#  array([-0.21879365,  0.28580546,  0.15203302,  0.10199619,  0.11250862,
#         -0.60293317,  0.21363726,  0.56495386, -0.33041343, -0.16894478,
#         -0.18580124, -0.44049987, -0.05368674,  0.11699399,  0.2468835 ,
#         -0.208902  ,  0.13867679, -0.37661815, -0.09243622, -0.6262226 ,
#          0.25235882,  0.12150271,  0.08902834, -0.26929438, -0.04333673,
#         -0.03141201, -0.24267043, -0.22416763, -0.33442983,  0.03745132,
#          0.38568223,  0.01602118,  0.13378039, -0.22045973, -0.13137655,
#          0.4702147 ,  0.08915901, -0.14465256, -0.1444527 , -0.56204885,
#          0.13557206, -0.28985524, -0.23108195,  0.00213226,  0.17065103,
#          0.03206191, -0.12946878, -0.02438993,  0.24953324,  0.17398302,
#          0.19308291, -0.2280776 , -0.05071895,  0.08106743, -0.05046684,
#          0.08076905,  0.1725132 ,  0.01179531, -0.4211355 ,  0.22291602,
#          0.00478404,  0.18301904,  0.0169379 , -0.1251952 , -0.36446694,
#          0.33017558,  0.12163137,  0.27668685, -0.41077122,  0.48678157,
#         -0.30690536,  0.20750843,  0.47600138, -0.14194654,  0.4498988 ,
#          0.08892778,  0.13116942, -0.12355713, -0.21636233,  0.09375181,
#         -0.2908074 , -0.11116337, -0.30772087,  0.5532629 , -0.19011232,
#         -0.04446542,  0.04508845,  0.24441063,  0.46178234,  0.07878657,
#          0.43547124,  0.17486164,  0.05217618,  0.06347636,  0.5097064 ,
#          0.23474987,  0.15767018, -0.25493386,  0.18993966, -0.00278357],
#        dtype=float32),
#  array([-0.20578797,  0.28744873,  0.152113  ,  0.10418252,  0.10329474,
#         -0.6010871 ,  0.21312411,  0.5535242 , -0.3237759 , -0.16835086,
#         -0.18303083, -0.44377434, -0.05926217,  0.1148051 ,  0.23687671,
#         -0.20473243,  0.13823722, -0.3763601 , -0.09034836, -0.6151719 ,
#          0.24707383,  0.12752046,  0.08059388, -0.26870474, -0.04537554,
#         -0.03811127, -0.24407853, -0.22061948, -0.32827538,  0.03303045,
#          0.3718567 ,  0.01690346,  0.13589256, -0.22127481, -0.13474204,
#          0.47180057,  0.10127562, -0.1501898 , -0.16386622, -0.5623724 ,
#          0.13204442, -0.29032457, -0.223011  ,  0.00274216,  0.17528325,
#          0.03018439, -0.1295936 , -0.02700622,  0.25476584,  0.1709016 ,
#          0.19014917, -0.23557492, -0.05324318,  0.07986545, -0.06097971,
#          0.07856037,  0.17142488,  0.00390324, -0.42298946,  0.22151725,
#          0.00413974,  0.17990394,  0.01844373, -0.12868616, -0.362101  ,
#          0.32828823,  0.11332393,  0.2793415 , -0.4162269 ,  0.48902342,
#         -0.3096668 ,  0.21004754,  0.47834495, -0.14377123,  0.4540627 ,
#          0.08580614,  0.13024993, -0.12862755, -0.21473067,  0.09162105,
#         -0.2943583 , -0.1224731 , -0.31396535,  0.54563564, -0.18513058,
#         -0.04603726,  0.02849788,  0.24111323,  0.46579775,  0.09070808,
#          0.43234122,  0.17972015,  0.04879581,  0.05379783,  0.5107983 ,
#          0.22001599,  0.14663605, -0.25094098,  0.19588035,  0.00528937],
#        dtype=float32),
#  array([-0.18723583,  0.2585684 ,  0.13298766,  0.09022097,  0.08381075,
#         -0.55103254,  0.18865481,  0.4821313 , -0.2931977 , -0.15697493,
#         -0.16115852, -0.3944748 , -0.05446574,  0.09238485,  0.20750082,
#         -0.18106964,  0.11998681, -0.33732653, -0.08592283, -0.53818303,
#          0.20680237,  0.12239304,  0.07183957, -0.24583192, -0.03257806,
#         -0.02801532, -0.21474564, -0.18745185, -0.3040252 ,  0.0227519 ,
#          0.32990482,  0.01329929,  0.11504364, -0.20012489, -0.10888448,
#          0.420301  ,  0.10313643, -0.1382581 , -0.14996627, -0.5108682 ,
#          0.11000081, -0.26503798, -0.21682721, -0.0056535 ,  0.14147678,
#          0.02806617, -0.10206298, -0.01178623,  0.2214294 ,  0.1472341 ,
#          0.1662658 , -0.22107455, -0.05291047,  0.07939405, -0.07099632,
#          0.0652299 ,  0.1573789 , -0.00699274, -0.38946804,  0.1977592 ,
#         -0.00186459,  0.159548  ,  0.02368593, -0.12594473, -0.3367711 ,
#          0.30453503,  0.09055015,  0.25028056, -0.3828441 ,  0.44022936,
#         -0.2797519 ,  0.21610498,  0.432065  , -0.1373001 ,  0.40362012,
#          0.08381276,  0.10995406, -0.1208792 , -0.19708546,  0.07715335,
#         -0.26478934, -0.11041039, -0.27335784,  0.48553476, -0.15264983,
#         -0.04048379,  0.01384401,  0.20873103,  0.41204748,  0.1021358 ,
#          0.37173337,  0.16009806,  0.04301569,  0.04426268,  0.45774716,
#          0.19638449,  0.11867325, -0.23388301,  0.18066822,  0.00675336],
#        dtype=float32),
#  array([-0.19215004,  0.26494488,  0.14095648,  0.0936624 ,  0.10385362,
#         -0.5633666 ,  0.20261292,  0.5374798 , -0.30875048, -0.14990966,
#         -0.1780927 , -0.4196166 , -0.05105122,  0.11245497,  0.22842221,
#         -0.1902352 ,  0.12565695, -0.3519121 , -0.08647718, -0.5895214 ,
#          0.24437277,  0.10817757,  0.06883839, -0.24686225, -0.05380116,
#         -0.02945211, -0.2258844 , -0.22548856, -0.31634605,  0.03149897,
#          0.35379124,  0.01458559,  0.12202162, -0.2156011 , -0.13072927,
#          0.44804814,  0.06942184, -0.13327385, -0.13768639, -0.526169  ,
#          0.13025746, -0.25545597, -0.20868649, -0.00171495,  0.17216142,
#          0.0135694 , -0.12169864, -0.02743666,  0.24863619,  0.16825916,
#          0.17968178, -0.21302746, -0.05404102,  0.06323633, -0.03827714,
#          0.07991455,  0.16335489,  0.01575623, -0.39737454,  0.20014279,
#         -0.00110571,  0.18508226,  0.00074677, -0.12008087, -0.34491894,
#          0.30910942,  0.11929405,  0.25651428, -0.38097465,  0.45157146,
#         -0.28806046,  0.17958212,  0.4429686 , -0.14030443,  0.4156027 ,
#          0.08499199,  0.1296178 , -0.11483815, -0.21409877,  0.09981302,
#         -0.27291408, -0.10801613, -0.29997575,  0.52453136, -0.18993358,
#         -0.04995796,  0.03738336,  0.25393763,  0.44419727,  0.06748842,
#          0.4109087 ,  0.17780079,  0.0532486 ,  0.07184029,  0.48191962,
#          0.22411847,  0.1640576 , -0.23115353,  0.18400784, -0.01032977],
#        dtype=float32),
#  array([-0.1796047 ,  0.22469182,  0.12426969,  0.08023147,  0.09928426,
#         -0.4816188 ,  0.16445978,  0.4536583 , -0.2641171 , -0.12769088,
#         -0.1586168 , -0.35095885, -0.04310471,  0.09541705,  0.20119523,
#         -0.16994037,  0.10984695, -0.30389524, -0.07532912, -0.51078355,
#          0.20723534,  0.08925024,  0.0685839 , -0.20624427, -0.03993591,
#         -0.02255965, -0.19589488, -0.19483988, -0.26270178,  0.03154187,
#          0.3047693 ,  0.0128934 ,  0.10202318, -0.17413561, -0.10974269,
#          0.37617096,  0.05257424, -0.11937238, -0.11041424, -0.45452705,
#          0.11190364, -0.22914845, -0.17379884,  0.00530109,  0.13812365,
#          0.01820395, -0.11019099, -0.02915244,  0.1989038 ,  0.13977589,
#          0.1478997 , -0.1834566 , -0.03081352,  0.06168254, -0.03697775,
#          0.07349336,  0.13986917,  0.01806184, -0.3417906 ,  0.1780659 ,
#          0.00678229,  0.15146574,  0.00602338, -0.09613588, -0.29175726,
#          0.2561672 ,  0.10620327,  0.22441298, -0.32098973,  0.3939449 ,
#         -0.24721877,  0.15090588,  0.37600112, -0.12130463,  0.35290524,
#          0.06991552,  0.10981899, -0.09054235, -0.17848527,  0.07588618,
#         -0.22702938, -0.09151316, -0.24536006,  0.44971228, -0.15963678,
#         -0.03612288,  0.04273951,  0.21158014,  0.37061235,  0.04649705,
#          0.3564087 ,  0.13409115,  0.03576646,  0.05581995,  0.40859565,
#          0.1966641 ,  0.1384727 , -0.20865704,  0.14983074, -0.00677345],
#        dtype=float32),
#  array([-0.23773889,  0.30798775,  0.16303468,  0.10404831,  0.13535851,
#         -0.6438118 ,  0.22935884,  0.6228235 , -0.363133  , -0.17956272,
#         -0.20900305, -0.4677959 , -0.0531292 ,  0.13212328,  0.28725553,
#         -0.22502609,  0.15171206, -0.39769584, -0.10692086, -0.6925778 ,
#          0.2836605 ,  0.11575852,  0.09541886, -0.2850168 , -0.05157094,
#         -0.03083814, -0.25690207, -0.25678986, -0.3613601 ,  0.04071914,
#          0.42179695,  0.02126537,  0.14657044, -0.25137362, -0.14685802,
#          0.5156251 ,  0.07822014, -0.14933853, -0.15439117, -0.60069853,
#          0.1439802 , -0.30447128, -0.23669334,  0.01351649,  0.20627494,
#          0.0228855 , -0.13982876, -0.03678054,  0.27743906,  0.19668466,
#          0.20815678, -0.23484886, -0.06468799,  0.06492291, -0.03691087,
#          0.08799581,  0.18785164,  0.02481261, -0.45058864,  0.22716403,
#          0.01202659,  0.21584657,  0.01259291, -0.12799874, -0.3851605 ,
#          0.36066186,  0.14807647,  0.3031769 , -0.43545666,  0.52575785,
#         -0.3262846 ,  0.20457804,  0.50628656, -0.14452352,  0.48782548,
#          0.10151041,  0.1546481 , -0.12433752, -0.23684561,  0.11856054,
#         -0.31797805, -0.1232955 , -0.3410728 ,  0.61460865, -0.22362399,
#         -0.05825019,  0.0638725 ,  0.2816543 ,  0.5110003 ,  0.0631554 ,
#          0.48271304,  0.19746462,  0.065488  ,  0.08183216,  0.5593575 ,
#          0.26738945,  0.20494068, -0.26599273,  0.19182518, -0.0141439 ],
#        dtype=float32),
#  array([-0.16780274,  0.22631915,  0.11666593,  0.08537542,  0.07546958,
#         -0.49330765,  0.16640738,  0.42049822, -0.2581006 , -0.13881204,
#         -0.13926288, -0.35014653, -0.05129956,  0.08016477,  0.1750206 ,
#         -0.16376895,  0.11448088, -0.30452704, -0.0798144 , -0.4762093 ,
#          0.17802094,  0.11700875,  0.06012885, -0.21428823, -0.02242336,
#         -0.02062568, -0.1895773 , -0.1611678 , -0.26838332,  0.01982366,
#          0.29391652,  0.01174579,  0.09773694, -0.17441283, -0.09550547,
#          0.36273474,  0.09623739, -0.12959099, -0.12948102, -0.460967  ,
#          0.09667351, -0.24028458, -0.19524574, -0.00690829,  0.11989427,
#          0.02555647, -0.09612418, -0.00861337,  0.18931733,  0.12283075,
#          0.13928209, -0.20118304, -0.04130681,  0.07611582, -0.06984332,
#          0.0615327 ,  0.14419815, -0.0073896 , -0.34406352,  0.18258458,
#         -0.00193483,  0.13668953,  0.02315523, -0.10917957, -0.29528904,
#          0.27104986,  0.07623123,  0.22398646, -0.33660313,  0.38835108,
#         -0.25550252,  0.19315533,  0.3799776 , -0.12843503,  0.3522314 ,
#          0.06139596,  0.08500502, -0.10590933, -0.17068067,  0.05510532,
#         -0.22831365, -0.09630425, -0.23648384,  0.42590103, -0.12240985,
#         -0.02864509,  0.01393826,  0.18263143,  0.36168692,  0.09332773,
#          0.3211928 ,  0.13494897,  0.03239606,  0.03333759,  0.40273586,
#          0.1733006 ,  0.09475562, -0.2152553 ,  0.16460985,  0.01121732],
#        dtype=float32),
#  array([-0.23533238,  0.28480744,  0.16095014,  0.1027258 ,  0.13040353,
#         -0.6040973 ,  0.21173832,  0.5868327 , -0.34045103, -0.1667032 ,
#         -0.1963348 , -0.44697794, -0.05166999,  0.13607909,  0.26691407,
#         -0.20775592,  0.14222452, -0.37420034, -0.09132467, -0.6579591 ,
#          0.27450377,  0.10387957,  0.09826886, -0.26962897, -0.04440246,
#         -0.02227849, -0.24436155, -0.2460132 , -0.33249906,  0.04858757,
#          0.40314975,  0.0182421 ,  0.13796486, -0.22208552, -0.13608807,
#          0.4830609 ,  0.06145785, -0.14251247, -0.12571633, -0.57484066,
#          0.15359016, -0.2896348 , -0.21371941,  0.00652331,  0.18287091,
#          0.0275219 , -0.14398837, -0.04202638,  0.2510584 ,  0.18128304,
#          0.20104441, -0.22354136, -0.04638961,  0.07349855, -0.03227467,
#          0.09412659,  0.17848566,  0.03010019, -0.42913827,  0.22317001,
#          0.00697004,  0.19689819,  0.00892786, -0.11212106, -0.35942593,
#          0.32891577,  0.14621274,  0.28195077, -0.3991278 ,  0.5000175 ,
#         -0.30956867,  0.18058978,  0.47906396, -0.13465062,  0.45266765,
#          0.09288716,  0.14115216, -0.11611498, -0.21995676,  0.10756708,
#         -0.29231712, -0.11160179, -0.30461508,  0.57162035, -0.2093294 ,
#         -0.04566433,  0.07133628,  0.26188084,  0.47314507,  0.04619106,
#          0.46045098,  0.17197652,  0.05217435,  0.07142081,  0.51559204,
#          0.2527386 ,  0.1903567 , -0.2633025 ,  0.17587836, -0.00599111],
#        dtype=float32),
#  array([-0.22054605,  0.31758434,  0.16359758,  0.11412946,  0.09663116,
#         -0.65696514,  0.23399098,  0.5951874 , -0.34811682, -0.18852122,
#         -0.18969467, -0.47225788, -0.06420501,  0.12082253,  0.24767716,
#         -0.22491834,  0.13804805, -0.40770602, -0.09762441, -0.65474343,
#          0.25966874,  0.14490543,  0.08236364, -0.28685206, -0.04893428,
#         -0.04089238, -0.26021674, -0.23002025, -0.360514  ,  0.03483219,
#          0.3961273 ,  0.02680199,  0.15086746, -0.24863273, -0.14002828,
#          0.506396  ,  0.11176266, -0.16313404, -0.18392737, -0.61268383,
#          0.13129261, -0.31172335, -0.2566601 , -0.01173298,  0.18324715,
#          0.03120164, -0.13389413, -0.01901249,  0.28498986,  0.18454736,
#          0.20447928, -0.2487981 , -0.06956925,  0.08434391, -0.06692313,
#          0.06715608,  0.18297511,  0.00243557, -0.4678527 ,  0.23201823,
#         -0.00354954,  0.1991085 ,  0.01884305, -0.1541327 , -0.40626538,
#          0.3564221 ,  0.12045322,  0.2918856 , -0.46639708,  0.5245834 ,
#         -0.33324707,  0.24549492,  0.5128774 , -0.16533965,  0.49320826,
#          0.0946531 ,  0.14336897, -0.1479427 , -0.23620336,  0.09381544,
#         -0.32260355, -0.1333822 , -0.33963126,  0.5866645 , -0.1960079 ,
#         -0.05945162,  0.01643746,  0.25484532,  0.5002706 ,  0.11413365,
#          0.45304453,  0.19642821,  0.06023208,  0.06080622,  0.5554776 ,
#          0.24008407,  0.15163176, -0.27259246,  0.21532589,  0.00985454],
#        dtype=float32),
#  array([-0.19426033,  0.2626367 ,  0.14125061,  0.0932212 ,  0.10650191,
#         -0.54772496,  0.19505878,  0.52138203, -0.302438  , -0.14372346,
#         -0.1784806 , -0.3973161 , -0.04831089,  0.11454348,  0.23053117,
#         -0.19296743,  0.12101658, -0.34068516, -0.08808295, -0.5773261 ,
#          0.23538288,  0.10279443,  0.07446303, -0.23932914, -0.04828403,
#         -0.02616149, -0.22462551, -0.22083035, -0.30370992,  0.03624651,
#          0.3451379 ,  0.01626876,  0.11599676, -0.20894781, -0.1283676 ,
#          0.42769223,  0.06222741, -0.12878937, -0.13406737, -0.51730895,
#          0.12060855, -0.24826288, -0.19385125,  0.00244202,  0.16229531,
#          0.01360083, -0.12234648, -0.03646678,  0.23821807,  0.16232756,
#          0.168855  , -0.20639911, -0.04655377,  0.06251706, -0.03302733,
#          0.07738607,  0.15840308,  0.01465047, -0.3852242 ,  0.19786696,
#          0.00826569,  0.1777029 ,  0.00563109, -0.11161906, -0.32775787,
#          0.30019844,  0.11125157,  0.24788508, -0.36737794,  0.4386    ,
#         -0.2804639 ,  0.1720654 ,  0.42815846, -0.13255025,  0.40363067,
#          0.08062179,  0.12440746, -0.09958266, -0.20654047,  0.08815741,
#         -0.26013094, -0.10619602, -0.2926844 ,  0.50129646, -0.18552028,
#         -0.04814252,  0.04435993,  0.24337164,  0.43090105,  0.05755686,
#          0.40875083,  0.16247001,  0.043303  ,  0.05976268,  0.46893573,
#          0.21397932,  0.15920189, -0.23300254,  0.17209953, -0.00654018],
#        dtype=float32),
#  array([-2.09453419e-01,  2.67445952e-01,  1.42282054e-01,  9.37200338e-02,
#          1.15439758e-01, -5.61500430e-01,  1.87392607e-01,  5.21761358e-01,
#         -3.10251057e-01, -1.35725304e-01, -1.86477721e-01, -4.06972528e-01,
#         -5.41957691e-02,  1.11057714e-01,  2.32666701e-01, -1.98687956e-01,
#          1.24565057e-01, -3.55264902e-01, -9.50333923e-02, -5.80671728e-01,
#          2.25971311e-01,  1.18514352e-01,  7.77316466e-02, -2.36465707e-01,
#         -4.86699566e-02, -2.13283282e-02, -2.36527637e-01, -2.24059209e-01,
#         -3.04335415e-01,  3.61338966e-02,  3.47895443e-01,  1.10015646e-02,
#          1.00892656e-01, -1.97471976e-01, -1.34081557e-01,  4.25805658e-01,
#          7.06131831e-02, -1.36618033e-01, -1.27759784e-01, -5.33205688e-01,
#          1.25723347e-01, -2.57014096e-01, -2.03037962e-01,  1.24112761e-04,
#          1.54306620e-01,  1.52272517e-02, -1.23652972e-01, -3.63894217e-02,
#          2.34710604e-01,  1.54636621e-01,  1.64635718e-01, -2.19582915e-01,
#         -3.85030098e-02,  7.30408728e-02, -5.19081913e-02,  8.58002901e-02,
#          1.72780678e-01,  8.34251754e-03, -3.92942429e-01,  2.08329052e-01,
#          8.81043635e-03,  1.72152355e-01,  3.67468968e-03, -1.12939335e-01,
#         -3.38805079e-01,  2.98419774e-01,  1.06181562e-01,  2.56766230e-01,
#         -3.77388149e-01,  4.49247807e-01, -2.91644841e-01,  1.79440126e-01,
#          4.31993991e-01, -1.54984310e-01,  4.02298361e-01,  7.60239810e-02,
#          1.11406043e-01, -1.03545763e-01, -2.18080536e-01,  7.47122243e-02,
#         -2.52594441e-01, -1.11509800e-01, -2.89809108e-01,  5.07587075e-01,
#         -1.82305247e-01, -4.01386470e-02,  3.65157388e-02,  2.48386800e-01,
#          4.27104920e-01,  5.66296056e-02,  4.07346785e-01,  1.60417557e-01,
#          3.59340832e-02,  5.23765609e-02,  4.78123724e-01,  2.20913142e-01,
#          1.54204831e-01, -2.47683033e-01,  1.82851329e-01, -3.56187671e-03],
#        dtype=float32),
#  array([-0.2428418 ,  0.30233988,  0.1681519 ,  0.10905687,  0.1364262 ,
#         -0.6554951 ,  0.22107255,  0.6227289 , -0.36571375, -0.18226235,
#         -0.21101496, -0.47605196, -0.06090494,  0.13552156,  0.281314  ,
#         -0.22770968,  0.15401705, -0.41247565, -0.10298456, -0.6931517 ,
#          0.27989322,  0.12067401,  0.10585755, -0.2958476 , -0.04446847,
#         -0.02691136, -0.26647004, -0.25066394, -0.35225505,  0.04934882,
#          0.42141142,  0.01442567,  0.13700865, -0.2355375 , -0.14375794,
#          0.51057804,  0.08313759, -0.15657207, -0.14177117, -0.60811675,
#          0.15727761, -0.31803092, -0.24182652,  0.01146392,  0.1899503 ,
#          0.03145222, -0.14718322, -0.03905315,  0.26454058,  0.18690753,
#          0.20941494, -0.24542272, -0.04285958,  0.0875623 , -0.04357806,
#          0.10240665,  0.18835373,  0.02234438, -0.44991115,  0.2457481 ,
#          0.01649719,  0.20441975,  0.0107539 , -0.12030335, -0.38628176,
#          0.35734844,  0.14263806,  0.29916683, -0.43228865,  0.5343269 ,
#         -0.33153927,  0.20129083,  0.50954545, -0.15423365,  0.48040146,
#          0.09522492,  0.13039853, -0.12247614, -0.2371528 ,  0.1040337 ,
#         -0.30606806, -0.11899787, -0.33775413,  0.5996407 , -0.2084473 ,
#         -0.0390996 ,  0.06677472,  0.2762987 ,  0.50221026,  0.06720473,
#          0.4869602 ,  0.18180673,  0.04314386,  0.06925828,  0.5495072 ,
#          0.26318198,  0.18595728, -0.28116953,  0.19944596, -0.00984896],
#        dtype=float32),
#  array([-0.16938993,  0.21714288,  0.12007067,  0.07960419,  0.0885903 ,
#         -0.46457136,  0.1584395 ,  0.43637773, -0.25336862, -0.12630971,
#         -0.14688583, -0.33527532, -0.04138893,  0.09468711,  0.19119887,
#         -0.1608404 ,  0.10401285, -0.28987944, -0.0758396 , -0.48497486,
#          0.19473387,  0.08810275,  0.06477141, -0.20274377, -0.03526277,
#         -0.02131646, -0.18778552, -0.17977597, -0.25467527,  0.02968388,
#          0.29211375,  0.01203722,  0.10042166, -0.17046867, -0.10574055,
#          0.35889646,  0.06225506, -0.11453822, -0.11039221, -0.43663654,
#          0.10345444, -0.21924771, -0.1718594 ,  0.00111907,  0.13499315,
#          0.01669885, -0.10193937, -0.02561547,  0.1881374 ,  0.1334094 ,
#          0.14398639, -0.17410214, -0.03926689,  0.0591809 , -0.03621617,
#          0.066665  ,  0.13219522,  0.01207396, -0.3252332 ,  0.16585527,
#          0.00633681,  0.14399758,  0.00493   , -0.0902115 , -0.2770889 ,
#          0.25454584,  0.0945955 ,  0.21493034, -0.3090236 ,  0.3733145 ,
#         -0.23660876,  0.15128823,  0.3629612 , -0.11266475,  0.3413324 ,
#          0.06498805,  0.0983805 , -0.09117467, -0.16930084,  0.07233352,
#         -0.21946354, -0.08811687, -0.23726106,  0.4270787 , -0.14783698,
#         -0.03361829,  0.03948173,  0.19644336,  0.35503706,  0.05190608,
#          0.34004095,  0.12923478,  0.03875461,  0.04934194,  0.3907728 ,
#          0.18385075,  0.12530631, -0.20345236,  0.14504959, -0.00534822],
#        dtype=float32),
#  array([-0.24480164,  0.32014045,  0.17626746,  0.11038351,  0.11953139,
#         -0.6709868 ,  0.23164606,  0.62634933, -0.3641816 , -0.1925162 ,
#         -0.20820582, -0.4886936 , -0.05393974,  0.12853724,  0.28075144,
#         -0.23248145,  0.15131815, -0.42744222, -0.10619623, -0.7000784 ,
#          0.2700866 ,  0.13592172,  0.09650359, -0.29645103, -0.0535819 ,
#         -0.03503266, -0.27642396, -0.26144487, -0.36280388,  0.04915544,
#          0.42674923,  0.01511872,  0.14732702, -0.22732022, -0.15458933,
#          0.5287405 ,  0.09351981, -0.16893388, -0.16653796, -0.63483566,
#          0.14982596, -0.32255137, -0.25595793,  0.00485236,  0.18702388,
#          0.02601866, -0.14721128, -0.03389351,  0.26974583,  0.19533494,
#          0.2094126 , -0.26124987, -0.05485969,  0.09344406, -0.0581851 ,
#          0.09843843,  0.19432189,  0.01042094, -0.4691333 ,  0.2474607 ,
#          0.0027919 ,  0.20029879,  0.01425941, -0.14033559, -0.409262  ,
#          0.36874378,  0.13217914,  0.30617073, -0.45963103,  0.539744  ,
#         -0.34785193,  0.2331084 ,  0.5311711 , -0.1658617 ,  0.49360284,
#          0.10448053,  0.14854218, -0.1373052 , -0.24971485,  0.09774061,
#         -0.3171322 , -0.13110709, -0.34023902,  0.620661  , -0.21241227,
#         -0.04622403,  0.04295861,  0.27151424,  0.5138038 ,  0.07912198,
#          0.48966223,  0.19355609,  0.04661505,  0.0703785 ,  0.5694252 ,
#          0.25762662,  0.17671797, -0.29457816,  0.21295743, -0.00305123],
#        dtype=float32),
#  array([-0.22225833,  0.2592312 ,  0.15434715,  0.09151341,  0.12685126,
#         -0.55120146,  0.18944563,  0.5417044 , -0.31387913, -0.15390292,
#         -0.18177629, -0.40965626, -0.04380014,  0.12086305,  0.25203067,
#         -0.19207907,  0.13719936, -0.34708473, -0.08772369, -0.610341  ,
#          0.24733096,  0.09741431,  0.09204262, -0.25666142, -0.0387041 ,
#         -0.01862819, -0.2236395 , -0.2237368 , -0.29889643,  0.05081685,
#          0.3740525 ,  0.01076247,  0.11750618, -0.18887287, -0.1234209 ,
#          0.4406609 ,  0.05988939, -0.12839034, -0.10217719, -0.5151618 ,
#          0.14946648, -0.27110836, -0.20249926,  0.01322803,  0.16445072,
#          0.02952577, -0.13606212, -0.03340701,  0.21038215,  0.15876873,
#          0.18785831, -0.20015314, -0.03283609,  0.07253672, -0.02532932,
#          0.09701248,  0.16234392,  0.03284686, -0.38073558,  0.21187785,
#          0.00941826,  0.17064387,  0.00859372, -0.09503501, -0.3177978 ,
#          0.2984061 ,  0.13392708,  0.25963628, -0.34962893,  0.4520734 ,
#         -0.2850296 ,  0.15763217,  0.4362766 , -0.11884376,  0.40515688,
#          0.08005238,  0.11998046, -0.1032621 , -0.19628853,  0.09704503,
#         -0.25947106, -0.08994218, -0.275313  ,  0.520383  , -0.18533301,
#         -0.02501502,  0.07849658,  0.23193075,  0.42952755,  0.03533975,
#          0.42877585,  0.1516828 ,  0.03969183,  0.06412962,  0.46640587,
#          0.23882595,  0.17051944, -0.24297732,  0.16005486, -0.01079807],
#        dtype=float32),
#  array([-0.2398591 ,  0.31334725,  0.17243387,  0.111244  ,  0.13778953,
#         -0.6611347 ,  0.23224732,  0.6442098 , -0.37277752, -0.18239984,
#         -0.21880291, -0.48239586, -0.05992381,  0.14051221,  0.28937826,
#         -0.22794391,  0.15144558, -0.4124014 , -0.11295528, -0.7065339 ,
#          0.28391606,  0.11099656,  0.0986527 , -0.30624506, -0.05040412,
#         -0.03160039, -0.26948187, -0.26031548, -0.36291358,  0.04650973,
#          0.42288285,  0.01920089,  0.14416066, -0.2534444 , -0.15130995,
#          0.51871926,  0.09030401, -0.155188  , -0.15624475, -0.6154328 ,
#          0.1516979 , -0.31130007, -0.24204437,  0.01152558,  0.20317562,
#          0.02252113, -0.15006234, -0.03829757,  0.27762693,  0.19602741,
#          0.212727  , -0.24647066, -0.05616673,  0.08524625, -0.04073406,
#          0.10122031,  0.18791418,  0.02111589, -0.45986924,  0.24830054,
#          0.01739454,  0.20925891,  0.01206655, -0.1254762 , -0.3872647 ,
#          0.3682437 ,  0.14593758,  0.30464548, -0.4365521 ,  0.5376442 ,
#         -0.33872813,  0.20780835,  0.5159142 , -0.15087469,  0.4851609 ,
#          0.09451722,  0.1416131 , -0.12837733, -0.23860541,  0.1126418 ,
#         -0.314367  , -0.12313182, -0.35023758,  0.6125717 , -0.21861242,
#         -0.0459398 ,  0.06915223,  0.28806692,  0.5160755 ,  0.0690976 ,
#          0.49814668,  0.19351542,  0.04886008,  0.07320701,  0.56410444,
#          0.27017227,  0.18824448, -0.2862344 ,  0.20081258, -0.01297008],
#        dtype=float32),
#  array([-2.14011922e-01,  2.79354751e-01,  1.48809820e-01,  9.66140702e-02,
#          1.23989001e-01, -5.82045317e-01,  2.04211742e-01,  5.69391072e-01,
#         -3.24878901e-01, -1.64800003e-01, -1.88080624e-01, -4.24224347e-01,
#         -4.78328317e-02,  1.26011312e-01,  2.57672638e-01, -1.94879964e-01,
#          1.31618917e-01, -3.59663218e-01, -9.11028758e-02, -6.33724451e-01,
#          2.54133821e-01,  9.67231914e-02,  8.63559470e-02, -2.54282832e-01,
#         -5.26825897e-02, -2.92891394e-02, -2.35289648e-01, -2.34956950e-01,
#         -3.17630798e-01,  4.24480848e-02,  3.79442096e-01,  1.73267853e-02,
#          1.35362759e-01, -2.24049985e-01, -1.33764088e-01,  4.62083340e-01,
#          6.51232302e-02, -1.33367866e-01, -1.37805432e-01, -5.41772842e-01,
#          1.31019726e-01, -2.66342491e-01, -2.07780510e-01,  7.47294724e-03,
#          1.85958430e-01,  1.28136240e-02, -1.28793076e-01, -4.12102863e-02,
#          2.46793166e-01,  1.79784939e-01,  1.88645691e-01, -2.07449526e-01,
#         -5.37590124e-02,  6.54188842e-02, -2.47357246e-02,  8.35387036e-02,
#          1.72316819e-01,  2.63479594e-02, -4.01931465e-01,  2.08302319e-01,
#          9.27311182e-03,  1.93324015e-01, -1.52406807e-04, -1.09565482e-01,
#         -3.45320940e-01,  3.20350021e-01,  1.37630492e-01,  2.72986174e-01,
#         -3.79698932e-01,  4.71978128e-01, -2.96576589e-01,  1.66466206e-01,
#          4.56347883e-01, -1.28000066e-01,  4.31095839e-01,  8.01835358e-02,
#          1.36916280e-01, -1.07529290e-01, -2.16198429e-01,  1.06067799e-01,
#         -2.83054709e-01, -1.06119804e-01, -3.02136779e-01,  5.49376726e-01,
#         -2.04517305e-01, -4.54617515e-02,  6.62188381e-02,  2.64396578e-01,
#          4.59400803e-01,  4.97768037e-02,  4.42271262e-01,  1.73309386e-01,
#          5.20969480e-02,  7.67579451e-02,  5.04880488e-01,  2.41206110e-01,
#          1.86146602e-01, -2.47827083e-01,  1.70266554e-01, -1.75731629e-02],
#        dtype=float32),
#  array([-0.24817699,  0.31904614,  0.17339788,  0.11468763,  0.13057981,
#         -0.6658092 ,  0.22906929,  0.635251  , -0.36977625, -0.18655333,
#         -0.21381682, -0.48483303, -0.05724342,  0.13710023,  0.2832706 ,
#         -0.2274191 ,  0.15356392, -0.41596845, -0.10471591, -0.71112037,
#          0.28504273,  0.12313261,  0.0980961 , -0.29699832, -0.05009693,
#         -0.02773688, -0.27258813, -0.2580078 , -0.36445856,  0.04976428,
#          0.4273082 ,  0.01737836,  0.14899002, -0.24869165, -0.15083276,
#          0.5197645 ,  0.08524371, -0.15972058, -0.15546574, -0.6216274 ,
#          0.15193754, -0.31538662, -0.24453567,  0.00685275,  0.19687878,
#          0.0208625 , -0.14704327, -0.03885913,  0.2765782 ,  0.19061445,
#          0.212575  , -0.2460197 , -0.05746721,  0.08394817, -0.04171441,
#          0.09662562,  0.19409285,  0.02249958, -0.46373004,  0.24757534,
#          0.01035625,  0.21429731,  0.00693688, -0.12579818, -0.39168358,
#          0.3653483 ,  0.14504974,  0.30891326, -0.44108668,  0.53918153,
#         -0.33959478,  0.2079234 ,  0.5194071 , -0.15376176,  0.49160385,
#          0.09851888,  0.14051695, -0.12919582, -0.23939818,  0.10927301,
#         -0.31734073, -0.1272134 , -0.3409581 ,  0.61799514, -0.21669368,
#         -0.04528012,  0.0654658 ,  0.28421932,  0.5175972 ,  0.06709138,
#          0.4960162 ,  0.189287  ,  0.05204209,  0.07516739,  0.5653654 ,
#          0.26058817,  0.19146518, -0.2873732 ,  0.20161238, -0.00841506],
#        dtype=float32),
#  array([-0.25298107,  0.33084577,  0.17795648,  0.11334151,  0.13757564,
#         -0.68867874,  0.24681014,  0.6653017 , -0.3854129 , -0.18310164,
#         -0.22525033, -0.50456065, -0.06432226,  0.14131561,  0.2963983 ,
#         -0.24146684,  0.15528165, -0.43161112, -0.11043422, -0.7383809 ,
# ...
#          4.70659345e-01,  9.87432152e-02,  4.31141675e-01,  1.80039778e-01,
#          4.77247424e-02,  5.30700162e-02,  5.21519363e-01,  2.23280624e-01,
#          1.44681796e-01, -2.62399673e-01,  1.96560487e-01,  5.51105011e-03],
#        dtype=float32),
#  array([-1.85152441e-01,  2.45705441e-01,  1.35490552e-01,  9.58967581e-02,
#          9.43868905e-02, -5.19856155e-01,  1.84469968e-01,  4.71479207e-01,
#         -2.81799018e-01, -1.41835600e-01, -1.60538122e-01, -3.75875175e-01,
#         -4.96198125e-02,  9.96394828e-02,  2.03137070e-01, -1.78519204e-01,
#          1.17237143e-01, -3.24931800e-01, -8.29655975e-02, -5.25956988e-01,
#          2.09474325e-01,  1.12917118e-01,  7.75281042e-02, -2.24071950e-01,
#         -2.95774601e-02, -2.78963521e-02, -2.11039603e-01, -1.90215811e-01,
#         -2.85424948e-01,  3.19831818e-02,  3.23320359e-01,  1.42522156e-02,
#          1.11472473e-01, -1.81633323e-01, -1.12832151e-01,  4.03829575e-01,
#          8.50799754e-02, -1.31017283e-01, -1.35184839e-01, -4.93092328e-01,
#          1.10201083e-01, -2.48008415e-01, -1.95433319e-01, -5.42233582e-04,
#          1.40305102e-01,  2.60808989e-02, -1.14110470e-01, -1.95853449e-02,
#          2.09487572e-01,  1.43834516e-01,  1.60050005e-01, -2.10677758e-01,
#         -4.81521040e-02,  7.16067702e-02, -5.47563657e-02,  6.64021969e-02,
#          1.48559421e-01,  5.55000988e-05, -3.70747924e-01,  1.89631149e-01,
#         -3.18765116e-04,  1.52819216e-01,  1.81958675e-02, -1.12808309e-01,
#         -3.18921357e-01,  2.86670148e-01,  9.54530165e-02,  2.38118991e-01,
#         -3.64043236e-01,  4.21022952e-01, -2.69167334e-01,  1.91260993e-01,
#          4.04200763e-01, -1.33419126e-01,  3.82600427e-01,  6.98389113e-02,
#          1.04838744e-01, -1.10393092e-01, -1.90281451e-01,  7.13718832e-02,
#         -2.47062266e-01, -1.05772257e-01, -2.64386773e-01,  4.67765659e-01,
#         -1.52342826e-01, -3.58670205e-02,  2.86840331e-02,  2.01916754e-01,
#          3.89809817e-01,  7.43442029e-02,  3.65636557e-01,  1.50661439e-01,
#          3.72645631e-02,  4.29658554e-02,  4.37152088e-01,  1.90662131e-01,
#          1.23834133e-01, -2.25366801e-01,  1.68922976e-01,  2.51848716e-03],
#        dtype=float32),
#  array([-0.2025038 ,  0.3243362 ,  0.17122501,  0.09479806,  0.10674359,
#         -0.64497864,  0.2491629 ,  0.61645097, -0.3472934 , -0.19448212,
#         -0.19814117, -0.48803514, -0.06256014,  0.1242514 ,  0.25470865,
#         -0.22132972,  0.14332484, -0.3961809 , -0.08702057, -0.67090946,
#          0.2813921 ,  0.13614592,  0.0709205 , -0.28115246, -0.05431318,
#         -0.04272826, -0.26123485, -0.2440134 , -0.38996914,  0.02549015,
#          0.40424448,  0.03383692,  0.1640359 , -0.27268165, -0.14154115,
#          0.51278734,  0.0853907 , -0.16397029, -0.19507907, -0.6310818 ,
#          0.13518392, -0.30088595, -0.25463447, -0.02208113,  0.20580322,
#          0.00447129, -0.12920177, -0.04002009,  0.3077105 ,  0.21489152,
#          0.21945322, -0.25259387, -0.07994924,  0.05668616, -0.03752253,
#          0.05641465,  0.18512627,  0.02341734, -0.4656078 ,  0.2180453 ,
#         -0.01611747,  0.21897411,  0.00644483, -0.17218998, -0.41710186,
#          0.3713226 ,  0.13822639,  0.3069626 , -0.47903943,  0.53591275,
#         -0.3357585 ,  0.23483247,  0.5446297 , -0.15213323,  0.50306666,
#          0.10293603,  0.1706419 , -0.14932498, -0.24782416,  0.12880261,
#         -0.3542915 , -0.13641438, -0.35398203,  0.62242943, -0.22937736,
#         -0.08911929,  0.02609154,  0.27624175,  0.52992284,  0.11544497,
#          0.4627773 ,  0.21257746,  0.08487134,  0.07846488,  0.56885946,
#          0.25494567,  0.19416259, -0.24580488,  0.21377435, -0.00746102],
#        dtype=float32),
#  array([-0.21916425,  0.3092206 ,  0.15711868,  0.10406382,  0.11527962,
#         -0.63752747,  0.23439632,  0.60440767, -0.35011122, -0.17218232,
#         -0.19632174, -0.46598247, -0.05621359,  0.12311675,  0.26258236,
#         -0.21822889,  0.1465472 , -0.39118814, -0.09871049, -0.6705047 ,
#          0.2735476 ,  0.12546398,  0.09129035, -0.28548223, -0.05441532,
#         -0.03698982, -0.25125554, -0.24616624, -0.35585985,  0.03502961,
#          0.4037946 ,  0.01880075,  0.14398758, -0.2454947 , -0.1431913 ,
#          0.5058717 ,  0.08873291, -0.15278511, -0.16207166, -0.6025134 ,
#          0.14380941, -0.30400917, -0.23608632,  0.00067282,  0.19067271,
#          0.02679157, -0.13741662, -0.03236307,  0.2756854 ,  0.18627815,
#          0.20551682, -0.24113436, -0.06051508,  0.07584524, -0.04687595,
#          0.08402658,  0.18454051,  0.01406756, -0.45349404,  0.22332656,
#          0.00661561,  0.20187478,  0.0099455 , -0.13738169, -0.38474956,
#          0.3576929 ,  0.13244879,  0.2960721 , -0.44205904,  0.5198149 ,
#         -0.32881615,  0.21584816,  0.50999606, -0.14893259,  0.48039562,
#          0.10005106,  0.15142167, -0.13065936, -0.23491152,  0.1100621 ,
#         -0.31764317, -0.12203927, -0.3373775 ,  0.59514314, -0.21229692,
#         -0.05880182,  0.04168454,  0.27025715,  0.50276166,  0.08399945,
#          0.46755484,  0.19143412,  0.0608581 ,  0.07301302,  0.55096537,
#          0.25368392,  0.18310502, -0.2607743 ,  0.19898914, -0.00885059],
#        dtype=float32),
#  array([-0.24866681,  0.31876743,  0.16615999,  0.11702317,  0.13479795,
#         -0.68173534,  0.2333999 ,  0.6479459 , -0.3834397 , -0.17517632,
#         -0.22064522, -0.48861307, -0.06159182,  0.14356741,  0.28207833,
#         -0.24469343,  0.1543021 , -0.4271265 , -0.11966525, -0.7117365 ,
#          0.2839883 ,  0.12888348,  0.09577862, -0.28822675, -0.05947109,
#         -0.03198936, -0.28088772, -0.2725677 , -0.36652592,  0.04449505,
#          0.4225393 ,  0.01774348,  0.13860653, -0.2504652 , -0.15917978,
#          0.5221437 ,  0.08617631, -0.15789166, -0.15701833, -0.6394964 ,
#          0.15290555, -0.31407315, -0.24845067,  0.00837627,  0.19086805,
#          0.01727039, -0.1482945 , -0.04407816,  0.28492525,  0.19250982,
#          0.19957656, -0.25617528, -0.04716957,  0.08361526, -0.04946663,
#          0.10383375,  0.20438771,  0.01473652, -0.4692936 ,  0.2571625 ,
#          0.02094713,  0.21085382,  0.00429478, -0.1350145 , -0.40472427,
#          0.36937717,  0.13671355,  0.30736673, -0.45658702,  0.54738677,
#         -0.34474096,  0.20730627,  0.52316034, -0.17324373,  0.4922215 ,
#          0.09292647,  0.13835648, -0.12341098, -0.25557736,  0.09589573,
#         -0.30390787, -0.12401307, -0.3598779 ,  0.611602  , -0.2271924 ,
#         -0.04863315,  0.06190168,  0.2972981 ,  0.5187778 ,  0.0713485 ,
#          0.49904042,  0.19188738,  0.04679762,  0.07125085,  0.5781134 ,
#          0.26588118,  0.18956605, -0.29850346,  0.2200996 , -0.01351125],
#        dtype=float32),
#  array([-1.68415412e-01,  2.38594368e-01,  1.26759306e-01,  8.38943347e-02,
#          8.97738487e-02, -4.99853820e-01,  1.78286955e-01,  4.66788203e-01,
#         -2.71869004e-01, -1.37724429e-01, -1.48773745e-01, -3.68229926e-01,
#         -3.79459932e-02,  9.71933082e-02,  2.00903445e-01, -1.69355556e-01,
#          1.16001882e-01, -3.03389162e-01, -7.52897412e-02, -5.15512466e-01,
#          2.12155312e-01,  1.06247962e-01,  6.61562607e-02, -2.21894711e-01,
#         -4.07156199e-02, -2.94734444e-02, -1.95371836e-01, -1.86502114e-01,
#         -2.84498155e-01,  2.65556034e-02,  3.20716679e-01,  1.62812173e-02,
#          1.15403958e-01, -1.84221193e-01, -1.12994820e-01,  3.94009322e-01,
#          6.77398369e-02, -1.24228612e-01, -1.32620931e-01, -4.76924658e-01,
#          1.11619458e-01, -2.37278506e-01, -1.84085593e-01, -3.90605838e-03,
#          1.55169293e-01,  2.29597241e-02, -1.06018804e-01, -2.57317536e-02,
#          2.12803155e-01,  1.45194218e-01,  1.59933478e-01, -1.93742633e-01,
#         -5.74124493e-02,  5.76974377e-02, -4.74396646e-02,  5.85270040e-02,
#          1.40475780e-01,  5.11079980e-03, -3.60263973e-01,  1.71025559e-01,
#         -2.50331988e-03,  1.58941433e-01,  1.19804004e-02, -1.15493096e-01,
#         -3.11202586e-01,  2.81953990e-01,  1.02698624e-01,  2.29554683e-01,
#         -3.54384005e-01,  4.05651450e-01, -2.57954836e-01,  1.75267056e-01,
#          4.01377320e-01, -1.17841423e-01,  3.80363137e-01,  7.67765269e-02,
#          1.18391663e-01, -1.06210232e-01, -1.82552069e-01,  8.54292735e-02,
#         -2.46790379e-01, -1.00153409e-01, -2.64548242e-01,  4.66445655e-01,
#         -1.59326658e-01, -5.04550189e-02,  2.46164594e-02,  2.02971816e-01,
#          3.94344419e-01,  6.98431879e-02,  3.57476324e-01,  1.55894920e-01,
#          5.16769364e-02,  5.77093065e-02,  4.30730999e-01,  1.98029384e-01,
#          1.40973568e-01, -2.03280836e-01,  1.60067022e-01,  4.36158938e-04],
#        dtype=float32),
#  array([-0.25743002,  0.33749145,  0.18445134,  0.12282397,  0.1459199 ,
#         -0.7112318 ,  0.24985847,  0.68682796, -0.3944398 , -0.20403428,
#         -0.22901651, -0.52812606, -0.06428771,  0.14374042,  0.30386385,
#         -0.2468321 ,  0.1672217 , -0.45545682, -0.11508124, -0.7557082 ,
#          0.29850212,  0.13236551,  0.10139368, -0.32212248, -0.06021122,
#         -0.02914865, -0.29424027, -0.27340704, -0.3802609 ,  0.05355716,
#          0.4597982 ,  0.01526954,  0.15675338, -0.25565368, -0.1687279 ,
#          0.5522057 ,  0.10641816, -0.16763774, -0.1656522 , -0.6704876 ,
#          0.15781376, -0.34449342, -0.25680724,  0.01066004,  0.2136887 ,
#          0.02815389, -0.16043699, -0.04129972,  0.2937097 ,  0.2011412 ,
#          0.22111455, -0.26588517, -0.05868085,  0.09493995, -0.05121909,
#          0.10333139,  0.20920172,  0.0232265 , -0.49106485,  0.27268222,
#          0.00737776,  0.2227552 ,  0.01734176, -0.12938407, -0.42116556,
#          0.40114468,  0.1554124 ,  0.32778877, -0.475669  ,  0.57545483,
#         -0.36054587,  0.21782322,  0.55619925, -0.16800202,  0.5220901 ,
#          0.09191931,  0.14375079, -0.13921869, -0.26394612,  0.10535999,
#         -0.3336267 , -0.1306139 , -0.36797616,  0.6579102 , -0.21890411,
#         -0.04098725,  0.07141458,  0.30114585,  0.54053676,  0.06459168,
#          0.53292805,  0.19935465,  0.05745632,  0.07542537,  0.6061169 ,
#          0.2749796 ,  0.196417  , -0.31402653,  0.21957842, -0.00795515],
#        dtype=float32),
#  array([-0.22996832,  0.29083022,  0.15987319,  0.10816699,  0.11535051,
#         -0.6195337 ,  0.21593666,  0.5786101 , -0.3347163 , -0.1758526 ,
#         -0.1875583 , -0.44735703, -0.05124955,  0.12026199,  0.2499279 ,
#         -0.21008556,  0.14515829, -0.38880965, -0.10248387, -0.64096326,
#          0.25170645,  0.11757398,  0.08783305, -0.2650536 , -0.04375613,
#         -0.02701873, -0.24603736, -0.23038274, -0.34297678,  0.03676474,
#          0.38186634,  0.01895334,  0.13250227, -0.22827415, -0.13662557,
#          0.47935393,  0.09372315, -0.1595325 , -0.15759383, -0.5780857 ,
#          0.12830411, -0.29251042, -0.23142432,  0.00284908,  0.17726366,
#          0.0197069 , -0.1338027 , -0.02720325,  0.2538787 ,  0.18054855,
#          0.18749462, -0.23111777, -0.05999577,  0.0792436 , -0.05490638,
#          0.08702681,  0.18626153,  0.01131361, -0.4316434 ,  0.22678815,
#          0.0071196 ,  0.19416796,  0.0124562 , -0.12666886, -0.3714435 ,
#          0.33898714,  0.12430138,  0.28591132, -0.41991076,  0.49968746,
#         -0.31125882,  0.20752841,  0.48118505, -0.15202253,  0.45606837,
#          0.08830297,  0.12191397, -0.12165914, -0.2290283 ,  0.08864642,
#         -0.290106  , -0.1116694 , -0.3116481 ,  0.56201655, -0.19595385,
#         -0.04327379,  0.04808835,  0.2613443 ,  0.47217834,  0.07760864,
#          0.44258535,  0.17696898,  0.04931605,  0.06361984,  0.5272843 ,
#          0.24378116,  0.1621591 , -0.2679304 ,  0.1964723 , -0.00544088],
#        dtype=float32),
#  array([-0.23987646,  0.3063186 ,  0.1699521 ,  0.112309  ,  0.1319774 ,
#         -0.6498117 ,  0.2259388 ,  0.61922264, -0.35816714, -0.18200804,
#         -0.20436443, -0.47237957, -0.05792539,  0.13428673,  0.2705801 ,
#         -0.22430326,  0.14817946, -0.40593663, -0.11040046, -0.68399423,
#          0.27229893,  0.11819053,  0.09661648, -0.28724477, -0.04603751,
#         -0.0288486 , -0.26437858, -0.24716392, -0.3544366 ,  0.04581546,
#          0.41263586,  0.01735685,  0.13996291, -0.24285227, -0.14737315,
#          0.5068473 ,  0.09298649, -0.16294716, -0.15577514, -0.60388094,
#          0.14221312, -0.30843464, -0.23926291,  0.00413457,  0.19267912,
#          0.02226631, -0.14439163, -0.03919336,  0.27096334,  0.18931563,
#          0.20185518, -0.2445191 , -0.05314775,  0.08612515, -0.04988587,
#          0.09646019,  0.19003834,  0.01703986, -0.45087436,  0.24062096,
#          0.01463606,  0.20573993,  0.01377239, -0.12754086, -0.38461915,
#          0.3577503 ,  0.13769035,  0.3004087 , -0.4318542 ,  0.527475  ,
#         -0.32649773,  0.20654917,  0.5042867 , -0.15309766,  0.47583023,
#          0.08718946,  0.13452533, -0.1280114 , -0.23715448,  0.09727058,
#         -0.30461848, -0.12080528, -0.3339695 ,  0.59303164, -0.21414588,
#         -0.04639415,  0.05927444,  0.27816483,  0.49767476,  0.06988226,
#          0.4801509 ,  0.1832512 ,  0.04874719,  0.06543291,  0.55166435,
#          0.25956482,  0.17808136, -0.28350335,  0.19830137, -0.00871537],
#        dtype=float32),
#  array([-0.23759136,  0.31710908,  0.16764128,  0.11256343,  0.12687108,
#         -0.65752   ,  0.23636597,  0.63019484, -0.36537984, -0.17941067,
#         -0.20735651, -0.48008493, -0.05758275,  0.13603482,  0.2752706 ,
#         -0.22830829,  0.15115872, -0.40770274, -0.10327428, -0.7000318 ,
#          0.28546017,  0.1216974 ,  0.09539108, -0.2902748 , -0.05877292,
#         -0.03298758, -0.26414815, -0.25759047, -0.3671026 ,  0.0461803 ,
#          0.42359394,  0.01807589,  0.15037273, -0.2499242 , -0.15053342,
#          0.5240083 ,  0.08276773, -0.15301478, -0.1601099 , -0.61802185,
#          0.15296462, -0.31400394, -0.24327251,  0.00288624,  0.20115255,
#          0.02506817, -0.14321299, -0.0387379 ,  0.28325194,  0.1951281 ,
#          0.21368428, -0.24518317, -0.06013196,  0.07456261, -0.04431292,
#          0.08821674,  0.1868883 ,  0.01781807, -0.4700473 ,  0.23304464,
#          0.00659856,  0.2092976 ,  0.00889524, -0.1358591 , -0.39593822,
#          0.36331698,  0.14459558,  0.30560103, -0.44846576,  0.53664154,
#         -0.335832  ,  0.21229984,  0.52190804, -0.15288694,  0.49313658,
#          0.09782856,  0.15293628, -0.12961543, -0.24039993,  0.11294053,
#         -0.32029986, -0.12956783, -0.34548604,  0.6141669 , -0.22239506,
#         -0.05973696,  0.05751792,  0.28414708,  0.5152277 ,  0.07294602,
#          0.48868096,  0.19471592,  0.060241  ,  0.0775232 ,  0.5636185 ,
#          0.26461583,  0.19520149, -0.27646136,  0.20223206, -0.00728065],
#        dtype=float32),
#  array([-0.22514954,  0.29965162,  0.15640232,  0.1079428 ,  0.1254832 ,
#         -0.6374754 ,  0.2230196 ,  0.59302545, -0.35258722, -0.16750258,
#         -0.20416203, -0.45543253, -0.05641296,  0.1249292 ,  0.25691572,
#         -0.22182758,  0.1440366 , -0.39619404, -0.10807321, -0.6621743 ,
#          0.2600866 ,  0.12384461,  0.08715516, -0.2759389 , -0.04954305,
#         -0.02771543, -0.2624633 , -0.24961333, -0.34824312,  0.04276094,
#          0.38843995,  0.01938428,  0.12974653, -0.23877418, -0.14514911,
#          0.48917928,  0.08507729, -0.1517176 , -0.15340422, -0.59926313,
#          0.13820404, -0.2976173 , -0.23184755,  0.00447982,  0.1790686 ,
#          0.01329737, -0.13549554, -0.0368978 ,  0.26743612,  0.17617282,
#          0.18764737, -0.24470554, -0.04447972,  0.0801046 , -0.05314473,
#          0.08963238,  0.18631223,  0.00792269, -0.44046783,  0.2391608 ,
#          0.01800656,  0.19359434,  0.00996125, -0.12673554, -0.38072252,
#          0.3506539 ,  0.12366742,  0.28959307, -0.43284535,  0.51002   ,
#         -0.32769904,  0.20478146,  0.49278083, -0.16517913,  0.45988783,
#          0.08683216,  0.12311803, -0.12124386, -0.23694952,  0.08998782,
#         -0.29035842, -0.11745062, -0.3372579 ,  0.5696235 , -0.20350856,
#         -0.04899964,  0.049938  ,  0.27887562,  0.48708194,  0.07578751,
#          0.45881602,  0.17822766,  0.0407275 ,  0.06282124,  0.5366912 ,
#          0.24711548,  0.16727287, -0.27703413,  0.20662086, -0.00905381],
#        dtype=float32),
#  ...]

# %%
len(X)
# Out:
# 5569

# %%
##independent Features
X_new=np.array(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 ##independent Features
# ----> 2 X_new=np.array(X)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5569,) + inhomogeneous part.

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X[0]
# Out:
# array([-1.71343833e-01,  2.36079827e-01,  1.24769114e-01,  8.30340385e-02,
#         9.28719714e-02, -4.97339725e-01,  1.79416478e-01,  4.64051694e-01,
#        -2.69818693e-01, -1.32228106e-01, -1.55763462e-01, -3.60272825e-01,
#        -4.94791269e-02,  9.53688920e-02,  1.98053688e-01, -1.68316498e-01,
#         1.06815659e-01, -3.07823360e-01, -7.90153667e-02, -5.12440503e-01,
#         2.00984702e-01,  9.91651490e-02,  7.16567039e-02, -2.17182145e-01,
#        -4.32692207e-02, -2.81740259e-02, -2.00575620e-01, -1.93412021e-01,
#        -2.74952054e-01,  3.32614854e-02,  3.05104613e-01,  1.13960123e-02,
#         1.03895150e-01, -1.87506706e-01, -1.11927785e-01,  3.86822522e-01,
#         6.65969998e-02, -1.19801432e-01, -1.27736434e-01, -4.64834183e-01,
#         1.07727334e-01, -2.27704063e-01, -1.84430972e-01, -2.95696722e-04,
#         1.45751521e-01,  1.59008838e-02, -1.05464600e-01, -2.54447982e-02,
#         2.10545078e-01,  1.42166719e-01,  1.56812683e-01, -1.93317100e-01,
#        -4.67790589e-02,  6.18289188e-02, -4.43275832e-02,  6.64105117e-02,
#         1.46415442e-01,  7.21792085e-03, -3.53858352e-01,  1.77491933e-01,
#         7.06583261e-03,  1.55040577e-01,  6.31303433e-03, -1.08237758e-01,
#        -2.98830569e-01,  2.66570777e-01,  9.78779942e-02,  2.22566277e-01,
#        -3.43684226e-01,  3.93130630e-01, -2.56285548e-01,  1.69512495e-01,
#         3.89814198e-01, -1.21034704e-01,  3.66685033e-01,  7.41155222e-02,
#         1.06651507e-01, -9.78684202e-02, -1.85281649e-01,  7.87086189e-02,
#        -2.37298235e-01, -9.65823159e-02, -2.58712500e-01,  4.53909755e-01,
#        -1.60188973e-01, -4.21204418e-02,  3.00307218e-02,  2.15918049e-01,
#         3.84023368e-01,  6.47714064e-02,  3.60833585e-01,  1.46002218e-01,
#         3.99394482e-02,  5.02587967e-02,  4.26850587e-01,  1.90430984e-01,
#         1.35698959e-01, -2.08878860e-01,  1.59176752e-01, -2.30085198e-03],
#       dtype=float32)

# %%
X_new.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 X_new.shape
#
# NameError: name 'X_new' is not defined

# %%
X_new[0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 X_new[0].shape
#
# NameError: name 'X_new' is not defined

# %%
## Dependent Features
## Output Features
y = messages[list(map(lambda x: len(x)>0 ,corpus))]
y=pd.get_dummies(y['label'])
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (5569,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
## this is the final independent features
df = pd.DataFrame()
df = pd.concat([pd.DataFrame(X[i].reshape(1, -1)) for i in range(len(X))], ignore_index=True)
# Out:
# C:\Users\indira gothi\AppData\Local\Temp\ipykernel_42760\2304316154.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([pd.DataFrame(X[i].reshape(1, -1)) for i in range(len(X))], ignore_index=True)

# %%
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.171344  0.236080  0.124769  0.083034  0.092872 -0.497340  0.179416
# 1 -0.161424  0.209365  0.109102  0.072662  0.087669 -0.433555  0.145645
# 2 -0.184804  0.251041  0.130618  0.094520  0.073111 -0.540703  0.181560
# 3 -0.242900  0.320730  0.166196  0.117586  0.131148 -0.670337  0.234338
# 4 -0.208712  0.270494  0.149421  0.098194  0.115825 -0.572337  0.201613
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.464052 -0.269819 -0.132228  ...  0.360834  0.146002  0.039939  0.050259
# 1  0.409539 -0.236851 -0.107796  ...  0.322922  0.121181  0.031235  0.040097
# 2  0.458629 -0.278619 -0.159143  ...  0.352296  0.145632  0.032471  0.028879
# 3  0.633730 -0.372497 -0.170096  ...  0.494914  0.190915  0.048692  0.074447
# 4  0.548125 -0.319859 -0.155302  ...  0.424475  0.162854  0.047612  0.067024
#
#          94        95        96        97        98        99
# 0  0.426851  0.190431  0.135699 -0.208879  0.159177 -0.002301
# 1  0.366742  0.164515  0.122848 -0.189668  0.143195 -0.009697
# 2  0.441994  0.182365  0.092161 -0.238964  0.181798  0.019547
# 3  0.567949  0.262875  0.200129 -0.289524  0.215430 -0.011726
# 4  0.490321  0.226742  0.165686 -0.253984  0.179603 -0.012644
#
# [5 rows x 100 columns]

# %%
df['Output']=y

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.171344  0.236080  0.124769  0.083034  0.092872 -0.497340  0.179416
# 1 -0.161424  0.209365  0.109102  0.072662  0.087669 -0.433555  0.145645
# 2 -0.184804  0.251041  0.130618  0.094520  0.073111 -0.540703  0.181560
# 3 -0.242900  0.320730  0.166196  0.117586  0.131148 -0.670337  0.234338
# 4 -0.208712  0.270494  0.149421  0.098194  0.115825 -0.572337  0.201613
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.464052 -0.269819 -0.132228  ...  0.146002  0.039939  0.050259  0.426851
# 1  0.409539 -0.236851 -0.107796  ...  0.121181  0.031235  0.040097  0.366742
# 2  0.458629 -0.278619 -0.159143  ...  0.145632  0.032471  0.028879  0.441994
# 3  0.633730 -0.372497 -0.170096  ...  0.190915  0.048692  0.074447  0.567949
# 4  0.548125 -0.319859 -0.155302  ...  0.162854  0.047612  0.067024  0.490321
#
#          95        96        97        98        99  Output
# 0  0.190431  0.135699 -0.208879  0.159177 -0.002301    True
# 1  0.164515  0.122848 -0.189668  0.143195 -0.009697    True
# 2  0.182365  0.092161 -0.238964  0.181798  0.019547   False
# 3  0.262875  0.200129 -0.289524  0.215430 -0.011726    True
# 4  0.226742  0.165686 -0.253984  0.179603 -0.012644    True
#
# [5 rows x 101 columns]

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
## Independent Feature
X=df

# %%
X.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
y=df['Output']

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train.head()
# Out:
#              0         1         2         3         4         5         6  \
# 2612 -0.234369  0.299783  0.159261  0.102305  0.128190 -0.625927  0.218508
# 4399 -0.142475  0.175234  0.101427  0.061967  0.077036 -0.390062  0.127156
# 5463 -0.136203  0.194456  0.102098  0.069638  0.061830 -0.404579  0.139531
# 4984 -0.198514  0.260570  0.134400  0.088225  0.110310 -0.536942  0.190080
# 1945 -0.249285  0.334059  0.178356  0.125679  0.134524 -0.705499  0.245732
#
#              7         8         9  ...        91        92        93  \
# 2612  0.595443 -0.343336 -0.164798  ...  0.181584  0.052947  0.073096
# 4399  0.358058 -0.216783 -0.096410  ...  0.104761  0.019124  0.035571
# 5463  0.362749 -0.213825 -0.109523  ...  0.117939  0.035684  0.038740
# 4984  0.513125 -0.301871 -0.146152  ...  0.155204  0.041380  0.062455
# 1945  0.657129 -0.392499 -0.197251  ...  0.194756  0.043465  0.063577
#
#             94        95        96        97        98        99  Output
# 2612  0.535229  0.251396  0.186480 -0.267187  0.195431 -0.016722    True
# 4399  0.333932  0.146303  0.106805 -0.173599  0.127760 -0.001973    True
# 5463  0.342315  0.147944  0.099894 -0.168188  0.125985  0.000855   False
# 4984  0.454982  0.213283  0.161360 -0.233852  0.163328 -0.008540    True
# 1945  0.594367  0.262759  0.177979 -0.310225  0.224961 -0.002988    True
#
# [5 rows x 101 columns]

# %%
y_train
# Out:
# 2612     True
# 4399     True
# 5463    False
# 4984     True
# 1945     True
#         ...
# 2479    False
# 3187     True
# 938      True
# 2329     True
# 717     False
# Name: Output, Length: 4445, dtype: bool

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 classifier.fit(X_train,y_train)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\ensemble\_forest.py:360, in BaseForest.fit(self, X, y, sample_weight)
#     357 if issparse(y):
#     358     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 360 X, y = validate_data(
#     361     self,
#     362     X,
#     363     y,
#     364     multi_output=True,
#     365     accept_sparse="csc",
#     366     dtype=DTYPE,
#     367     ensure_all_finite=False,
#     368 )
#     369 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     370 # will raise an error if the underlying tree base estimator can't handle missing
#     371 # values. Only the criterion is required to determine if the tree supports
#     372 # missing values.
#     373 estimator = type(self.estimator)(criterion=self.criterion)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:1370, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364     raise ValueError(
#    1365         f"{estimator_name} requires y to be passed, but the target y is None"
#    1366     )
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    1373     accept_large_sparse=accept_large_sparse,
#    1374     dtype=dtype,
#    1375     order=order,
#    1376     copy=copy,
#    1377     force_writeable=force_writeable,
#    1378     ensure_all_finite=ensure_all_finite,
#    1379     ensure_2d=ensure_2d,
#    1380     allow_nd=allow_nd,
#    1381     ensure_min_samples=ensure_min_samples,
#    1382     ensure_min_features=ensure_min_features,
#    1383     estimator=estimator,
#    1384     input_name="X",
#    1385 )
#    1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:1055, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1053         array = xp.astype(array, dtype, copy=False)
#    1054     else:
# -> 1055         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1056 except ComplexWarning as complex_warning:
#    1057     raise ValueError(
#    1058         "Complex data not supported\n{}\n".format(array)
#    1059     ) from complex_warning
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_array_api.py:839, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     837     array = numpy.array(array, order=order, dtype=dtype)
#     838 else:
# --> 839     array = numpy.asarray(array, order=order, dtype=dtype)
#     841 # At this point array is a NumPy ndarray. We convert it to an array
#     842 # container that is consistent with the input's namespace.
#     843 return xp.asarray(array)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:919, in Index.__array__(self, dtype, copy)
#     915 def __array__(self, dtype=None, copy=None) -> np.ndarray:
#     916     """
#     917     The array interface, return my values.
#     918     """
# --> 919     return np.asarray(self._data, dtype=dtype)
#
# ValueError: could not convert string to float: 'Output'

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9973021582733813

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       147
#            1       1.00      1.00      1.00       965
#
#     accuracy                           1.00      1112
#    macro avg       1.00      0.99      0.99      1112
# weighted avg       1.00      1.00      1.00      1112
